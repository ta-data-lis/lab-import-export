# %% [markdown]
# # Import and Export Files

# %% [markdown]
# # Challenge 0 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here
import mysql.connector
import pymysql
import sqlalchemy

import pandas as pd
import getpass

# %%
pwd = getpass.getpass()
cnx = mysql.connector.connect(user = 'root', password = pwd, host = 'localhost', database = 'sakila')
# Out:
# ········

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor() #method called cursor
cursor

# %%
query = ("select title, actor_id, film_actor.film_id from sakila.film inner join sakila.film_actor on film.film_id = film_actor.film_id;")

cursor.execute(query)

# %%
result = cursor.fetchall()
result
# Out:
# [('ACADEMY DINOSAUR', 1, 1),
#  ('ACADEMY DINOSAUR', 10, 1),
#  ('ACADEMY DINOSAUR', 20, 1),
#  ('ACADEMY DINOSAUR', 30, 1),
#  ('ACADEMY DINOSAUR', 40, 1),
#  ('ACADEMY DINOSAUR', 53, 1),
#  ('ACADEMY DINOSAUR', 108, 1),
#  ('ACADEMY DINOSAUR', 162, 1),
#  ('ACADEMY DINOSAUR', 188, 1),
#  ('ACADEMY DINOSAUR', 198, 1),
#  ('ACE GOLDFINGER', 19, 2),
#  ('ACE GOLDFINGER', 85, 2),
#  ('ACE GOLDFINGER', 90, 2),
#  ('ACE GOLDFINGER', 160, 2),
#  ('ADAPTATION HOLES', 2, 3),
#  ('ADAPTATION HOLES', 19, 3),
#  ('ADAPTATION HOLES', 24, 3),
#  ('ADAPTATION HOLES', 64, 3),
#  ('ADAPTATION HOLES', 123, 3),
#  ('AFFAIR PREJUDICE', 41, 4),
#  ('AFFAIR PREJUDICE', 81, 4),
#  ('AFFAIR PREJUDICE', 88, 4),
#  ('AFFAIR PREJUDICE', 147, 4),
#  ('AFFAIR PREJUDICE', 162, 4),
#  ('AFRICAN EGG', 51, 5),
#  ('AFRICAN EGG', 59, 5),
#  ('AFRICAN EGG', 103, 5),
#  ('AFRICAN EGG', 181, 5),
#  ('AFRICAN EGG', 200, 5),
#  ('AGENT TRUMAN', 21, 6),
#  ('AGENT TRUMAN', 23, 6),
#  ('AGENT TRUMAN', 62, 6),
#  ('AGENT TRUMAN', 108, 6),
#  ('AGENT TRUMAN', 137, 6),
#  ('AGENT TRUMAN', 169, 6),
#  ('AGENT TRUMAN', 197, 6),
#  ('AIRPLANE SIERRA', 99, 7),
#  ('AIRPLANE SIERRA', 133, 7),
#  ('AIRPLANE SIERRA', 162, 7),
#  ('AIRPLANE SIERRA', 170, 7),
#  ('AIRPLANE SIERRA', 185, 7),
#  ('AIRPORT POLLOCK', 55, 8),
#  ('AIRPORT POLLOCK', 96, 8),
#  ('AIRPORT POLLOCK', 110, 8),
#  ('AIRPORT POLLOCK', 138, 8),
#  ('ALABAMA DEVIL', 10, 9),
#  ('ALABAMA DEVIL', 22, 9),
#  ('ALABAMA DEVIL', 26, 9),
#  ('ALABAMA DEVIL', 53, 9),
#  ('ALABAMA DEVIL', 68, 9),
#  ('ALABAMA DEVIL', 108, 9),
#  ('ALABAMA DEVIL', 130, 9),
#  ('ALABAMA DEVIL', 175, 9),
#  ('ALABAMA DEVIL', 194, 9),
#  ('ALADDIN CALENDAR', 29, 10),
#  ('ALADDIN CALENDAR', 35, 10),
#  ('ALADDIN CALENDAR', 37, 10),
#  ('ALADDIN CALENDAR', 64, 10),
#  ('ALADDIN CALENDAR', 117, 10),
#  ('ALADDIN CALENDAR', 142, 10),
#  ('ALADDIN CALENDAR', 157, 10),
#  ('ALADDIN CALENDAR', 188, 10),
#  ('ALAMO VIDEOTAPE', 40, 11),
#  ('ALAMO VIDEOTAPE', 81, 11),
#  ('ALAMO VIDEOTAPE', 90, 11),
#  ('ALAMO VIDEOTAPE', 174, 11),
#  ('ALASKA PHANTOM', 37, 12),
#  ('ALASKA PHANTOM', 75, 12),
#  ('ALASKA PHANTOM', 105, 12),
#  ('ALASKA PHANTOM', 109, 12),
#  ('ALASKA PHANTOM', 146, 12),
#  ('ALASKA PHANTOM', 177, 12),
#  ('ALASKA PHANTOM', 180, 12),
#  ('ALI FOREVER', 77, 13),
#  ('ALI FOREVER', 91, 13),
#  ('ALI FOREVER', 94, 13),
#  ('ALI FOREVER', 114, 13),
#  ('ALI FOREVER', 176, 13),
#  ('ALICE FANTASIA', 28, 14),
#  ('ALICE FANTASIA', 85, 14),
#  ('ALICE FANTASIA', 137, 14),
#  ('ALICE FANTASIA', 188, 14),
#  ('ALIEN CENTER', 36, 15),
#  ('ALIEN CENTER', 69, 15),
#  ('ALIEN CENTER', 105, 15),
#  ('ALIEN CENTER', 117, 15),
#  ('ALIEN CENTER', 164, 15),
#  ('ALIEN CENTER', 170, 15),
#  ('ALLEY EVOLUTION', 12, 16),
#  ('ALLEY EVOLUTION', 57, 16),
#  ('ALLEY EVOLUTION', 146, 16),
#  ('ALLEY EVOLUTION', 191, 16),
#  ('ALLEY EVOLUTION', 192, 16),
#  ('ALONE TRIP', 3, 17),
#  ('ALONE TRIP', 12, 17),
#  ('ALONE TRIP', 13, 17),
#  ('ALONE TRIP', 82, 17),
#  ('ALONE TRIP', 100, 17),
#  ('ALONE TRIP', 160, 17),
#  ('ALONE TRIP', 167, 17),
#  ('ALONE TRIP', 187, 17),
#  ('ALTER VICTORY', 45, 18),
#  ('ALTER VICTORY', 142, 18),
#  ('ALTER VICTORY', 144, 18),
#  ('ALTER VICTORY', 162, 18),
#  ('AMADEUS HOLY', 5, 19),
#  ('AMADEUS HOLY', 27, 19),
#  ('AMADEUS HOLY', 37, 19),
#  ('AMADEUS HOLY', 43, 19),
#  ('AMADEUS HOLY', 84, 19),
#  ('AMADEUS HOLY', 104, 19),
#  ('AMELIE HELLFIGHTERS', 52, 20),
#  ('AMELIE HELLFIGHTERS', 102, 20),
#  ('AMELIE HELLFIGHTERS', 136, 20),
#  ('AMELIE HELLFIGHTERS', 139, 20),
#  ('AMELIE HELLFIGHTERS', 155, 20),
#  ('AMELIE HELLFIGHTERS', 159, 20),
#  ('AMERICAN CIRCUS', 25, 21),
#  ('AMERICAN CIRCUS', 26, 21),
#  ('AMERICAN CIRCUS', 105, 21),
#  ('AMERICAN CIRCUS', 119, 21),
#  ('AMERICAN CIRCUS', 126, 21),
#  ('AMISTAD MIDSUMMER', 77, 22),
#  ('AMISTAD MIDSUMMER', 95, 22),
#  ('AMISTAD MIDSUMMER', 122, 22),
#  ('AMISTAD MIDSUMMER', 124, 22),
#  ('ANACONDA CONFESSIONS', 1, 23),
#  ('ANACONDA CONFESSIONS', 4, 23),
#  ('ANACONDA CONFESSIONS', 22, 23),
#  ('ANACONDA CONFESSIONS', 150, 23),
#  ('ANACONDA CONFESSIONS', 164, 23),
#  ('ANALYZE HOOSIERS', 38, 24),
#  ('ANALYZE HOOSIERS', 42, 24),
#  ('ANALYZE HOOSIERS', 67, 24),
#  ('ANALYZE HOOSIERS', 157, 24),
#  ('ANALYZE HOOSIERS', 179, 24),
#  ('ANGELS LIFE', 1, 25),
#  ('ANGELS LIFE', 4, 25),
#  ('ANGELS LIFE', 7, 25),
#  ('ANGELS LIFE', 47, 25),
#  ('ANGELS LIFE', 91, 25),
#  ('ANGELS LIFE', 136, 25),
#  ('ANGELS LIFE', 166, 25),
#  ('ANGELS LIFE', 167, 25),
#  ('ANGELS LIFE', 187, 25),
#  ('ANNIE IDENTITY', 71, 26),
#  ('ANNIE IDENTITY', 128, 26),
#  ('ANNIE IDENTITY', 130, 26),
#  ('ANONYMOUS HUMAN', 7, 27),
#  ('ANONYMOUS HUMAN', 55, 27),
#  ('ANONYMOUS HUMAN', 99, 27),
#  ('ANONYMOUS HUMAN', 110, 27),
#  ('ANONYMOUS HUMAN', 140, 27),
#  ('ANONYMOUS HUMAN', 148, 27),
#  ('ANONYMOUS HUMAN', 154, 27),
#  ('ANONYMOUS HUMAN', 170, 27),
#  ('ANONYMOUS HUMAN', 179, 27),
#  ('ANTHEM LUKE', 74, 28),
#  ('ANTHEM LUKE', 162, 28),
#  ('ANTITRUST TOMATOES', 6, 29),
#  ('ANTITRUST TOMATOES', 13, 29),
#  ('ANTITRUST TOMATOES', 105, 29),
#  ('ANTITRUST TOMATOES', 122, 29),
#  ('ANTITRUST TOMATOES', 175, 29),
#  ('ANTITRUST TOMATOES', 187, 29),
#  ('ANTITRUST TOMATOES', 197, 29),
#  ('ANYTHING SAVANNAH', 9, 30),
#  ('ANYTHING SAVANNAH', 163, 30),
#  ('ANYTHING SAVANNAH', 178, 30),
#  ('APACHE DIVINE', 2, 31),
#  ('APACHE DIVINE', 15, 31),
#  ('APACHE DIVINE', 49, 31),
#  ('APACHE DIVINE', 60, 31),
#  ('APOCALYPSE FLAMINGOS', 79, 32),
#  ('APOCALYPSE FLAMINGOS', 158, 32),
#  ('APOCALYPSE FLAMINGOS', 162, 32),
#  ('APOCALYPSE FLAMINGOS', 168, 32),
#  ('APOCALYPSE FLAMINGOS', 183, 32),
#  ('APOLLO TEEN', 79, 33),
#  ('APOLLO TEEN', 82, 33),
#  ('APOLLO TEEN', 136, 33),
#  ('APOLLO TEEN', 146, 33),
#  ('APOLLO TEEN', 162, 33),
#  ('APOLLO TEEN', 170, 33),
#  ('APOLLO TEEN', 180, 33),
#  ('APOLLO TEEN', 182, 33),
#  ('ARABIA DOGMA', 12, 34),
#  ('ARABIA DOGMA', 26, 34),
#  ('ARABIA DOGMA', 27, 34),
#  ('ARABIA DOGMA', 40, 34),
#  ('ARABIA DOGMA', 57, 34),
#  ('ARABIA DOGMA', 72, 34),
#  ('ARABIA DOGMA', 75, 34),
#  ('ARABIA DOGMA', 102, 34),
#  ('ARABIA DOGMA', 112, 34),
#  ('ARABIA DOGMA', 126, 34),
#  ('ARABIA DOGMA', 157, 34),
#  ('ARABIA DOGMA', 178, 34),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 7, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 35, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 95, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 113, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 118, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 135, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 139, 35),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 184, 35),
#  ('ARGONAUTS TOWN', 47, 36),
#  ('ARGONAUTS TOWN', 73, 36),
#  ('ARGONAUTS TOWN', 96, 36),
#  ('ARGONAUTS TOWN', 116, 36),
#  ('ARGONAUTS TOWN', 127, 36),
#  ('ARIZONA BANG', 12, 37),
#  ('ARIZONA BANG', 64, 37),
#  ('ARIZONA BANG', 112, 37),
#  ('ARIZONA BANG', 130, 37),
#  ('ARK RIDGEMONT', 46, 38),
#  ('ARK RIDGEMONT', 166, 38),
#  ('ARK RIDGEMONT', 190, 38),
#  ('ARMAGEDDON LOST', 65, 39),
#  ('ARMAGEDDON LOST', 84, 39),
#  ('ARMAGEDDON LOST', 104, 39),
#  ('ARMAGEDDON LOST', 118, 39),
#  ('ARMAGEDDON LOST', 145, 39),
#  ('ARMAGEDDON LOST', 177, 39),
#  ('ARMAGEDDON LOST', 191, 39),
#  ('ARMY FLINTSTONES', 3, 40),
#  ('ARMY FLINTSTONES', 77, 40),
#  ('ARMY FLINTSTONES', 79, 40),
#  ('ARMY FLINTSTONES', 96, 40),
#  ('ARMY FLINTSTONES', 104, 40),
#  ('ARMY FLINTSTONES', 181, 40),
#  ('ARMY FLINTSTONES', 183, 40),
#  ('ARSENIC INDEPENDENCE', 118, 41),
#  ('ARSENIC INDEPENDENCE', 135, 41),
#  ('ARSENIC INDEPENDENCE', 162, 41),
#  ('ARTIST COLDBLOODED', 3, 42),
#  ('ARTIST COLDBLOODED', 23, 42),
#  ('ARTIST COLDBLOODED', 43, 42),
#  ('ARTIST COLDBLOODED', 62, 42),
#  ('ARTIST COLDBLOODED', 105, 42),
#  ('ARTIST COLDBLOODED', 117, 42),
#  ('ARTIST COLDBLOODED', 194, 42),
#  ('ATLANTIS CAUSE', 28, 43),
#  ('ATLANTIS CAUSE', 34, 43),
#  ('ATLANTIS CAUSE', 123, 43),
#  ('ATLANTIS CAUSE', 126, 43),
#  ('ATLANTIS CAUSE', 130, 43),
#  ('ATLANTIS CAUSE', 141, 43),
#  ('ATLANTIS CAUSE', 160, 43),
#  ('ATLANTIS CAUSE', 161, 43),
#  ('ATLANTIS CAUSE', 189, 43),
#  ('ATTACKS HATE', 18, 44),
#  ('ATTACKS HATE', 74, 44),
#  ('ATTACKS HATE', 106, 44),
#  ('ATTACKS HATE', 193, 44),
#  ('ATTRACTION NEWTON', 13, 45),
#  ('ATTRACTION NEWTON', 68, 45),
#  ('ATTRACTION NEWTON', 73, 45),
#  ('ATTRACTION NEWTON', 163, 45),
#  ('AUTUMN CROW', 59, 46),
#  ('AUTUMN CROW', 65, 46),
#  ('AUTUMN CROW', 84, 46),
#  ('BABY HALL', 2, 47),
#  ('BABY HALL', 8, 47),
#  ('BABY HALL', 89, 47),
#  ('BABY HALL', 95, 47),
#  ('BABY HALL', 127, 47),
#  ('BABY HALL', 143, 47),
#  ('BABY HALL', 153, 47),
#  ('BABY HALL', 158, 47),
#  ('BACKLASH UNDEFEATED', 58, 48),
#  ('BACKLASH UNDEFEATED', 87, 48),
#  ('BACKLASH UNDEFEATED', 91, 48),
#  ('BACKLASH UNDEFEATED', 109, 48),
#  ('BACKLASH UNDEFEATED', 116, 48),
#  ('BACKLASH UNDEFEATED', 127, 48),
#  ('BACKLASH UNDEFEATED', 131, 48),
#  ('BADMAN DAWN', 83, 49),
#  ('BADMAN DAWN', 115, 49),
#  ('BADMAN DAWN', 118, 49),
#  ('BADMAN DAWN', 119, 49),
#  ('BADMAN DAWN', 130, 49),
#  ('BADMAN DAWN', 171, 49),
#  ('BADMAN DAWN', 173, 49),
#  ('BADMAN DAWN', 200, 49),
#  ('BAKED CLEOPATRA', 70, 50),
#  ('BALLOON HOMEWARD', 46, 51),
#  ('BALLOON HOMEWARD', 53, 51),
#  ('BALLOON HOMEWARD', 73, 51),
#  ('BALLOON HOMEWARD', 133, 51),
#  ('BALLOON HOMEWARD', 187, 51),
#  ('BALLOON HOMEWARD', 188, 51),
#  ('BALLROOM MOCKINGBIRD', 35, 52),
#  ('BALLROOM MOCKINGBIRD', 71, 52),
#  ('BALLROOM MOCKINGBIRD', 83, 52),
#  ('BALLROOM MOCKINGBIRD', 95, 52),
#  ('BALLROOM MOCKINGBIRD', 115, 52),
#  ('BALLROOM MOCKINGBIRD', 138, 52),
#  ('BALLROOM MOCKINGBIRD', 177, 52),
#  ('BANG KWAI', 6, 53),
#  ('BANG KWAI', 30, 53),
#  ('BANG KWAI', 47, 53),
#  ('BANG KWAI', 70, 53),
#  ('BANG KWAI', 102, 53),
#  ('BANG KWAI', 149, 53),
#  ('BANG KWAI', 156, 53),
#  ('BANGER PINOCCHIO', 5, 54),
#  ('BANGER PINOCCHIO', 20, 54),
#  ('BANGER PINOCCHIO', 59, 54),
#  ('BANGER PINOCCHIO', 62, 54),
#  ('BANGER PINOCCHIO', 96, 54),
#  ('BANGER PINOCCHIO', 190, 54),
#  ('BARBARELLA STREETCAR', 66, 55),
#  ('BARBARELLA STREETCAR', 118, 55),
#  ('BARBARELLA STREETCAR', 166, 55),
#  ('BARBARELLA STREETCAR', 173, 55),
#  ('BARBARELLA STREETCAR', 177, 55),
#  ('BAREFOOT MANCHURIAN', 4, 56),
#  ('BAREFOOT MANCHURIAN', 22, 56),
#  ('BAREFOOT MANCHURIAN', 33, 56),
#  ('BAREFOOT MANCHURIAN', 43, 56),
#  ('BAREFOOT MANCHURIAN', 129, 56),
#  ('BAREFOOT MANCHURIAN', 136, 56),
#  ('BAREFOOT MANCHURIAN', 137, 56),
#  ('BAREFOOT MANCHURIAN', 168, 56),
#  ('BASIC EASY', 67, 57),
#  ('BASIC EASY', 120, 57),
#  ('BASIC EASY', 130, 57),
#  ('BASIC EASY', 139, 57),
#  ('BASIC EASY', 148, 57),
#  ('BASIC EASY', 172, 57),
#  ('BEACH HEARTBREAKERS', 28, 58),
#  ('BEACH HEARTBREAKERS', 44, 58),
#  ('BEACH HEARTBREAKERS', 53, 58),
#  ('BEACH HEARTBREAKERS', 83, 58),
#  ('BEACH HEARTBREAKERS', 96, 58),
#  ('BEACH HEARTBREAKERS', 126, 58),
#  ('BEACH HEARTBREAKERS', 161, 58),
#  ('BEAR GRACELAND', 81, 59),
#  ('BEAR GRACELAND', 104, 59),
#  ('BEAR GRACELAND', 152, 59),
#  ('BEAST HUNCHBACK', 6, 60),
#  ('BEAST HUNCHBACK', 41, 60),
#  ('BEAST HUNCHBACK', 76, 60),
#  ('BEAST HUNCHBACK', 94, 60),
#  ('BEAST HUNCHBACK', 101, 60),
#  ('BEAUTY GREASE', 111, 61),
#  ('BEAUTY GREASE', 136, 61),
#  ('BEAUTY GREASE', 138, 61),
#  ('BEAUTY GREASE', 166, 61),
#  ('BEAUTY GREASE', 174, 61),
#  ('BED HIGHBALL', 4, 62),
#  ('BED HIGHBALL', 107, 62),
#  ('BED HIGHBALL', 110, 62),
#  ('BED HIGHBALL', 125, 62),
#  ('BED HIGHBALL', 190, 62),
#  ('BEDAZZLED MARRIED', 20, 63),
#  ('BEDAZZLED MARRIED', 51, 63),
#  ('BEDAZZLED MARRIED', 56, 63),
#  ('BEDAZZLED MARRIED', 120, 63),
#  ('BEDAZZLED MARRIED', 150, 63),
#  ('BEDAZZLED MARRIED', 167, 63),
#  ('BEDAZZLED MARRIED', 197, 63),
#  ('BEETHOVEN EXORCIST', 30, 64),
#  ('BEETHOVEN EXORCIST', 119, 64),
#  ('BEETHOVEN EXORCIST', 124, 64),
#  ('BEETHOVEN EXORCIST', 153, 64),
#  ('BEETHOVEN EXORCIST', 158, 64),
#  ('BEETHOVEN EXORCIST', 196, 64),
#  ('BEHAVIOR RUNAWAY', 32, 65),
#  ('BEHAVIOR RUNAWAY', 45, 65),
#  ('BEHAVIOR RUNAWAY', 95, 65),
#  ('BEHAVIOR RUNAWAY', 135, 65),
#  ('BEHAVIOR RUNAWAY', 179, 65),
#  ('BENEATH RUSH', 45, 66),
#  ('BENEATH RUSH', 76, 66),
#  ('BENEATH RUSH', 96, 66),
#  ('BENEATH RUSH', 98, 66),
#  ('BENEATH RUSH', 101, 66),
#  ('BENEATH RUSH', 131, 66),
#  ('BENEATH RUSH', 158, 66),
#  ('BERETS AGENT', 7, 67),
#  ('BERETS AGENT', 47, 67),
#  ('BERETS AGENT', 67, 67),
#  ('BERETS AGENT', 123, 67),
#  ('BERETS AGENT', 141, 67),
#  ('BERETS AGENT', 144, 67),
#  ('BERETS AGENT', 155, 67),
#  ('BERETS AGENT', 175, 67),
#  ('BERETS AGENT', 194, 67),
#  ('BERETS AGENT', 199, 67),
#  ('BETRAYED REAR', 58, 68),
#  ('BETRAYED REAR', 76, 68),
#  ('BETRAYED REAR', 114, 68),
#  ('BETRAYED REAR', 166, 68),
#  ('BEVERLY OUTLAW', 30, 69),
#  ('BEVERLY OUTLAW', 41, 69),
#  ('BEVERLY OUTLAW', 80, 69),
#  ('BEVERLY OUTLAW', 192, 69),
#  ('BIKINI BORROWERS', 6, 70),
#  ('BIKINI BORROWERS', 104, 70),
#  ('BILKO ANONYMOUS', 39, 71),
#  ('BILKO ANONYMOUS', 93, 71),
#  ('BILKO ANONYMOUS', 183, 71),
#  ('BILL OTHERS', 59, 72),
#  ('BILL OTHERS', 85, 72),
#  ('BILL OTHERS', 98, 72),
#  ('BILL OTHERS', 149, 72),
#  ('BILL OTHERS', 165, 72),
#  ('BILL OTHERS', 167, 72),
#  ('BINGO TALENTED', 39, 73),
#  ('BINGO TALENTED', 63, 73),
#  ('BINGO TALENTED', 77, 73),
#  ('BINGO TALENTED', 176, 73),
#  ('BINGO TALENTED', 187, 73),
#  ('BIRCH ANTITRUST', 9, 74),
#  ('BIRCH ANTITRUST', 28, 74),
#  ('BIRCH ANTITRUST', 95, 74),
#  ('BIRCH ANTITRUST', 139, 74),
#  ('BIRCH ANTITRUST', 173, 74),
#  ('BIRCH ANTITRUST', 181, 74),
#  ('BIRD INDEPENDENCE', 55, 75),
#  ('BIRD INDEPENDENCE', 150, 75),
#  ('BIRDCAGE CASPER', 88, 76),
#  ('BIRDCAGE CASPER', 94, 76),
#  ('BIRDCAGE CASPER', 122, 76),
#  ('BIRDCAGE CASPER', 187, 76),
#  ('BIRDS PERDITION', 30, 77),
#  ('BIRDS PERDITION', 73, 77),
#  ('BIRDS PERDITION', 109, 77),
#  ('BIRDS PERDITION', 140, 77),
#  ('BLACKOUT PRIVATE', 23, 78),
#  ('BLACKOUT PRIVATE', 77, 78),
#  ('BLACKOUT PRIVATE', 111, 78),
#  ('BLACKOUT PRIVATE', 169, 78),
#  ('BLACKOUT PRIVATE', 181, 78),
#  ('BLADE POLISH', 4, 79),
#  ('BLADE POLISH', 29, 79),
#  ('BLADE POLISH', 127, 79),
#  ('BLADE POLISH', 143, 79),
#  ('BLADE POLISH', 144, 79),
#  ('BLANKET BEVERLY', 16, 80),
#  ('BLANKET BEVERLY', 173, 80),
#  ('BLANKET BEVERLY', 193, 80),
#  ('BLANKET BEVERLY', 200, 80),
#  ('BLINDNESS GUN', 36, 81),
#  ('BLINDNESS GUN', 98, 81),
#  ('BLINDNESS GUN', 132, 81),
#  ('BLOOD ARGONAUTS', 128, 82),
#  ('BLOOD ARGONAUTS', 132, 82),
#  ('BLOOD ARGONAUTS', 159, 82),
#  ('BLOOD ARGONAUTS', 189, 82),
#  ('BLUES INSTINCT', 24, 83),
#  ('BLUES INSTINCT', 106, 83),
#  ('BLUES INSTINCT', 122, 83),
#  ('BLUES INSTINCT', 181, 83),
#  ('BOILED DARES', 18, 84),
#  ('BOILED DARES', 32, 84),
#  ('BOILED DARES', 44, 84),
#  ('BOILED DARES', 54, 84),
#  ('BOILED DARES', 99, 84),
#  ('BOILED DARES', 113, 84),
#  ('BOILED DARES', 191, 84),
#  ('BOILED DARES', 199, 84),
#  ('BONNIE HOLOCAUST', 5, 85),
#  ('BONNIE HOLOCAUST', 27, 85),
#  ('BONNIE HOLOCAUST', 60, 85),
#  ('BONNIE HOLOCAUST', 85, 85),
#  ('BONNIE HOLOCAUST', 101, 85),
#  ('BONNIE HOLOCAUST', 126, 85),
#  ('BONNIE HOLOCAUST', 147, 85),
#  ('BONNIE HOLOCAUST', 162, 85),
#  ('BONNIE HOLOCAUST', 179, 85),
#  ('BOOGIE AMELIE', 25, 86),
#  ('BOOGIE AMELIE', 41, 86),
#  ('BOOGIE AMELIE', 78, 86),
#  ('BOOGIE AMELIE', 166, 86),
#  ('BOOGIE AMELIE', 177, 86),
#  ('BOOGIE AMELIE', 194, 86),
#  ('BOONDOCK BALLROOM', 3, 87),
#  ('BOONDOCK BALLROOM', 4, 87),
#  ('BOONDOCK BALLROOM', 13, 87),
#  ('BOONDOCK BALLROOM', 16, 87),
#  ('BOONDOCK BALLROOM', 21, 87),
#  ('BOONDOCK BALLROOM', 30, 87),
#  ('BOONDOCK BALLROOM', 56, 87),
#  ('BOONDOCK BALLROOM', 64, 87),
#  ('BOONDOCK BALLROOM', 88, 87),
#  ('BOONDOCK BALLROOM', 98, 87),
#  ('BOONDOCK BALLROOM', 119, 87),
#  ('BOONDOCK BALLROOM', 184, 87),
#  ('BOONDOCK BALLROOM', 190, 87),
#  ('BORN SPINAL', 21, 88),
#  ('BORN SPINAL', 31, 88),
#  ('BORN SPINAL', 44, 88),
#  ('BORN SPINAL', 59, 88),
#  ('BORN SPINAL', 64, 88),
#  ('BORN SPINAL', 69, 88),
#  ('BORN SPINAL', 116, 88),
#  ('BORN SPINAL', 135, 88),
#  ('BORN SPINAL', 194, 88),
#  ('BORROWERS BEDAZZLED', 15, 89),
#  ('BORROWERS BEDAZZLED', 22, 89),
#  ('BORROWERS BEDAZZLED', 43, 89),
#  ('BORROWERS BEDAZZLED', 81, 89),
#  ('BORROWERS BEDAZZLED', 129, 89),
#  ('BORROWERS BEDAZZLED', 161, 89),
#  ('BORROWERS BEDAZZLED', 176, 89),
#  ('BOULEVARD MOB', 26, 90),
#  ('BOULEVARD MOB', 34, 90),
#  ('BOULEVARD MOB', 92, 90),
#  ('BOULEVARD MOB', 114, 90),
#  ('BOULEVARD MOB', 116, 90),
#  ('BOULEVARD MOB', 139, 90),
#  ('BOULEVARD MOB', 144, 90),
#  ('BOULEVARD MOB', 161, 90),
#  ('BOUND CHEAPER', 12, 91),
#  ('BOUND CHEAPER', 15, 91),
#  ('BOWFINGER GABLES', 12, 92),
#  ('BOWFINGER GABLES', 52, 92),
#  ('BOWFINGER GABLES', 70, 92),
#  ('BOWFINGER GABLES', 85, 92),
#  ('BOWFINGER GABLES', 168, 92),
#  ('BRANNIGAN SUNRISE', 26, 93),
#  ('BRANNIGAN SUNRISE', 169, 93),
#  ('BRAVEHEART HUMAN', 44, 94),
#  ('BRAVEHEART HUMAN', 92, 94),
#  ('BRAVEHEART HUMAN', 131, 94),
#  ('BRAVEHEART HUMAN', 150, 94),
#  ('BREAKFAST GOLDFINGER', 76, 95),
#  ('BREAKFAST GOLDFINGER', 149, 95),
#  ('BREAKFAST GOLDFINGER', 165, 95),
#  ('BREAKFAST GOLDFINGER', 185, 95),
#  ('BREAKFAST GOLDFINGER', 186, 95),
#  ('BREAKING HOME', 7, 96),
#  ('BREAKING HOME', 17, 96),
#  ('BREAKING HOME', 28, 96),
#  ('BREAKING HOME', 52, 96),
#  ('BREAKING HOME', 126, 96),
#  ('BREAKING HOME', 137, 96),
#  ('BRIDE INTRIGUE', 65, 97),
#  ('BRIGHT ENCOUNTERS', 111, 98),
#  ('BRIGHT ENCOUNTERS', 125, 98),
#  ('BRIGHT ENCOUNTERS', 187, 98),
#  ('BRIGHT ENCOUNTERS', 194, 98),
#  ('BRINGING HYSTERICAL', 48, 99),
#  ('BRINGING HYSTERICAL', 144, 99),
#  ('BROOKLYN DESERT', 41, 100),
#  ('BROOKLYN DESERT', 62, 100),
#  ('BROOKLYN DESERT', 90, 100),
#  ('BROOKLYN DESERT', 125, 100),
#  ('BROOKLYN DESERT', 172, 100),
#  ('BROTHERHOOD BLANKET', 16, 101),
#  ('BROTHERHOOD BLANKET', 48, 101),
#  ('BROTHERHOOD BLANKET', 57, 101),
#  ('BROTHERHOOD BLANKET', 62, 101),
#  ('BROTHERHOOD BLANKET', 129, 101),
#  ('BUBBLE GROSSE', 158, 102),
#  ('BUBBLE GROSSE', 170, 102),
#  ('BUBBLE GROSSE', 188, 102),
#  ('BUCKET BROTHERHOOD', 26, 103),
#  ('BUCKET BROTHERHOOD', 32, 103),
#  ('BUCKET BROTHERHOOD', 51, 103),
#  ('BUCKET BROTHERHOOD', 89, 103),
#  ('BUCKET BROTHERHOOD', 92, 103),
#  ('BUCKET BROTHERHOOD', 193, 103),
#  ('BUGSY SONG', 82, 104),
#  ('BUGSY SONG', 92, 104),
#  ('BULL SHAWSHANK', 2, 105),
#  ('BULL SHAWSHANK', 23, 105),
#  ('BULL SHAWSHANK', 29, 105),
#  ('BULL SHAWSHANK', 43, 105),
#  ('BULL SHAWSHANK', 116, 105),
#  ('BULL SHAWSHANK', 123, 105),
#  ('BULL SHAWSHANK', 144, 105),
#  ('BULL SHAWSHANK', 150, 105),
#  ('BULWORTH COMMANDMENTS', 1, 106),
#  ('BULWORTH COMMANDMENTS', 65, 106),
#  ('BULWORTH COMMANDMENTS', 124, 106),
#  ('BULWORTH COMMANDMENTS', 173, 106),
#  ('BUNCH MINDS', 12, 107),
#  ('BUNCH MINDS', 28, 107),
#  ('BUNCH MINDS', 40, 107),
#  ('BUNCH MINDS', 98, 107),
#  ('BUNCH MINDS', 130, 107),
#  ('BUNCH MINDS', 139, 107),
#  ('BUNCH MINDS', 142, 107),
#  ('BUNCH MINDS', 167, 107),
#  ('BUTCH PANTHER', 15, 108),
#  ('BUTCH PANTHER', 52, 108),
#  ('BUTCH PANTHER', 106, 108),
#  ('BUTTERFLY CHOCOLAT', 44, 109),
#  ('BUTTERFLY CHOCOLAT', 53, 109),
#  ('BUTTERFLY CHOCOLAT', 145, 109),
#  ('BUTTERFLY CHOCOLAT', 178, 109),
#  ('BUTTERFLY CHOCOLAT', 179, 109),
#  ('BUTTERFLY CHOCOLAT', 193, 109),
#  ('BUTTERFLY CHOCOLAT', 198, 109),
#  ('CABIN FLASH', 13, 110),
#  ('CABIN FLASH', 29, 110),
#  ('CABIN FLASH', 83, 110),
#  ('CABIN FLASH', 187, 110),
#  ('CADDYSHACK JEDI', 3, 111),
#  ('CADDYSHACK JEDI', 22, 111),
#  ('CADDYSHACK JEDI', 38, 111),
#  ('CADDYSHACK JEDI', 50, 111),
#  ('CADDYSHACK JEDI', 69, 111),
#  ('CADDYSHACK JEDI', 154, 111),
#  ('CADDYSHACK JEDI', 188, 111),
#  ('CALENDAR GUNFIGHT', 6, 112),
#  ('CALENDAR GUNFIGHT', 24, 112),
#  ('CALENDAR GUNFIGHT', 32, 112),
#  ('CALENDAR GUNFIGHT', 33, 112),
#  ('CALENDAR GUNFIGHT', 51, 112),
#  ('CALENDAR GUNFIGHT', 107, 112),
#  ('CALENDAR GUNFIGHT', 130, 112),
#  ('CALENDAR GUNFIGHT', 140, 112),
#  ('CALIFORNIA BIRDS', 124, 113),
#  ('CALIFORNIA BIRDS', 183, 113),
#  ('CAMELOT VACATION', 57, 114),
#  ('CAMELOT VACATION', 125, 114),
#  ('CAMPUS REMEMBER', 8, 115),
#  ('CAMPUS REMEMBER', 45, 115),
#  ('CAMPUS REMEMBER', 168, 115),
#  ('CANDIDATE PERDITION', 23, 116),
#  ('CANDIDATE PERDITION', 105, 116),
#  ('CANDIDATE PERDITION', 113, 116),
#  ('CANDIDATE PERDITION', 200, 116),
#  ('CANDLES GRAPES', 23, 117),
#  ('CANDLES GRAPES', 45, 117),
#  ('CANDLES GRAPES', 65, 117),
#  ('CANDLES GRAPES', 74, 117),
#  ('CANDLES GRAPES', 89, 117),
#  ('CANDLES GRAPES', 146, 117),
#  ('CANDLES GRAPES', 192, 117),
#  ('CANYON STOCK', 11, 118),
#  ('CANYON STOCK', 37, 118),
#  ('CANYON STOCK', 80, 118),
#  ('CANYON STOCK', 100, 118),
#  ('CANYON STOCK', 103, 118),
#  ('CANYON STOCK', 149, 118),
#  ('CAPER MOTIONS', 17, 119),
#  ('CAPER MOTIONS', 34, 119),
#  ('CAPER MOTIONS', 37, 119),
#  ('CAPER MOTIONS', 58, 119),
#  ('CAPER MOTIONS', 127, 119),
#  ('CAPER MOTIONS', 128, 119),
#  ('CAPER MOTIONS', 193, 119),
#  ('CARIBBEAN LIBERTY', 83, 120),
#  ('CARIBBEAN LIBERTY', 93, 120),
#  ('CARIBBEAN LIBERTY', 98, 120),
#  ('CARIBBEAN LIBERTY', 110, 120),
#  ('CARIBBEAN LIBERTY', 131, 120),
#  ('CARIBBEAN LIBERTY', 145, 120),
#  ('CARIBBEAN LIBERTY', 161, 120),
#  ('CARIBBEAN LIBERTY', 167, 120),
#  ('CAROL TEXAS', 16, 121),
#  ('CAROL TEXAS', 51, 121),
#  ('CAROL TEXAS', 59, 121),
#  ('CAROL TEXAS', 83, 121),
#  ('CAROL TEXAS', 158, 121),
#  ('CAROL TEXAS', 162, 121),
#  ('CAROL TEXAS', 200, 121),
#  ('CARRIE BUNCH', 37, 122),
#  ('CARRIE BUNCH', 53, 122),
#  ('CARRIE BUNCH', 57, 122),
#  ('CARRIE BUNCH', 76, 122),
#  ('CARRIE BUNCH', 94, 122),
#  ('CARRIE BUNCH', 157, 122),
#  ('CARRIE BUNCH', 196, 122),
#  ('CASABLANCA SUPER', 92, 123),
#  ('CASABLANCA SUPER', 102, 123),
#  ('CASABLANCA SUPER', 144, 123),
#  ('CASABLANCA SUPER', 197, 123),
#  ('CASPER DRAGONFLY', 17, 124),
#  ('CASPER DRAGONFLY', 64, 124),
#  ('CASPER DRAGONFLY', 80, 124),
#  ('CASPER DRAGONFLY', 93, 124),
#  ('CASPER DRAGONFLY', 102, 124),
#  ('CASSIDY WYOMING', 15, 125),
#  ('CASSIDY WYOMING', 23, 125),
#  ('CASSIDY WYOMING', 34, 125),
#  ('CASSIDY WYOMING', 65, 125),
#  ('CASSIDY WYOMING', 138, 125),
#  ('CASSIDY WYOMING', 144, 125),
#  ('CASSIDY WYOMING', 198, 125),
#  ('CASUALTIES ENCINO', 24, 126),
#  ('CASUALTIES ENCINO', 53, 126),
#  ('CASUALTIES ENCINO', 95, 126),
#  ('CASUALTIES ENCINO', 106, 126),
#  ('CASUALTIES ENCINO', 110, 126),
#  ('CAT CONEHEADS', 17, 127),
#  ('CAT CONEHEADS', 144, 127),
#  ('CAT CONEHEADS', 159, 127),
#  ('CAT CONEHEADS', 187, 127),
#  ('CATCH AMISTAD', 40, 128),
#  ('CATCH AMISTAD', 58, 128),
#  ('CATCH AMISTAD', 88, 128),
#  ('CATCH AMISTAD', 116, 128),
#  ('CATCH AMISTAD', 155, 128),
#  ('CAUSE DATE', 54, 129),
#  ('CAUSE DATE', 59, 129),
#  ('CAUSE DATE', 62, 129),
#  ('CAUSE DATE', 175, 129),
#  ('CAUSE DATE', 195, 129),
#  ('CAUSE DATE', 197, 129),
#  ('CELEBRITY HORN', 59, 130),
#  ('CELEBRITY HORN', 103, 130),
#  ('CELEBRITY HORN', 144, 130),
#  ('CELEBRITY HORN', 195, 130),
#  ('CENTER DINOSAUR', 29, 131),
#  ('CENTER DINOSAUR', 147, 131),
#  ('CENTER DINOSAUR', 151, 131),
#  ('CENTER DINOSAUR', 179, 131),
#  ('CHAINSAW UPTOWN', 2, 132),
#  ('CHAINSAW UPTOWN', 134, 132),
#  ('CHAMBER ITALIAN', 29, 133),
#  ('CHAMBER ITALIAN', 60, 133),
#  ('CHAMBER ITALIAN', 68, 133),
#  ('CHAMBER ITALIAN', 107, 133),
#  ('CHAMBER ITALIAN', 132, 133),
#  ('CHAMBER ITALIAN', 133, 133),
#  ('CHAMBER ITALIAN', 148, 133),
#  ('CHAMPION FLATLINERS', 48, 134),
#  ('CHAMPION FLATLINERS', 57, 134),
#  ('CHAMPION FLATLINERS', 63, 134),
#  ('CHAMPION FLATLINERS', 96, 134),
#  ('CHANCE RESURRECTION', 33, 135),
#  ('CHANCE RESURRECTION', 58, 135),
#  ('CHANCE RESURRECTION', 83, 135),
#  ('CHANCE RESURRECTION', 140, 135),
#  ('CHANCE RESURRECTION', 144, 135),
#  ('CHANCE RESURRECTION', 194, 135),
#  ('CHAPLIN LICENSE', 32, 136),
#  ('CHAPLIN LICENSE', 104, 136),
#  ('CHAPLIN LICENSE', 106, 136),
#  ('CHAPLIN LICENSE', 107, 136),
#  ('CHAPLIN LICENSE', 118, 136),
#  ('CHAPLIN LICENSE', 153, 136),
#  ('CHARADE DUFFEL', 86, 137),
#  ('CHARADE DUFFEL', 92, 137),
#  ('CHARADE DUFFEL', 108, 137),
#  ('CHARIOTS CONSPIRACY', 107, 138),
#  ('CHARIOTS CONSPIRACY', 185, 138),
#  ('CHASING FIGHT', 42, 139),
#  ('CHASING FIGHT', 142, 139),
#  ('CHASING FIGHT', 147, 139),
#  ('CHASING FIGHT', 149, 139),
#  ('CHASING FIGHT', 170, 139),
#  ('CHEAPER CLYDE', 1, 140),
#  ('CHEAPER CLYDE', 20, 140),
#  ('CHICAGO NORTH', 79, 141),
#  ('CHICAGO NORTH', 118, 141),
#  ('CHICAGO NORTH', 121, 141),
#  ('CHICAGO NORTH', 127, 141),
#  ('CHICAGO NORTH', 143, 141),
#  ('CHICAGO NORTH', 154, 141),
#  ('CHICAGO NORTH', 193, 141),
#  ('CHICAGO NORTH', 195, 141),
#  ('CHICKEN HELLFIGHTERS', 21, 142),
#  ('CHICKEN HELLFIGHTERS', 60, 142),
#  ('CHILL LUCK', 66, 143),
#  ('CHILL LUCK', 75, 143),
#  ('CHILL LUCK', 82, 143),
#  ('CHILL LUCK', 97, 143),
#  ('CHILL LUCK', 119, 143),
#  ('CHINATOWN GLADIATOR', 13, 144),
#  ('CHINATOWN GLADIATOR', 18, 144),
#  ('CHINATOWN GLADIATOR', 19, 144),
#  ('CHINATOWN GLADIATOR', 57, 144),
#  ('CHINATOWN GLADIATOR', 67, 144),
#  ('CHINATOWN GLADIATOR', 72, 144),
#  ('CHINATOWN GLADIATOR', 120, 144),
#  ('CHINATOWN GLADIATOR', 151, 144),
#  ('CHINATOWN GLADIATOR', 180, 144),
#  ('CHINATOWN GLADIATOR', 195, 144),
#  ('CHISUM BEHAVIOR', 2, 145),
#  ('CHISUM BEHAVIOR', 134, 145),
#  ('CHISUM BEHAVIOR', 147, 145),
#  ('CHISUM BEHAVIOR', 199, 145),
#  ('CHITTY LOCK', 5, 146),
#  ('CHITTY LOCK', 20, 146),
#  ('CHITTY LOCK', 22, 146),
#  ('CHITTY LOCK', 31, 146),
#  ('CHITTY LOCK', 37, 146),
#  ('CHITTY LOCK', 101, 146),
#  ('CHITTY LOCK', 149, 146),
#  ('CHITTY LOCK', 165, 146),
#  ('CHITTY LOCK', 166, 146),
#  ('CHITTY LOCK', 171, 146),
#  ('CHITTY LOCK', 178, 146),
#  ('CHITTY LOCK', 184, 146),
#  ('CHITTY LOCK', 188, 146),
#  ('CHOCOLAT HARRY', 9, 147),
#  ('CHOCOLAT HARRY', 26, 147),
#  ('CHOCOLAT HARRY', 43, 147),
#  ('CHOCOLAT HARRY', 131, 147),
#  ('CHOCOLAT HARRY', 197, 147),
#  ('CHOCOLATE DUCK', 9, 148),
#  ('CHOCOLATE DUCK', 24, 148),
#  ('CHOCOLATE DUCK', 73, 148),
#  ('CHOCOLATE DUCK', 85, 148),
#  ('CHOCOLATE DUCK', 123, 148),
#  ('CHOCOLATE DUCK', 164, 148),
#  ('CHOCOLATE DUCK', 172, 148),
#  ('CHRISTMAS MOONSHINE', 120, 149),
#  ('CHRISTMAS MOONSHINE', 148, 149),
#  ('CHRISTMAS MOONSHINE', 200, 149),
#  ('CIDER DESIRE', 27, 150),
#  ('CIDER DESIRE', 41, 150),
#  ('CIDER DESIRE', 48, 150),
#  ('CIDER DESIRE', 54, 150),
#  ('CIDER DESIRE', 176, 150),
#  ('CINCINATTI WHISPERER', 49, 151),
#  ('CINCINATTI WHISPERER', 112, 151),
#  ('CINCINATTI WHISPERER', 118, 151),
#  ('CINCINATTI WHISPERER', 123, 151),
#  ('CIRCUS YOUTH', 19, 152),
#  ('CIRCUS YOUTH', 181, 152),
#  ('CITIZEN SHREK', 25, 153),
#  ('CITIZEN SHREK', 51, 153),
#  ('CITIZEN SHREK', 57, 153),
#  ('CITIZEN SHREK', 77, 153),
#  ('CITIZEN SHREK', 94, 153),
#  ('CITIZEN SHREK', 149, 153),
#  ('CITIZEN SHREK', 152, 153),
#  ('CITIZEN SHREK', 155, 153),
#  ('CLASH FREDDY', 13, 154),
#  ('CLASH FREDDY', 14, 154),
#  ('CLASH FREDDY', 17, 154),
#  ('CLASH FREDDY', 33, 154),
#  ('CLASH FREDDY', 121, 154),
#  ('CLASH FREDDY', 145, 154),
#  ('CLASH FREDDY', 173, 154),
#  ('CLEOPATRA DEVIL', 12, 155),
#  ('CLEOPATRA DEVIL', 16, 155),
#  ('CLEOPATRA DEVIL', 139, 155),
#  ('CLEOPATRA DEVIL', 145, 155),
#  ('CLEOPATRA DEVIL', 156, 155),
#  ('CLEOPATRA DEVIL', 175, 155),
#  ('CLEOPATRA DEVIL', 192, 155),
#  ('CLERKS ANGELS', 104, 156),
#  ('CLERKS ANGELS', 110, 156),
#  ('CLERKS ANGELS', 132, 156),
#  ('CLERKS ANGELS', 196, 156),
#  ('CLOCKWORK PARADISE', 87, 157),
#  ('CLOCKWORK PARADISE', 109, 157),
#  ('CLOCKWORK PARADISE', 122, 157),
#  ('CLOCKWORK PARADISE', 127, 157),
#  ('CLOCKWORK PARADISE', 138, 157),
#  ('CLONES PINOCCHIO', 8, 158),
#  ('CLONES PINOCCHIO', 65, 158),
#  ('CLONES PINOCCHIO', 105, 158),
#  ('CLONES PINOCCHIO', 122, 158),
#  ('CLONES PINOCCHIO', 154, 158),
#  ('CLOSER BANG', 21, 159),
#  ('CLOSER BANG', 41, 159),
#  ('CLOSER BANG', 149, 159),
#  ('CLOSER BANG', 157, 159),
#  ('CLOSER BANG', 179, 159),
#  ('CLOSER BANG', 199, 159),
#  ('CLUB GRAFFITI', 38, 160),
#  ('CLUB GRAFFITI', 137, 160),
#  ('CLUB GRAFFITI', 178, 160),
#  ('CLUB GRAFFITI', 182, 160),
#  ('CLUE GRAIL', 43, 161),
#  ('CLUE GRAIL', 68, 161),
#  ('CLUE GRAIL', 87, 161),
#  ('CLUE GRAIL', 121, 161),
#  ('CLUE GRAIL', 134, 161),
#  ('CLUE GRAIL', 194, 161),
#  ('CLUELESS BUCKET', 13, 162),
#  ('CLUELESS BUCKET', 89, 162),
#  ('CLUELESS BUCKET', 107, 162),
#  ('CLUELESS BUCKET', 111, 162),
#  ('CLUELESS BUCKET', 114, 162),
#  ('CLUELESS BUCKET', 132, 162),
#  ('CLUELESS BUCKET', 173, 162),
#  ('CLUELESS BUCKET', 176, 162),
#  ('CLYDE THEORY', 31, 163),
#  ('CLYDE THEORY', 40, 163),
#  ('CLYDE THEORY', 86, 163),
#  ('CLYDE THEORY', 194, 163),
#  ('COAST RAINBOW', 6, 164),
#  ('COAST RAINBOW', 24, 164),
#  ('COAST RAINBOW', 31, 164),
#  ('COAST RAINBOW', 45, 164),
#  ('COAST RAINBOW', 48, 164),
#  ('COAST RAINBOW', 144, 164),
#  ('COAST RAINBOW', 162, 164),
#  ('COAST RAINBOW', 178, 164),
#  ('COAST RAINBOW', 193, 164),
#  ('COAST RAINBOW', 197, 164),
#  ('COLDBLOODED DARLING', 6, 165),
#  ('COLDBLOODED DARLING', 20, 165),
#  ('COLDBLOODED DARLING', 83, 165),
#  ('COLDBLOODED DARLING', 107, 165),
#  ('COLOR PHILADELPHIA', 1, 166),
#  ('COLOR PHILADELPHIA', 106, 166),
#  ('COLOR PHILADELPHIA', 122, 166),
#  ('COLOR PHILADELPHIA', 129, 166),
#  ('COLOR PHILADELPHIA', 163, 166),
#  ('COLOR PHILADELPHIA', 171, 166),
#  ('COLOR PHILADELPHIA', 192, 166),
#  ('COMA HEAD', 63, 167),
#  ('COMA HEAD', 117, 167),
#  ('COMA HEAD', 151, 167),
#  ('COMANCHEROS ENEMY', 39, 168),
#  ('COMANCHEROS ENEMY', 128, 168),
#  ('COMANCHEROS ENEMY', 150, 168),
#  ('COMANCHEROS ENEMY', 174, 168),
#  ('COMANCHEROS ENEMY', 187, 168),
#  ('COMFORTS RUSH', 149, 169),
#  ('COMFORTS RUSH', 154, 169),
#  ('COMFORTS RUSH', 164, 169),
#  ('COMFORTS RUSH', 184, 169),
#  ('COMFORTS RUSH', 196, 169),
#  ('COMMAND DARLING', 7, 170),
#  ('COMMAND DARLING', 75, 170),
#  ('COMMAND DARLING', 88, 170),
#  ('COMMAND DARLING', 121, 170),
#  ('COMMAND DARLING', 135, 170),
#  ('COMMAND DARLING', 139, 170),
#  ('COMMAND DARLING', 151, 170),
#  ('COMMAND DARLING', 154, 170),
#  ('COMMANDMENTS EXPRESS', 5, 171),
#  ('COMMANDMENTS EXPRESS', 36, 171),
#  ('COMMANDMENTS EXPRESS', 119, 171),
#  ('COMMANDMENTS EXPRESS', 189, 171),
#  ('CONEHEADS SMOOCHY', 5, 172),
#  ('CONEHEADS SMOOCHY', 18, 172),
#  ('CONEHEADS SMOOCHY', 27, 172),
#  ('CONEHEADS SMOOCHY', 29, 172),
#  ('CONEHEADS SMOOCHY', 34, 172),
#  ('CONEHEADS SMOOCHY', 47, 172),
#  ('CONEHEADS SMOOCHY', 107, 172),
#  ('CONEHEADS SMOOCHY', 119, 172),
#  ('CONEHEADS SMOOCHY', 133, 172),
#  ('CONFESSIONS MAGUIRE', 7, 173),
#  ('CONFESSIONS MAGUIRE', 112, 173),
#  ('CONFESSIONS MAGUIRE', 119, 173),
#  ('CONFESSIONS MAGUIRE', 190, 173),
#  ('CONFIDENTIAL INTERVIEW', 46, 174),
#  ('CONFIDENTIAL INTERVIEW', 109, 174),
#  ('CONFUSED CANDLES', 58, 175),
#  ('CONFUSED CANDLES', 80, 175),
#  ('CONFUSED CANDLES', 84, 175),
#  ('CONFUSED CANDLES', 125, 175),
#  ('CONFUSED CANDLES', 143, 175),
#  ('CONFUSED CANDLES', 177, 175),
#  ('CONGENIALITY QUEST', 38, 176),
#  ('CONGENIALITY QUEST', 44, 176),
#  ('CONGENIALITY QUEST', 91, 176),
#  ('CONNECTICUT TRAMP', 12, 177),
#  ('CONNECTICUT TRAMP', 16, 177),
#  ('CONNECTICUT TRAMP', 40, 177),
#  ('CONNECTICUT TRAMP', 60, 177),
#  ('CONNECTICUT TRAMP', 97, 177),
#  ('CONNECTICUT TRAMP', 146, 177),
#  ('CONNECTICUT TRAMP', 158, 177),
#  ('CONNECTION MICROCOSMOS', 24, 178),
#  ('CONNECTION MICROCOSMOS', 50, 178),
#  ('CONNECTION MICROCOSMOS', 81, 178),
#  ('CONNECTION MICROCOSMOS', 117, 178),
#  ('CONNECTION MICROCOSMOS', 147, 178),
#  ('CONNECTION MICROCOSMOS', 149, 178),
#  ('CONNECTION MICROCOSMOS', 158, 178),
#  ('CONQUERER NUTS', 8, 179),
#  ('CONQUERER NUTS', 21, 179),
#  ('CONQUERER NUTS', 25, 179),
#  ('CONQUERER NUTS', 60, 179),
#  ('CONQUERER NUTS', 111, 179),
#  ('CONQUERER NUTS', 192, 179),
#  ('CONSPIRACY SPIRIT', 43, 180),
#  ('CONSPIRACY SPIRIT', 153, 180),
#  ('CONSPIRACY SPIRIT', 163, 180),
#  ('CONSPIRACY SPIRIT', 170, 180),
#  ('CONTACT ANONYMOUS', 53, 181),
#  ('CONTACT ANONYMOUS', 91, 181),
#  ('CONTACT ANONYMOUS', 113, 181),
#  ('CONTACT ANONYMOUS', 139, 181),
#  ('CONTACT ANONYMOUS', 171, 181),
#  ('CONTROL ANTHEM', 19, 182),
#  ('CONTROL ANTHEM', 34, 182),
#  ('CONTROL ANTHEM', 89, 182),
#  ('CONVERSATION DOWNHILL', 59, 183),
#  ('CONVERSATION DOWNHILL', 98, 183),
#  ('CONVERSATION DOWNHILL', 157, 183),
#  ('CORE SUIT', 54, 184),
#  ('CORE SUIT', 104, 184),
#  ('CORE SUIT', 144, 184),
#  ('CORE SUIT', 170, 184),
#  ('COWBOY DOOM', 3, 185),
#  ('COWBOY DOOM', 74, 185),
#  ('COWBOY DOOM', 123, 185),
#  ('COWBOY DOOM', 140, 185),
#  ('COWBOY DOOM', 191, 185),
#  ('CRAFT OUTFIELD', 26, 186),
#  ('CRAFT OUTFIELD', 60, 186),
#  ('CRAFT OUTFIELD', 81, 186),
#  ...]

# %% [markdown]
# # Challenge 1 - Working with JSON files
# Import the pandas library.

# %%
# your code here
import pandas as pd

# %% [markdown]
# In the next cell, load the data in nasa.json in the data folder and load it into a pandas dataframe. Name the dataframe nasa.

# %%
# your code here
data = pd.read_json("nasa.json")
nasa = pd.DataFrame(data)

# %% [markdown]
# Now that we have loaded the data, let's examine it using the head() function.

# %%
# your code here
nasa.head(5)
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass      name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0    Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0    Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0      Abee
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0  Acapulco
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0   Achiras
#
#   nametype     recclass    reclat    reclong                     year
# 0    Valid           L5  50.77500    6.08333  1880-01-01T00:00:00.000
# 1    Valid           H6  56.18333   10.23333  1951-01-01T00:00:00.000
# 2    Valid          EH4  54.21667 -113.00000  1952-01-01T00:00:00.000
# 3    Valid  Acapulcoite  16.88333  -99.90000  1976-01-01T00:00:00.000
# 4    Valid           L6 -33.16667  -64.95000  1902-01-01T00:00:00.000

# %% [markdown]
# ####  The value_counts() function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the value_counts() function to determine the frequency of all types of asteroid landings by applying the function to the fall column.

# %%
# your code here
nasa["fall"].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the orient=records argument and name the file nasa-output.json. Remember to save the file inside the data folder.

# %%
# your code here
result = nasa.to_json('nasa2.json',orient='records')

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# Import the pandas library
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
#Your pandas import here:
import pandas as pd

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:

shuttles = pd.read_csv(tst_url, sep = ' ', names = cols)

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# Your code here:

shuttles.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:

shuttle = shuttles.to_csv('shuttle.csv',index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:

astronaut = pd.read_excel('astronauts.xls')

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:

astronaut.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN
# 1                   STS 51-F (Challenger)        NaT           NaN

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut["Undergraduate Major"].value_counts()

#Physics
# Out:
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:

astronaut.to_csv('astronaut.csv', index=False, sep = '|')

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:
