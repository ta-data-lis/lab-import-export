# %% [markdown]
# # Import and Export Files

# %% [markdown]
# # Challenge 0 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here

import mysql.connector
import getpass

import pandas as pd

# %%
password = getpass.getpass()
# Out:
# ········

# %%
cnx = mysql.connector.connect(user = "root",
                              password = password,
                              host = "localhost",
                              database = "sakila")

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()

# %%
query = ('''SELECT *
FROM sakila.customer;''')

# %%
cursor.execute(query)

# %%
q_result = cursor.fetchall()
q_result
# Out:
# [(1,
#   1,
#   'MARY',
#   'SMITH',
#   'MARY.SMITH@sakilacustomer.org',
#   5,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (2,
#   1,
#   'PATRICIA',
#   'JOHNSON',
#   'PATRICIA.JOHNSON@sakilacustomer.org',
#   6,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (3,
#   1,
#   'LINDA',
#   'WILLIAMS',
#   'LINDA.WILLIAMS@sakilacustomer.org',
#   7,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (4,
#   2,
#   'BARBARA',
#   'JONES',
#   'BARBARA.JONES@sakilacustomer.org',
#   8,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (5,
#   1,
#   'ELIZABETH',
#   'BROWN',
#   'ELIZABETH.BROWN@sakilacustomer.org',
#   9,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (6,
#   2,
#   'JENNIFER',
#   'DAVIS',
#   'JENNIFER.DAVIS@sakilacustomer.org',
#   10,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (7,
#   1,
#   'MARIA',
#   'MILLER',
#   'MARIA.MILLER@sakilacustomer.org',
#   11,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (8,
#   2,
#   'SUSAN',
#   'WILSON',
#   'SUSAN.WILSON@sakilacustomer.org',
#   12,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (9,
#   2,
#   'MARGARET',
#   'MOORE',
#   'MARGARET.MOORE@sakilacustomer.org',
#   13,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (10,
#   1,
#   'DOROTHY',
#   'TAYLOR',
#   'DOROTHY.TAYLOR@sakilacustomer.org',
#   14,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (11,
#   2,
#   'LISA',
#   'ANDERSON',
#   'LISA.ANDERSON@sakilacustomer.org',
#   15,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (12,
#   1,
#   'NANCY',
#   'THOMAS',
#   'NANCY.THOMAS@sakilacustomer.org',
#   16,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (13,
#   2,
#   'KAREN',
#   'JACKSON',
#   'KAREN.JACKSON@sakilacustomer.org',
#   17,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (14,
#   2,
#   'BETTY',
#   'WHITE',
#   'BETTY.WHITE@sakilacustomer.org',
#   18,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (15,
#   1,
#   'HELEN',
#   'HARRIS',
#   'HELEN.HARRIS@sakilacustomer.org',
#   19,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (16,
#   2,
#   'SANDRA',
#   'MARTIN',
#   'SANDRA.MARTIN@sakilacustomer.org',
#   20,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (17,
#   1,
#   'DONNA',
#   'THOMPSON',
#   'DONNA.THOMPSON@sakilacustomer.org',
#   21,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (18,
#   2,
#   'CAROL',
#   'GARCIA',
#   'CAROL.GARCIA@sakilacustomer.org',
#   22,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (19,
#   1,
#   'RUTH',
#   'MARTINEZ',
#   'RUTH.MARTINEZ@sakilacustomer.org',
#   23,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (20,
#   2,
#   'SHARON',
#   'ROBINSON',
#   'SHARON.ROBINSON@sakilacustomer.org',
#   24,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (21,
#   1,
#   'MICHELLE',
#   'CLARK',
#   'MICHELLE.CLARK@sakilacustomer.org',
#   25,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (22,
#   1,
#   'LAURA',
#   'RODRIGUEZ',
#   'LAURA.RODRIGUEZ@sakilacustomer.org',
#   26,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (23,
#   2,
#   'SARAH',
#   'LEWIS',
#   'SARAH.LEWIS@sakilacustomer.org',
#   27,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (24,
#   2,
#   'KIMBERLY',
#   'LEE',
#   'KIMBERLY.LEE@sakilacustomer.org',
#   28,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (25,
#   1,
#   'DEBORAH',
#   'WALKER',
#   'DEBORAH.WALKER@sakilacustomer.org',
#   29,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (26,
#   2,
#   'JESSICA',
#   'HALL',
#   'JESSICA.HALL@sakilacustomer.org',
#   30,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (27,
#   2,
#   'SHIRLEY',
#   'ALLEN',
#   'SHIRLEY.ALLEN@sakilacustomer.org',
#   31,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (28,
#   1,
#   'CYNTHIA',
#   'YOUNG',
#   'CYNTHIA.YOUNG@sakilacustomer.org',
#   32,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (29,
#   2,
#   'ANGELA',
#   'HERNANDEZ',
#   'ANGELA.HERNANDEZ@sakilacustomer.org',
#   33,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (30,
#   1,
#   'MELISSA',
#   'KING',
#   'MELISSA.KING@sakilacustomer.org',
#   34,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (31,
#   2,
#   'BRENDA',
#   'WRIGHT',
#   'BRENDA.WRIGHT@sakilacustomer.org',
#   35,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (32,
#   1,
#   'AMY',
#   'LOPEZ',
#   'AMY.LOPEZ@sakilacustomer.org',
#   36,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (33,
#   2,
#   'ANNA',
#   'HILL',
#   'ANNA.HILL@sakilacustomer.org',
#   37,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (34,
#   2,
#   'REBECCA',
#   'SCOTT',
#   'REBECCA.SCOTT@sakilacustomer.org',
#   38,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (35,
#   2,
#   'VIRGINIA',
#   'GREEN',
#   'VIRGINIA.GREEN@sakilacustomer.org',
#   39,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (36,
#   2,
#   'KATHLEEN',
#   'ADAMS',
#   'KATHLEEN.ADAMS@sakilacustomer.org',
#   40,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (37,
#   1,
#   'PAMELA',
#   'BAKER',
#   'PAMELA.BAKER@sakilacustomer.org',
#   41,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (38,
#   1,
#   'MARTHA',
#   'GONZALEZ',
#   'MARTHA.GONZALEZ@sakilacustomer.org',
#   42,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (39,
#   1,
#   'DEBRA',
#   'NELSON',
#   'DEBRA.NELSON@sakilacustomer.org',
#   43,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (40,
#   2,
#   'AMANDA',
#   'CARTER',
#   'AMANDA.CARTER@sakilacustomer.org',
#   44,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (41,
#   1,
#   'STEPHANIE',
#   'MITCHELL',
#   'STEPHANIE.MITCHELL@sakilacustomer.org',
#   45,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (42,
#   2,
#   'CAROLYN',
#   'PEREZ',
#   'CAROLYN.PEREZ@sakilacustomer.org',
#   46,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (43,
#   2,
#   'CHRISTINE',
#   'ROBERTS',
#   'CHRISTINE.ROBERTS@sakilacustomer.org',
#   47,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (44,
#   1,
#   'MARIE',
#   'TURNER',
#   'MARIE.TURNER@sakilacustomer.org',
#   48,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (45,
#   1,
#   'JANET',
#   'PHILLIPS',
#   'JANET.PHILLIPS@sakilacustomer.org',
#   49,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (46,
#   2,
#   'CATHERINE',
#   'CAMPBELL',
#   'CATHERINE.CAMPBELL@sakilacustomer.org',
#   50,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (47,
#   1,
#   'FRANCES',
#   'PARKER',
#   'FRANCES.PARKER@sakilacustomer.org',
#   51,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (48,
#   1,
#   'ANN',
#   'EVANS',
#   'ANN.EVANS@sakilacustomer.org',
#   52,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (49,
#   2,
#   'JOYCE',
#   'EDWARDS',
#   'JOYCE.EDWARDS@sakilacustomer.org',
#   53,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (50,
#   1,
#   'DIANE',
#   'COLLINS',
#   'DIANE.COLLINS@sakilacustomer.org',
#   54,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (51,
#   1,
#   'ALICE',
#   'STEWART',
#   'ALICE.STEWART@sakilacustomer.org',
#   55,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (52,
#   1,
#   'JULIE',
#   'SANCHEZ',
#   'JULIE.SANCHEZ@sakilacustomer.org',
#   56,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (53,
#   1,
#   'HEATHER',
#   'MORRIS',
#   'HEATHER.MORRIS@sakilacustomer.org',
#   57,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (54,
#   1,
#   'TERESA',
#   'ROGERS',
#   'TERESA.ROGERS@sakilacustomer.org',
#   58,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (55,
#   2,
#   'DORIS',
#   'REED',
#   'DORIS.REED@sakilacustomer.org',
#   59,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (56,
#   1,
#   'GLORIA',
#   'COOK',
#   'GLORIA.COOK@sakilacustomer.org',
#   60,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (57,
#   2,
#   'EVELYN',
#   'MORGAN',
#   'EVELYN.MORGAN@sakilacustomer.org',
#   61,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (58,
#   1,
#   'JEAN',
#   'BELL',
#   'JEAN.BELL@sakilacustomer.org',
#   62,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (59,
#   1,
#   'CHERYL',
#   'MURPHY',
#   'CHERYL.MURPHY@sakilacustomer.org',
#   63,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (60,
#   1,
#   'MILDRED',
#   'BAILEY',
#   'MILDRED.BAILEY@sakilacustomer.org',
#   64,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (61,
#   2,
#   'KATHERINE',
#   'RIVERA',
#   'KATHERINE.RIVERA@sakilacustomer.org',
#   65,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (62,
#   1,
#   'JOAN',
#   'COOPER',
#   'JOAN.COOPER@sakilacustomer.org',
#   66,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (63,
#   1,
#   'ASHLEY',
#   'RICHARDSON',
#   'ASHLEY.RICHARDSON@sakilacustomer.org',
#   67,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (64,
#   2,
#   'JUDITH',
#   'COX',
#   'JUDITH.COX@sakilacustomer.org',
#   68,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (65,
#   2,
#   'ROSE',
#   'HOWARD',
#   'ROSE.HOWARD@sakilacustomer.org',
#   69,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (66,
#   2,
#   'JANICE',
#   'WARD',
#   'JANICE.WARD@sakilacustomer.org',
#   70,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (67,
#   1,
#   'KELLY',
#   'TORRES',
#   'KELLY.TORRES@sakilacustomer.org',
#   71,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (68,
#   1,
#   'NICOLE',
#   'PETERSON',
#   'NICOLE.PETERSON@sakilacustomer.org',
#   72,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (69,
#   2,
#   'JUDY',
#   'GRAY',
#   'JUDY.GRAY@sakilacustomer.org',
#   73,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (70,
#   2,
#   'CHRISTINA',
#   'RAMIREZ',
#   'CHRISTINA.RAMIREZ@sakilacustomer.org',
#   74,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (71,
#   1,
#   'KATHY',
#   'JAMES',
#   'KATHY.JAMES@sakilacustomer.org',
#   75,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (72,
#   2,
#   'THERESA',
#   'WATSON',
#   'THERESA.WATSON@sakilacustomer.org',
#   76,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (73,
#   2,
#   'BEVERLY',
#   'BROOKS',
#   'BEVERLY.BROOKS@sakilacustomer.org',
#   77,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (74,
#   1,
#   'DENISE',
#   'KELLY',
#   'DENISE.KELLY@sakilacustomer.org',
#   78,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (75,
#   2,
#   'TAMMY',
#   'SANDERS',
#   'TAMMY.SANDERS@sakilacustomer.org',
#   79,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (76,
#   2,
#   'IRENE',
#   'PRICE',
#   'IRENE.PRICE@sakilacustomer.org',
#   80,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (77,
#   2,
#   'JANE',
#   'BENNETT',
#   'JANE.BENNETT@sakilacustomer.org',
#   81,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (78,
#   1,
#   'LORI',
#   'WOOD',
#   'LORI.WOOD@sakilacustomer.org',
#   82,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (79,
#   1,
#   'RACHEL',
#   'BARNES',
#   'RACHEL.BARNES@sakilacustomer.org',
#   83,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (80,
#   1,
#   'MARILYN',
#   'ROSS',
#   'MARILYN.ROSS@sakilacustomer.org',
#   84,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (81,
#   1,
#   'ANDREA',
#   'HENDERSON',
#   'ANDREA.HENDERSON@sakilacustomer.org',
#   85,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (82,
#   1,
#   'KATHRYN',
#   'COLEMAN',
#   'KATHRYN.COLEMAN@sakilacustomer.org',
#   86,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (83,
#   1,
#   'LOUISE',
#   'JENKINS',
#   'LOUISE.JENKINS@sakilacustomer.org',
#   87,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (84,
#   2,
#   'SARA',
#   'PERRY',
#   'SARA.PERRY@sakilacustomer.org',
#   88,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (85,
#   2,
#   'ANNE',
#   'POWELL',
#   'ANNE.POWELL@sakilacustomer.org',
#   89,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (86,
#   2,
#   'JACQUELINE',
#   'LONG',
#   'JACQUELINE.LONG@sakilacustomer.org',
#   90,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (87,
#   1,
#   'WANDA',
#   'PATTERSON',
#   'WANDA.PATTERSON@sakilacustomer.org',
#   91,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (88,
#   2,
#   'BONNIE',
#   'HUGHES',
#   'BONNIE.HUGHES@sakilacustomer.org',
#   92,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (89,
#   1,
#   'JULIA',
#   'FLORES',
#   'JULIA.FLORES@sakilacustomer.org',
#   93,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (90,
#   2,
#   'RUBY',
#   'WASHINGTON',
#   'RUBY.WASHINGTON@sakilacustomer.org',
#   94,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (91,
#   2,
#   'LOIS',
#   'BUTLER',
#   'LOIS.BUTLER@sakilacustomer.org',
#   95,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (92,
#   2,
#   'TINA',
#   'SIMMONS',
#   'TINA.SIMMONS@sakilacustomer.org',
#   96,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (93,
#   1,
#   'PHYLLIS',
#   'FOSTER',
#   'PHYLLIS.FOSTER@sakilacustomer.org',
#   97,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (94,
#   1,
#   'NORMA',
#   'GONZALES',
#   'NORMA.GONZALES@sakilacustomer.org',
#   98,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (95,
#   2,
#   'PAULA',
#   'BRYANT',
#   'PAULA.BRYANT@sakilacustomer.org',
#   99,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (96,
#   1,
#   'DIANA',
#   'ALEXANDER',
#   'DIANA.ALEXANDER@sakilacustomer.org',
#   100,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (97,
#   2,
#   'ANNIE',
#   'RUSSELL',
#   'ANNIE.RUSSELL@sakilacustomer.org',
#   101,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (98,
#   1,
#   'LILLIAN',
#   'GRIFFIN',
#   'LILLIAN.GRIFFIN@sakilacustomer.org',
#   102,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (99,
#   2,
#   'EMILY',
#   'DIAZ',
#   'EMILY.DIAZ@sakilacustomer.org',
#   103,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (100,
#   1,
#   'ROBIN',
#   'HAYES',
#   'ROBIN.HAYES@sakilacustomer.org',
#   104,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (101,
#   1,
#   'PEGGY',
#   'MYERS',
#   'PEGGY.MYERS@sakilacustomer.org',
#   105,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (102,
#   1,
#   'CRYSTAL',
#   'FORD',
#   'CRYSTAL.FORD@sakilacustomer.org',
#   106,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (103,
#   1,
#   'GLADYS',
#   'HAMILTON',
#   'GLADYS.HAMILTON@sakilacustomer.org',
#   107,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (104,
#   1,
#   'RITA',
#   'GRAHAM',
#   'RITA.GRAHAM@sakilacustomer.org',
#   108,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (105,
#   1,
#   'DAWN',
#   'SULLIVAN',
#   'DAWN.SULLIVAN@sakilacustomer.org',
#   109,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (106,
#   1,
#   'CONNIE',
#   'WALLACE',
#   'CONNIE.WALLACE@sakilacustomer.org',
#   110,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (107,
#   1,
#   'FLORENCE',
#   'WOODS',
#   'FLORENCE.WOODS@sakilacustomer.org',
#   111,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (108,
#   1,
#   'TRACY',
#   'COLE',
#   'TRACY.COLE@sakilacustomer.org',
#   112,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (109,
#   2,
#   'EDNA',
#   'WEST',
#   'EDNA.WEST@sakilacustomer.org',
#   113,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (110,
#   2,
#   'TIFFANY',
#   'JORDAN',
#   'TIFFANY.JORDAN@sakilacustomer.org',
#   114,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (111,
#   1,
#   'CARMEN',
#   'OWENS',
#   'CARMEN.OWENS@sakilacustomer.org',
#   115,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (112,
#   2,
#   'ROSA',
#   'REYNOLDS',
#   'ROSA.REYNOLDS@sakilacustomer.org',
#   116,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (113,
#   2,
#   'CINDY',
#   'FISHER',
#   'CINDY.FISHER@sakilacustomer.org',
#   117,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (114,
#   2,
#   'GRACE',
#   'ELLIS',
#   'GRACE.ELLIS@sakilacustomer.org',
#   118,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (115,
#   1,
#   'WENDY',
#   'HARRISON',
#   'WENDY.HARRISON@sakilacustomer.org',
#   119,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (116,
#   1,
#   'VICTORIA',
#   'GIBSON',
#   'VICTORIA.GIBSON@sakilacustomer.org',
#   120,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (117,
#   1,
#   'EDITH',
#   'MCDONALD',
#   'EDITH.MCDONALD@sakilacustomer.org',
#   121,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (118,
#   1,
#   'KIM',
#   'CRUZ',
#   'KIM.CRUZ@sakilacustomer.org',
#   122,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (119,
#   1,
#   'SHERRY',
#   'MARSHALL',
#   'SHERRY.MARSHALL@sakilacustomer.org',
#   123,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (120,
#   2,
#   'SYLVIA',
#   'ORTIZ',
#   'SYLVIA.ORTIZ@sakilacustomer.org',
#   124,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (121,
#   1,
#   'JOSEPHINE',
#   'GOMEZ',
#   'JOSEPHINE.GOMEZ@sakilacustomer.org',
#   125,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (122,
#   1,
#   'THELMA',
#   'MURRAY',
#   'THELMA.MURRAY@sakilacustomer.org',
#   126,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (123,
#   2,
#   'SHANNON',
#   'FREEMAN',
#   'SHANNON.FREEMAN@sakilacustomer.org',
#   127,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (124,
#   1,
#   'SHEILA',
#   'WELLS',
#   'SHEILA.WELLS@sakilacustomer.org',
#   128,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (125,
#   1,
#   'ETHEL',
#   'WEBB',
#   'ETHEL.WEBB@sakilacustomer.org',
#   129,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (126,
#   1,
#   'ELLEN',
#   'SIMPSON',
#   'ELLEN.SIMPSON@sakilacustomer.org',
#   130,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (127,
#   2,
#   'ELAINE',
#   'STEVENS',
#   'ELAINE.STEVENS@sakilacustomer.org',
#   131,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (128,
#   1,
#   'MARJORIE',
#   'TUCKER',
#   'MARJORIE.TUCKER@sakilacustomer.org',
#   132,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (129,
#   1,
#   'CARRIE',
#   'PORTER',
#   'CARRIE.PORTER@sakilacustomer.org',
#   133,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (130,
#   1,
#   'CHARLOTTE',
#   'HUNTER',
#   'CHARLOTTE.HUNTER@sakilacustomer.org',
#   134,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (131,
#   2,
#   'MONICA',
#   'HICKS',
#   'MONICA.HICKS@sakilacustomer.org',
#   135,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (132,
#   2,
#   'ESTHER',
#   'CRAWFORD',
#   'ESTHER.CRAWFORD@sakilacustomer.org',
#   136,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (133,
#   1,
#   'PAULINE',
#   'HENRY',
#   'PAULINE.HENRY@sakilacustomer.org',
#   137,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (134,
#   1,
#   'EMMA',
#   'BOYD',
#   'EMMA.BOYD@sakilacustomer.org',
#   138,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (135,
#   2,
#   'JUANITA',
#   'MASON',
#   'JUANITA.MASON@sakilacustomer.org',
#   139,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (136,
#   2,
#   'ANITA',
#   'MORALES',
#   'ANITA.MORALES@sakilacustomer.org',
#   140,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (137,
#   2,
#   'RHONDA',
#   'KENNEDY',
#   'RHONDA.KENNEDY@sakilacustomer.org',
#   141,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (138,
#   1,
#   'HAZEL',
#   'WARREN',
#   'HAZEL.WARREN@sakilacustomer.org',
#   142,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (139,
#   1,
#   'AMBER',
#   'DIXON',
#   'AMBER.DIXON@sakilacustomer.org',
#   143,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (140,
#   1,
#   'EVA',
#   'RAMOS',
#   'EVA.RAMOS@sakilacustomer.org',
#   144,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (141,
#   1,
#   'DEBBIE',
#   'REYES',
#   'DEBBIE.REYES@sakilacustomer.org',
#   145,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (142,
#   1,
#   'APRIL',
#   'BURNS',
#   'APRIL.BURNS@sakilacustomer.org',
#   146,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (143,
#   1,
#   'LESLIE',
#   'GORDON',
#   'LESLIE.GORDON@sakilacustomer.org',
#   147,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (144,
#   1,
#   'CLARA',
#   'SHAW',
#   'CLARA.SHAW@sakilacustomer.org',
#   148,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (145,
#   1,
#   'LUCILLE',
#   'HOLMES',
#   'LUCILLE.HOLMES@sakilacustomer.org',
#   149,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (146,
#   1,
#   'JAMIE',
#   'RICE',
#   'JAMIE.RICE@sakilacustomer.org',
#   150,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (147,
#   2,
#   'JOANNE',
#   'ROBERTSON',
#   'JOANNE.ROBERTSON@sakilacustomer.org',
#   151,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (148,
#   1,
#   'ELEANOR',
#   'HUNT',
#   'ELEANOR.HUNT@sakilacustomer.org',
#   152,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (149,
#   1,
#   'VALERIE',
#   'BLACK',
#   'VALERIE.BLACK@sakilacustomer.org',
#   153,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (150,
#   2,
#   'DANIELLE',
#   'DANIELS',
#   'DANIELLE.DANIELS@sakilacustomer.org',
#   154,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (151,
#   2,
#   'MEGAN',
#   'PALMER',
#   'MEGAN.PALMER@sakilacustomer.org',
#   155,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (152,
#   1,
#   'ALICIA',
#   'MILLS',
#   'ALICIA.MILLS@sakilacustomer.org',
#   156,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (153,
#   2,
#   'SUZANNE',
#   'NICHOLS',
#   'SUZANNE.NICHOLS@sakilacustomer.org',
#   157,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (154,
#   2,
#   'MICHELE',
#   'GRANT',
#   'MICHELE.GRANT@sakilacustomer.org',
#   158,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (155,
#   1,
#   'GAIL',
#   'KNIGHT',
#   'GAIL.KNIGHT@sakilacustomer.org',
#   159,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (156,
#   1,
#   'BERTHA',
#   'FERGUSON',
#   'BERTHA.FERGUSON@sakilacustomer.org',
#   160,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (157,
#   2,
#   'DARLENE',
#   'ROSE',
#   'DARLENE.ROSE@sakilacustomer.org',
#   161,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (158,
#   1,
#   'VERONICA',
#   'STONE',
#   'VERONICA.STONE@sakilacustomer.org',
#   162,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (159,
#   1,
#   'JILL',
#   'HAWKINS',
#   'JILL.HAWKINS@sakilacustomer.org',
#   163,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (160,
#   2,
#   'ERIN',
#   'DUNN',
#   'ERIN.DUNN@sakilacustomer.org',
#   164,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (161,
#   1,
#   'GERALDINE',
#   'PERKINS',
#   'GERALDINE.PERKINS@sakilacustomer.org',
#   165,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (162,
#   2,
#   'LAUREN',
#   'HUDSON',
#   'LAUREN.HUDSON@sakilacustomer.org',
#   166,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (163,
#   1,
#   'CATHY',
#   'SPENCER',
#   'CATHY.SPENCER@sakilacustomer.org',
#   167,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (164,
#   2,
#   'JOANN',
#   'GARDNER',
#   'JOANN.GARDNER@sakilacustomer.org',
#   168,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (165,
#   2,
#   'LORRAINE',
#   'STEPHENS',
#   'LORRAINE.STEPHENS@sakilacustomer.org',
#   169,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (166,
#   1,
#   'LYNN',
#   'PAYNE',
#   'LYNN.PAYNE@sakilacustomer.org',
#   170,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (167,
#   2,
#   'SALLY',
#   'PIERCE',
#   'SALLY.PIERCE@sakilacustomer.org',
#   171,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (168,
#   1,
#   'REGINA',
#   'BERRY',
#   'REGINA.BERRY@sakilacustomer.org',
#   172,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (169,
#   2,
#   'ERICA',
#   'MATTHEWS',
#   'ERICA.MATTHEWS@sakilacustomer.org',
#   173,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (170,
#   1,
#   'BEATRICE',
#   'ARNOLD',
#   'BEATRICE.ARNOLD@sakilacustomer.org',
#   174,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (171,
#   2,
#   'DOLORES',
#   'WAGNER',
#   'DOLORES.WAGNER@sakilacustomer.org',
#   175,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (172,
#   1,
#   'BERNICE',
#   'WILLIS',
#   'BERNICE.WILLIS@sakilacustomer.org',
#   176,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (173,
#   1,
#   'AUDREY',
#   'RAY',
#   'AUDREY.RAY@sakilacustomer.org',
#   177,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (174,
#   2,
#   'YVONNE',
#   'WATKINS',
#   'YVONNE.WATKINS@sakilacustomer.org',
#   178,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (175,
#   1,
#   'ANNETTE',
#   'OLSON',
#   'ANNETTE.OLSON@sakilacustomer.org',
#   179,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (176,
#   1,
#   'JUNE',
#   'CARROLL',
#   'JUNE.CARROLL@sakilacustomer.org',
#   180,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (177,
#   2,
#   'SAMANTHA',
#   'DUNCAN',
#   'SAMANTHA.DUNCAN@sakilacustomer.org',
#   181,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (178,
#   2,
#   'MARION',
#   'SNYDER',
#   'MARION.SNYDER@sakilacustomer.org',
#   182,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (179,
#   1,
#   'DANA',
#   'HART',
#   'DANA.HART@sakilacustomer.org',
#   183,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (180,
#   2,
#   'STACY',
#   'CUNNINGHAM',
#   'STACY.CUNNINGHAM@sakilacustomer.org',
#   184,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (181,
#   2,
#   'ANA',
#   'BRADLEY',
#   'ANA.BRADLEY@sakilacustomer.org',
#   185,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (182,
#   1,
#   'RENEE',
#   'LANE',
#   'RENEE.LANE@sakilacustomer.org',
#   186,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (183,
#   2,
#   'IDA',
#   'ANDREWS',
#   'IDA.ANDREWS@sakilacustomer.org',
#   187,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (184,
#   1,
#   'VIVIAN',
#   'RUIZ',
#   'VIVIAN.RUIZ@sakilacustomer.org',
#   188,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (185,
#   1,
#   'ROBERTA',
#   'HARPER',
#   'ROBERTA.HARPER@sakilacustomer.org',
#   189,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (186,
#   2,
#   'HOLLY',
#   'FOX',
#   'HOLLY.FOX@sakilacustomer.org',
#   190,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (187,
#   2,
#   'BRITTANY',
#   'RILEY',
#   'BRITTANY.RILEY@sakilacustomer.org',
#   191,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (188,
#   1,
#   'MELANIE',
#   'ARMSTRONG',
#   'MELANIE.ARMSTRONG@sakilacustomer.org',
#   192,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (189,
#   1,
#   'LORETTA',
#   'CARPENTER',
#   'LORETTA.CARPENTER@sakilacustomer.org',
#   193,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (190,
#   2,
#   'YOLANDA',
#   'WEAVER',
#   'YOLANDA.WEAVER@sakilacustomer.org',
#   194,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (191,
#   1,
#   'JEANETTE',
#   'GREENE',
#   'JEANETTE.GREENE@sakilacustomer.org',
#   195,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (192,
#   1,
#   'LAURIE',
#   'LAWRENCE',
#   'LAURIE.LAWRENCE@sakilacustomer.org',
#   196,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (193,
#   2,
#   'KATIE',
#   'ELLIOTT',
#   'KATIE.ELLIOTT@sakilacustomer.org',
#   197,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (194,
#   2,
#   'KRISTEN',
#   'CHAVEZ',
#   'KRISTEN.CHAVEZ@sakilacustomer.org',
#   198,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (195,
#   1,
#   'VANESSA',
#   'SIMS',
#   'VANESSA.SIMS@sakilacustomer.org',
#   199,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (196,
#   1,
#   'ALMA',
#   'AUSTIN',
#   'ALMA.AUSTIN@sakilacustomer.org',
#   200,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (197,
#   2,
#   'SUE',
#   'PETERS',
#   'SUE.PETERS@sakilacustomer.org',
#   201,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (198,
#   2,
#   'ELSIE',
#   'KELLEY',
#   'ELSIE.KELLEY@sakilacustomer.org',
#   202,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (199,
#   2,
#   'BETH',
#   'FRANKLIN',
#   'BETH.FRANKLIN@sakilacustomer.org',
#   203,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (200,
#   2,
#   'JEANNE',
#   'LAWSON',
#   'JEANNE.LAWSON@sakilacustomer.org',
#   204,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (201,
#   1,
#   'VICKI',
#   'FIELDS',
#   'VICKI.FIELDS@sakilacustomer.org',
#   205,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (202,
#   2,
#   'CARLA',
#   'GUTIERREZ',
#   'CARLA.GUTIERREZ@sakilacustomer.org',
#   206,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (203,
#   1,
#   'TARA',
#   'RYAN',
#   'TARA.RYAN@sakilacustomer.org',
#   207,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (204,
#   1,
#   'ROSEMARY',
#   'SCHMIDT',
#   'ROSEMARY.SCHMIDT@sakilacustomer.org',
#   208,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (205,
#   2,
#   'EILEEN',
#   'CARR',
#   'EILEEN.CARR@sakilacustomer.org',
#   209,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (206,
#   1,
#   'TERRI',
#   'VASQUEZ',
#   'TERRI.VASQUEZ@sakilacustomer.org',
#   210,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (207,
#   1,
#   'GERTRUDE',
#   'CASTILLO',
#   'GERTRUDE.CASTILLO@sakilacustomer.org',
#   211,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (208,
#   1,
#   'LUCY',
#   'WHEELER',
#   'LUCY.WHEELER@sakilacustomer.org',
#   212,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (209,
#   2,
#   'TONYA',
#   'CHAPMAN',
#   'TONYA.CHAPMAN@sakilacustomer.org',
#   213,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (210,
#   2,
#   'ELLA',
#   'OLIVER',
#   'ELLA.OLIVER@sakilacustomer.org',
#   214,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (211,
#   1,
#   'STACEY',
#   'MONTGOMERY',
#   'STACEY.MONTGOMERY@sakilacustomer.org',
#   215,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (212,
#   2,
#   'WILMA',
#   'RICHARDS',
#   'WILMA.RICHARDS@sakilacustomer.org',
#   216,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (213,
#   1,
#   'GINA',
#   'WILLIAMSON',
#   'GINA.WILLIAMSON@sakilacustomer.org',
#   217,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (214,
#   1,
#   'KRISTIN',
#   'JOHNSTON',
#   'KRISTIN.JOHNSTON@sakilacustomer.org',
#   218,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (215,
#   2,
#   'JESSIE',
#   'BANKS',
#   'JESSIE.BANKS@sakilacustomer.org',
#   219,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (216,
#   1,
#   'NATALIE',
#   'MEYER',
#   'NATALIE.MEYER@sakilacustomer.org',
#   220,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (217,
#   2,
#   'AGNES',
#   'BISHOP',
#   'AGNES.BISHOP@sakilacustomer.org',
#   221,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (218,
#   1,
#   'VERA',
#   'MCCOY',
#   'VERA.MCCOY@sakilacustomer.org',
#   222,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (219,
#   2,
#   'WILLIE',
#   'HOWELL',
#   'WILLIE.HOWELL@sakilacustomer.org',
#   223,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (220,
#   2,
#   'CHARLENE',
#   'ALVAREZ',
#   'CHARLENE.ALVAREZ@sakilacustomer.org',
#   224,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (221,
#   1,
#   'BESSIE',
#   'MORRISON',
#   'BESSIE.MORRISON@sakilacustomer.org',
#   225,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (222,
#   2,
#   'DELORES',
#   'HANSEN',
#   'DELORES.HANSEN@sakilacustomer.org',
#   226,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (223,
#   1,
#   'MELINDA',
#   'FERNANDEZ',
#   'MELINDA.FERNANDEZ@sakilacustomer.org',
#   227,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (224,
#   2,
#   'PEARL',
#   'GARZA',
#   'PEARL.GARZA@sakilacustomer.org',
#   228,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (225,
#   1,
#   'ARLENE',
#   'HARVEY',
#   'ARLENE.HARVEY@sakilacustomer.org',
#   229,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (226,
#   2,
#   'MAUREEN',
#   'LITTLE',
#   'MAUREEN.LITTLE@sakilacustomer.org',
#   230,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (227,
#   1,
#   'COLLEEN',
#   'BURTON',
#   'COLLEEN.BURTON@sakilacustomer.org',
#   231,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (228,
#   2,
#   'ALLISON',
#   'STANLEY',
#   'ALLISON.STANLEY@sakilacustomer.org',
#   232,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (229,
#   1,
#   'TAMARA',
#   'NGUYEN',
#   'TAMARA.NGUYEN@sakilacustomer.org',
#   233,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (230,
#   2,
#   'JOY',
#   'GEORGE',
#   'JOY.GEORGE@sakilacustomer.org',
#   234,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (231,
#   1,
#   'GEORGIA',
#   'JACOBS',
#   'GEORGIA.JACOBS@sakilacustomer.org',
#   235,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (232,
#   2,
#   'CONSTANCE',
#   'REID',
#   'CONSTANCE.REID@sakilacustomer.org',
#   236,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (233,
#   2,
#   'LILLIE',
#   'KIM',
#   'LILLIE.KIM@sakilacustomer.org',
#   237,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (234,
#   1,
#   'CLAUDIA',
#   'FULLER',
#   'CLAUDIA.FULLER@sakilacustomer.org',
#   238,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (235,
#   1,
#   'JACKIE',
#   'LYNCH',
#   'JACKIE.LYNCH@sakilacustomer.org',
#   239,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (236,
#   1,
#   'MARCIA',
#   'DEAN',
#   'MARCIA.DEAN@sakilacustomer.org',
#   240,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (237,
#   1,
#   'TANYA',
#   'GILBERT',
#   'TANYA.GILBERT@sakilacustomer.org',
#   241,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (238,
#   1,
#   'NELLIE',
#   'GARRETT',
#   'NELLIE.GARRETT@sakilacustomer.org',
#   242,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (239,
#   2,
#   'MINNIE',
#   'ROMERO',
#   'MINNIE.ROMERO@sakilacustomer.org',
#   243,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (240,
#   1,
#   'MARLENE',
#   'WELCH',
#   'MARLENE.WELCH@sakilacustomer.org',
#   244,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (241,
#   2,
#   'HEIDI',
#   'LARSON',
#   'HEIDI.LARSON@sakilacustomer.org',
#   245,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (242,
#   1,
#   'GLENDA',
#   'FRAZIER',
#   'GLENDA.FRAZIER@sakilacustomer.org',
#   246,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (243,
#   1,
#   'LYDIA',
#   'BURKE',
#   'LYDIA.BURKE@sakilacustomer.org',
#   247,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (244,
#   2,
#   'VIOLA',
#   'HANSON',
#   'VIOLA.HANSON@sakilacustomer.org',
#   248,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (245,
#   1,
#   'COURTNEY',
#   'DAY',
#   'COURTNEY.DAY@sakilacustomer.org',
#   249,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (246,
#   1,
#   'MARIAN',
#   'MENDOZA',
#   'MARIAN.MENDOZA@sakilacustomer.org',
#   250,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (247,
#   1,
#   'STELLA',
#   'MORENO',
#   'STELLA.MORENO@sakilacustomer.org',
#   251,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (248,
#   1,
#   'CAROLINE',
#   'BOWMAN',
#   'CAROLINE.BOWMAN@sakilacustomer.org',
#   252,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (249,
#   2,
#   'DORA',
#   'MEDINA',
#   'DORA.MEDINA@sakilacustomer.org',
#   253,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (250,
#   2,
#   'JO',
#   'FOWLER',
#   'JO.FOWLER@sakilacustomer.org',
#   254,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (251,
#   2,
#   'VICKIE',
#   'BREWER',
#   'VICKIE.BREWER@sakilacustomer.org',
#   255,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (252,
#   2,
#   'MATTIE',
#   'HOFFMAN',
#   'MATTIE.HOFFMAN@sakilacustomer.org',
#   256,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (253,
#   1,
#   'TERRY',
#   'CARLSON',
#   'TERRY.CARLSON@sakilacustomer.org',
#   258,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (254,
#   2,
#   'MAXINE',
#   'SILVA',
#   'MAXINE.SILVA@sakilacustomer.org',
#   259,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (255,
#   2,
#   'IRMA',
#   'PEARSON',
#   'IRMA.PEARSON@sakilacustomer.org',
#   260,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (256,
#   2,
#   'MABEL',
#   'HOLLAND',
#   'MABEL.HOLLAND@sakilacustomer.org',
#   261,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (257,
#   2,
#   'MARSHA',
#   'DOUGLAS',
#   'MARSHA.DOUGLAS@sakilacustomer.org',
#   262,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (258,
#   1,
#   'MYRTLE',
#   'FLEMING',
#   'MYRTLE.FLEMING@sakilacustomer.org',
#   263,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (259,
#   2,
#   'LENA',
#   'JENSEN',
#   'LENA.JENSEN@sakilacustomer.org',
#   264,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (260,
#   1,
#   'CHRISTY',
#   'VARGAS',
#   'CHRISTY.VARGAS@sakilacustomer.org',
#   265,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (261,
#   1,
#   'DEANNA',
#   'BYRD',
#   'DEANNA.BYRD@sakilacustomer.org',
#   266,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (262,
#   2,
#   'PATSY',
#   'DAVIDSON',
#   'PATSY.DAVIDSON@sakilacustomer.org',
#   267,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (263,
#   1,
#   'HILDA',
#   'HOPKINS',
#   'HILDA.HOPKINS@sakilacustomer.org',
#   268,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (264,
#   1,
#   'GWENDOLYN',
#   'MAY',
#   'GWENDOLYN.MAY@sakilacustomer.org',
#   269,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (265,
#   2,
#   'JENNIE',
#   'TERRY',
#   'JENNIE.TERRY@sakilacustomer.org',
#   270,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (266,
#   2,
#   'NORA',
#   'HERRERA',
#   'NORA.HERRERA@sakilacustomer.org',
#   271,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (267,
#   1,
#   'MARGIE',
#   'WADE',
#   'MARGIE.WADE@sakilacustomer.org',
#   272,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (268,
#   1,
#   'NINA',
#   'SOTO',
#   'NINA.SOTO@sakilacustomer.org',
#   273,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (269,
#   1,
#   'CASSANDRA',
#   'WALTERS',
#   'CASSANDRA.WALTERS@sakilacustomer.org',
#   274,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (270,
#   1,
#   'LEAH',
#   'CURTIS',
#   'LEAH.CURTIS@sakilacustomer.org',
#   275,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (271,
#   1,
#   'PENNY',
#   'NEAL',
#   'PENNY.NEAL@sakilacustomer.org',
#   276,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 36),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (272,
#   1,
#   'KAY',
#   'CALDWELL',
#   'KAY.CALDWELL@sakilacustomer.org',
#   277,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (273,
#   2,
#   'PRISCILLA',
#   'LOWE',
#   'PRISCILLA.LOWE@sakilacustomer.org',
#   278,
#   1,
# ...
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (510,
#   2,
#   'BEN',
#   'EASTER',
#   'BEN.EASTER@sakilacustomer.org',
#   515,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (511,
#   1,
#   'CHESTER',
#   'BENNER',
#   'CHESTER.BENNER@sakilacustomer.org',
#   516,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (512,
#   1,
#   'CECIL',
#   'VINES',
#   'CECIL.VINES@sakilacustomer.org',
#   517,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (513,
#   2,
#   'DUANE',
#   'TUBBS',
#   'DUANE.TUBBS@sakilacustomer.org',
#   519,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (514,
#   2,
#   'FRANKLIN',
#   'TROUTMAN',
#   'FRANKLIN.TROUTMAN@sakilacustomer.org',
#   520,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (515,
#   1,
#   'ANDRE',
#   'RAPP',
#   'ANDRE.RAPP@sakilacustomer.org',
#   521,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (516,
#   2,
#   'ELMER',
#   'NOE',
#   'ELMER.NOE@sakilacustomer.org',
#   522,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (517,
#   2,
#   'BRAD',
#   'MCCURDY',
#   'BRAD.MCCURDY@sakilacustomer.org',
#   523,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (518,
#   1,
#   'GABRIEL',
#   'HARDER',
#   'GABRIEL.HARDER@sakilacustomer.org',
#   524,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (519,
#   2,
#   'RON',
#   'DELUCA',
#   'RON.DELUCA@sakilacustomer.org',
#   525,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (520,
#   2,
#   'MITCHELL',
#   'WESTMORELAND',
#   'MITCHELL.WESTMORELAND@sakilacustomer.org',
#   526,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (521,
#   2,
#   'ROLAND',
#   'SOUTH',
#   'ROLAND.SOUTH@sakilacustomer.org',
#   527,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (522,
#   2,
#   'ARNOLD',
#   'HAVENS',
#   'ARNOLD.HAVENS@sakilacustomer.org',
#   528,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (523,
#   1,
#   'HARVEY',
#   'GUAJARDO',
#   'HARVEY.GUAJARDO@sakilacustomer.org',
#   529,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (524,
#   1,
#   'JARED',
#   'ELY',
#   'JARED.ELY@sakilacustomer.org',
#   530,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (525,
#   2,
#   'ADRIAN',
#   'CLARY',
#   'ADRIAN.CLARY@sakilacustomer.org',
#   531,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (526,
#   2,
#   'KARL',
#   'SEAL',
#   'KARL.SEAL@sakilacustomer.org',
#   532,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (527,
#   1,
#   'CORY',
#   'MEEHAN',
#   'CORY.MEEHAN@sakilacustomer.org',
#   533,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (528,
#   1,
#   'CLAUDE',
#   'HERZOG',
#   'CLAUDE.HERZOG@sakilacustomer.org',
#   534,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (529,
#   2,
#   'ERIK',
#   'GUILLEN',
#   'ERIK.GUILLEN@sakilacustomer.org',
#   535,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (530,
#   2,
#   'DARRYL',
#   'ASHCRAFT',
#   'DARRYL.ASHCRAFT@sakilacustomer.org',
#   536,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (531,
#   2,
#   'JAMIE',
#   'WAUGH',
#   'JAMIE.WAUGH@sakilacustomer.org',
#   537,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (532,
#   2,
#   'NEIL',
#   'RENNER',
#   'NEIL.RENNER@sakilacustomer.org',
#   538,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (533,
#   1,
#   'JESSIE',
#   'MILAM',
#   'JESSIE.MILAM@sakilacustomer.org',
#   539,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (534,
#   1,
#   'CHRISTIAN',
#   'JUNG',
#   'CHRISTIAN.JUNG@sakilacustomer.org',
#   540,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (535,
#   1,
#   'JAVIER',
#   'ELROD',
#   'JAVIER.ELROD@sakilacustomer.org',
#   541,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (536,
#   2,
#   'FERNANDO',
#   'CHURCHILL',
#   'FERNANDO.CHURCHILL@sakilacustomer.org',
#   542,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (537,
#   2,
#   'CLINTON',
#   'BUFORD',
#   'CLINTON.BUFORD@sakilacustomer.org',
#   543,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (538,
#   2,
#   'TED',
#   'BREAUX',
#   'TED.BREAUX@sakilacustomer.org',
#   544,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (539,
#   1,
#   'MATHEW',
#   'BOLIN',
#   'MATHEW.BOLIN@sakilacustomer.org',
#   545,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (540,
#   1,
#   'TYRONE',
#   'ASHER',
#   'TYRONE.ASHER@sakilacustomer.org',
#   546,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (541,
#   2,
#   'DARREN',
#   'WINDHAM',
#   'DARREN.WINDHAM@sakilacustomer.org',
#   547,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (542,
#   2,
#   'LONNIE',
#   'TIRADO',
#   'LONNIE.TIRADO@sakilacustomer.org',
#   548,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (543,
#   1,
#   'LANCE',
#   'PEMBERTON',
#   'LANCE.PEMBERTON@sakilacustomer.org',
#   549,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (544,
#   2,
#   'CODY',
#   'NOLEN',
#   'CODY.NOLEN@sakilacustomer.org',
#   550,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (545,
#   2,
#   'JULIO',
#   'NOLAND',
#   'JULIO.NOLAND@sakilacustomer.org',
#   551,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (546,
#   1,
#   'KELLY',
#   'KNOTT',
#   'KELLY.KNOTT@sakilacustomer.org',
#   552,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (547,
#   1,
#   'KURT',
#   'EMMONS',
#   'KURT.EMMONS@sakilacustomer.org',
#   553,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (548,
#   1,
#   'ALLAN',
#   'CORNISH',
#   'ALLAN.CORNISH@sakilacustomer.org',
#   554,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (549,
#   1,
#   'NELSON',
#   'CHRISTENSON',
#   'NELSON.CHRISTENSON@sakilacustomer.org',
#   555,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (550,
#   2,
#   'GUY',
#   'BROWNLEE',
#   'GUY.BROWNLEE@sakilacustomer.org',
#   556,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (551,
#   2,
#   'CLAYTON',
#   'BARBEE',
#   'CLAYTON.BARBEE@sakilacustomer.org',
#   557,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (552,
#   2,
#   'HUGH',
#   'WALDROP',
#   'HUGH.WALDROP@sakilacustomer.org',
#   558,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (553,
#   1,
#   'MAX',
#   'PITT',
#   'MAX.PITT@sakilacustomer.org',
#   559,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (554,
#   1,
#   'DWAYNE',
#   'OLVERA',
#   'DWAYNE.OLVERA@sakilacustomer.org',
#   560,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (555,
#   1,
#   'DWIGHT',
#   'LOMBARDI',
#   'DWIGHT.LOMBARDI@sakilacustomer.org',
#   561,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (556,
#   2,
#   'ARMANDO',
#   'GRUBER',
#   'ARMANDO.GRUBER@sakilacustomer.org',
#   562,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (557,
#   1,
#   'FELIX',
#   'GAFFNEY',
#   'FELIX.GAFFNEY@sakilacustomer.org',
#   563,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (558,
#   1,
#   'JIMMIE',
#   'EGGLESTON',
#   'JIMMIE.EGGLESTON@sakilacustomer.org',
#   564,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (559,
#   2,
#   'EVERETT',
#   'BANDA',
#   'EVERETT.BANDA@sakilacustomer.org',
#   565,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (560,
#   1,
#   'JORDAN',
#   'ARCHULETA',
#   'JORDAN.ARCHULETA@sakilacustomer.org',
#   566,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (561,
#   2,
#   'IAN',
#   'STILL',
#   'IAN.STILL@sakilacustomer.org',
#   567,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (562,
#   1,
#   'WALLACE',
#   'SLONE',
#   'WALLACE.SLONE@sakilacustomer.org',
#   568,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (563,
#   2,
#   'KEN',
#   'PREWITT',
#   'KEN.PREWITT@sakilacustomer.org',
#   569,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (564,
#   2,
#   'BOB',
#   'PFEIFFER',
#   'BOB.PFEIFFER@sakilacustomer.org',
#   570,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (565,
#   2,
#   'JAIME',
#   'NETTLES',
#   'JAIME.NETTLES@sakilacustomer.org',
#   571,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (566,
#   1,
#   'CASEY',
#   'MENA',
#   'CASEY.MENA@sakilacustomer.org',
#   572,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (567,
#   2,
#   'ALFREDO',
#   'MCADAMS',
#   'ALFREDO.MCADAMS@sakilacustomer.org',
#   573,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (568,
#   2,
#   'ALBERTO',
#   'HENNING',
#   'ALBERTO.HENNING@sakilacustomer.org',
#   574,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (569,
#   2,
#   'DAVE',
#   'GARDINER',
#   'DAVE.GARDINER@sakilacustomer.org',
#   575,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (570,
#   2,
#   'IVAN',
#   'CROMWELL',
#   'IVAN.CROMWELL@sakilacustomer.org',
#   576,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (571,
#   2,
#   'JOHNNIE',
#   'CHISHOLM',
#   'JOHNNIE.CHISHOLM@sakilacustomer.org',
#   577,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (572,
#   1,
#   'SIDNEY',
#   'BURLESON',
#   'SIDNEY.BURLESON@sakilacustomer.org',
#   578,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (573,
#   1,
#   'BYRON',
#   'BOX',
#   'BYRON.BOX@sakilacustomer.org',
#   579,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (574,
#   2,
#   'JULIAN',
#   'VEST',
#   'JULIAN.VEST@sakilacustomer.org',
#   580,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (575,
#   2,
#   'ISAAC',
#   'OGLESBY',
#   'ISAAC.OGLESBY@sakilacustomer.org',
#   581,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (576,
#   2,
#   'MORRIS',
#   'MCCARTER',
#   'MORRIS.MCCARTER@sakilacustomer.org',
#   582,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (577,
#   2,
#   'CLIFTON',
#   'MALCOLM',
#   'CLIFTON.MALCOLM@sakilacustomer.org',
#   583,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (578,
#   2,
#   'WILLARD',
#   'LUMPKIN',
#   'WILLARD.LUMPKIN@sakilacustomer.org',
#   584,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (579,
#   2,
#   'DARYL',
#   'LARUE',
#   'DARYL.LARUE@sakilacustomer.org',
#   585,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (580,
#   1,
#   'ROSS',
#   'GREY',
#   'ROSS.GREY@sakilacustomer.org',
#   586,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (581,
#   1,
#   'VIRGIL',
#   'WOFFORD',
#   'VIRGIL.WOFFORD@sakilacustomer.org',
#   587,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (582,
#   2,
#   'ANDY',
#   'VANHORN',
#   'ANDY.VANHORN@sakilacustomer.org',
#   588,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (583,
#   1,
#   'MARSHALL',
#   'THORN',
#   'MARSHALL.THORN@sakilacustomer.org',
#   589,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (584,
#   2,
#   'SALVADOR',
#   'TEEL',
#   'SALVADOR.TEEL@sakilacustomer.org',
#   590,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (585,
#   1,
#   'PERRY',
#   'SWAFFORD',
#   'PERRY.SWAFFORD@sakilacustomer.org',
#   591,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (586,
#   1,
#   'KIRK',
#   'STCLAIR',
#   'KIRK.STCLAIR@sakilacustomer.org',
#   592,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (587,
#   1,
#   'SERGIO',
#   'STANFIELD',
#   'SERGIO.STANFIELD@sakilacustomer.org',
#   593,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (588,
#   1,
#   'MARION',
#   'OCAMPO',
#   'MARION.OCAMPO@sakilacustomer.org',
#   594,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (589,
#   1,
#   'TRACY',
#   'HERRMANN',
#   'TRACY.HERRMANN@sakilacustomer.org',
#   595,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (590,
#   2,
#   'SETH',
#   'HANNON',
#   'SETH.HANNON@sakilacustomer.org',
#   596,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (591,
#   1,
#   'KENT',
#   'ARSENAULT',
#   'KENT.ARSENAULT@sakilacustomer.org',
#   597,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (592,
#   1,
#   'TERRANCE',
#   'ROUSH',
#   'TERRANCE.ROUSH@sakilacustomer.org',
#   598,
#   0,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (593,
#   2,
#   'RENE',
#   'MCALISTER',
#   'RENE.MCALISTER@sakilacustomer.org',
#   599,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (594,
#   1,
#   'EDUARDO',
#   'HIATT',
#   'EDUARDO.HIATT@sakilacustomer.org',
#   600,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (595,
#   1,
#   'TERRENCE',
#   'GUNDERSON',
#   'TERRENCE.GUNDERSON@sakilacustomer.org',
#   601,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (596,
#   1,
#   'ENRIQUE',
#   'FORSYTHE',
#   'ENRIQUE.FORSYTHE@sakilacustomer.org',
#   602,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (597,
#   1,
#   'FREDDIE',
#   'DUGGAN',
#   'FREDDIE.DUGGAN@sakilacustomer.org',
#   603,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (598,
#   1,
#   'WADE',
#   'DELVALLE',
#   'WADE.DELVALLE@sakilacustomer.org',
#   604,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (599,
#   2,
#   'AUSTIN',
#   'CINTRON',
#   'AUSTIN.CINTRON@sakilacustomer.org',
#   605,
#   1,
#   datetime.datetime(2006, 2, 14, 22, 4, 37),
#   datetime.datetime(2006, 2, 15, 4, 57, 20))]

# %%
customers = pd.DataFrame(q_result)
customers
# Out:
#        0  1          2          3                                      4    5  \
# 0      1  1       MARY      SMITH          MARY.SMITH@sakilacustomer.org    5
# 1      2  1   PATRICIA    JOHNSON    PATRICIA.JOHNSON@sakilacustomer.org    6
# 2      3  1      LINDA   WILLIAMS      LINDA.WILLIAMS@sakilacustomer.org    7
# 3      4  2    BARBARA      JONES       BARBARA.JONES@sakilacustomer.org    8
# 4      5  1  ELIZABETH      BROWN     ELIZABETH.BROWN@sakilacustomer.org    9
# ..   ... ..        ...        ...                                    ...  ...
# 594  595  1   TERRENCE  GUNDERSON  TERRENCE.GUNDERSON@sakilacustomer.org  601
# 595  596  1    ENRIQUE   FORSYTHE    ENRIQUE.FORSYTHE@sakilacustomer.org  602
# 596  597  1    FREDDIE     DUGGAN      FREDDIE.DUGGAN@sakilacustomer.org  603
# 597  598  1       WADE   DELVALLE       WADE.DELVALLE@sakilacustomer.org  604
# 598  599  2     AUSTIN    CINTRON      AUSTIN.CINTRON@sakilacustomer.org  605
#
#      6                   7                   8
# 0    1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 1    1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 2    1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 3    1 2006-02-14 22:04:36 2006-02-15 04:57:20
# 4    1 2006-02-14 22:04:36 2006-02-15 04:57:20
# ..  ..                 ...                 ...
# 594  1 2006-02-14 22:04:37 2006-02-15 04:57:20
# 595  1 2006-02-14 22:04:37 2006-02-15 04:57:20
# 596  1 2006-02-14 22:04:37 2006-02-15 04:57:20
# 597  1 2006-02-14 22:04:37 2006-02-15 04:57:20
# 598  1 2006-02-14 22:04:37 2006-02-15 04:57:20
#
# [599 rows x 9 columns]

# %%
query = ('''SELECT customer.customer_id, customer.first_name, customer.last_name, rental.rental_id, rental.rental_date, rental.return_date
FROM sakila.customer
JOIN rental ON customer.customer_id = rental.customer_id;''')

# %%
cursor.execute(query)

# %%
q_result = cursor.fetchall()
q_result
# Out:
# [(1,
#   'MARY',
#   'SMITH',
#   76,
#   datetime.datetime(2005, 5, 25, 11, 30, 37),
#   datetime.datetime(2005, 6, 3, 12, 0, 37)),
#  (1,
#   'MARY',
#   'SMITH',
#   573,
#   datetime.datetime(2005, 5, 28, 10, 35, 23),
#   datetime.datetime(2005, 6, 3, 6, 32, 23)),
#  (1,
#   'MARY',
#   'SMITH',
#   1185,
#   datetime.datetime(2005, 6, 15, 0, 54, 12),
#   datetime.datetime(2005, 6, 23, 2, 42, 12)),
#  (1,
#   'MARY',
#   'SMITH',
#   1422,
#   datetime.datetime(2005, 6, 15, 18, 2, 53),
#   datetime.datetime(2005, 6, 19, 15, 54, 53)),
#  (1,
#   'MARY',
#   'SMITH',
#   1476,
#   datetime.datetime(2005, 6, 15, 21, 8, 46),
#   datetime.datetime(2005, 6, 25, 2, 26, 46)),
#  (1,
#   'MARY',
#   'SMITH',
#   1725,
#   datetime.datetime(2005, 6, 16, 15, 18, 57),
#   datetime.datetime(2005, 6, 17, 21, 5, 57)),
#  (1,
#   'MARY',
#   'SMITH',
#   2308,
#   datetime.datetime(2005, 6, 18, 8, 41, 48),
#   datetime.datetime(2005, 6, 22, 3, 36, 48)),
#  (1,
#   'MARY',
#   'SMITH',
#   2363,
#   datetime.datetime(2005, 6, 18, 13, 33, 59),
#   datetime.datetime(2005, 6, 19, 17, 40, 59)),
#  (1,
#   'MARY',
#   'SMITH',
#   3284,
#   datetime.datetime(2005, 6, 21, 6, 24, 45),
#   datetime.datetime(2005, 6, 28, 3, 28, 45)),
#  (1,
#   'MARY',
#   'SMITH',
#   4526,
#   datetime.datetime(2005, 7, 8, 3, 17, 5),
#   datetime.datetime(2005, 7, 14, 1, 19, 5)),
#  (1,
#   'MARY',
#   'SMITH',
#   4611,
#   datetime.datetime(2005, 7, 8, 7, 33, 56),
#   datetime.datetime(2005, 7, 12, 13, 25, 56)),
#  (1,
#   'MARY',
#   'SMITH',
#   5244,
#   datetime.datetime(2005, 7, 9, 13, 24, 7),
#   datetime.datetime(2005, 7, 14, 14, 1, 7)),
#  (1,
#   'MARY',
#   'SMITH',
#   5326,
#   datetime.datetime(2005, 7, 9, 16, 38, 1),
#   datetime.datetime(2005, 7, 13, 18, 2, 1)),
#  (1,
#   'MARY',
#   'SMITH',
#   6163,
#   datetime.datetime(2005, 7, 11, 10, 13, 46),
#   datetime.datetime(2005, 7, 19, 13, 15, 46)),
#  (1,
#   'MARY',
#   'SMITH',
#   7273,
#   datetime.datetime(2005, 7, 27, 11, 31, 22),
#   datetime.datetime(2005, 7, 31, 6, 50, 22)),
#  (1,
#   'MARY',
#   'SMITH',
#   7841,
#   datetime.datetime(2005, 7, 28, 9, 4, 45),
#   datetime.datetime(2005, 7, 30, 12, 37, 45)),
#  (1,
#   'MARY',
#   'SMITH',
#   8033,
#   datetime.datetime(2005, 7, 28, 16, 18, 23),
#   datetime.datetime(2005, 7, 30, 17, 56, 23)),
#  (1,
#   'MARY',
#   'SMITH',
#   8074,
#   datetime.datetime(2005, 7, 28, 17, 33, 39),
#   datetime.datetime(2005, 7, 29, 20, 17, 39)),
#  (1,
#   'MARY',
#   'SMITH',
#   8116,
#   datetime.datetime(2005, 7, 28, 19, 20, 7),
#   datetime.datetime(2005, 7, 29, 22, 54, 7)),
#  (1,
#   'MARY',
#   'SMITH',
#   8326,
#   datetime.datetime(2005, 7, 29, 3, 58, 49),
#   datetime.datetime(2005, 8, 1, 5, 16, 49)),
#  (1,
#   'MARY',
#   'SMITH',
#   9571,
#   datetime.datetime(2005, 7, 31, 2, 42, 18),
#   datetime.datetime(2005, 8, 2, 23, 26, 18)),
#  (1,
#   'MARY',
#   'SMITH',
#   10437,
#   datetime.datetime(2005, 8, 1, 8, 51, 4),
#   datetime.datetime(2005, 8, 10, 12, 12, 4)),
#  (1,
#   'MARY',
#   'SMITH',
#   11299,
#   datetime.datetime(2005, 8, 2, 15, 36, 52),
#   datetime.datetime(2005, 8, 10, 16, 40, 52)),
#  (1,
#   'MARY',
#   'SMITH',
#   11367,
#   datetime.datetime(2005, 8, 2, 18, 1, 38),
#   datetime.datetime(2005, 8, 4, 13, 19, 38)),
#  (1,
#   'MARY',
#   'SMITH',
#   11824,
#   datetime.datetime(2005, 8, 17, 12, 37, 54),
#   datetime.datetime(2005, 8, 19, 10, 11, 54)),
#  (1,
#   'MARY',
#   'SMITH',
#   12250,
#   datetime.datetime(2005, 8, 18, 3, 57, 29),
#   datetime.datetime(2005, 8, 22, 23, 5, 29)),
#  (1,
#   'MARY',
#   'SMITH',
#   13068,
#   datetime.datetime(2005, 8, 19, 9, 55, 16),
#   datetime.datetime(2005, 8, 20, 14, 44, 16)),
#  (1,
#   'MARY',
#   'SMITH',
#   13176,
#   datetime.datetime(2005, 8, 19, 13, 56, 54),
#   datetime.datetime(2005, 8, 23, 8, 50, 54)),
#  (1,
#   'MARY',
#   'SMITH',
#   14762,
#   datetime.datetime(2005, 8, 21, 23, 33, 57),
#   datetime.datetime(2005, 8, 23, 1, 30, 57)),
#  (1,
#   'MARY',
#   'SMITH',
#   14825,
#   datetime.datetime(2005, 8, 22, 1, 27, 57),
#   datetime.datetime(2005, 8, 27, 7, 1, 57)),
#  (1,
#   'MARY',
#   'SMITH',
#   15298,
#   datetime.datetime(2005, 8, 22, 19, 41, 37),
#   datetime.datetime(2005, 8, 28, 22, 49, 37)),
#  (1,
#   'MARY',
#   'SMITH',
#   15315,
#   datetime.datetime(2005, 8, 22, 20, 3, 46),
#   datetime.datetime(2005, 8, 30, 1, 51, 46)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   320,
#   datetime.datetime(2005, 5, 27, 0, 9, 24),
#   datetime.datetime(2005, 5, 28, 4, 30, 24)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   2128,
#   datetime.datetime(2005, 6, 17, 20, 54, 58),
#   datetime.datetime(2005, 6, 24, 0, 41, 58)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   5636,
#   datetime.datetime(2005, 7, 10, 6, 31, 24),
#   datetime.datetime(2005, 7, 13, 2, 36, 24)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   5755,
#   datetime.datetime(2005, 7, 10, 12, 38, 56),
#   datetime.datetime(2005, 7, 19, 17, 2, 56)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   7346,
#   datetime.datetime(2005, 7, 27, 14, 30, 42),
#   datetime.datetime(2005, 8, 2, 16, 48, 42)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   7376,
#   datetime.datetime(2005, 7, 27, 15, 23, 2),
#   datetime.datetime(2005, 8, 4, 10, 35, 2)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   7459,
#   datetime.datetime(2005, 7, 27, 18, 40, 20),
#   datetime.datetime(2005, 8, 2, 21, 7, 20)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   8230,
#   datetime.datetime(2005, 7, 29, 0, 12, 59),
#   datetime.datetime(2005, 8, 6, 19, 52, 59)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   8598,
#   datetime.datetime(2005, 7, 29, 12, 56, 59),
#   datetime.datetime(2005, 8, 1, 8, 39, 59)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   8705,
#   datetime.datetime(2005, 7, 29, 17, 14, 29),
#   datetime.datetime(2005, 8, 2, 16, 1, 29)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   9031,
#   datetime.datetime(2005, 7, 30, 6, 6, 10),
#   datetime.datetime(2005, 8, 4, 10, 45, 10)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   9236,
#   datetime.datetime(2005, 7, 30, 13, 47, 43),
#   datetime.datetime(2005, 8, 8, 18, 52, 43)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   9248,
#   datetime.datetime(2005, 7, 30, 14, 14, 11),
#   datetime.datetime(2005, 8, 5, 11, 19, 11)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   9296,
#   datetime.datetime(2005, 7, 30, 16, 21, 13),
#   datetime.datetime(2005, 8, 8, 11, 57, 13)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   9465,
#   datetime.datetime(2005, 7, 30, 22, 39, 53),
#   datetime.datetime(2005, 8, 6, 16, 43, 53)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   10136,
#   datetime.datetime(2005, 7, 31, 21, 58, 56),
#   datetime.datetime(2005, 8, 3, 19, 44, 56)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   10466,
#   datetime.datetime(2005, 8, 1, 9, 45, 26),
#   datetime.datetime(2005, 8, 6, 6, 28, 26)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   10918,
#   datetime.datetime(2005, 8, 2, 2, 10, 56),
#   datetime.datetime(2005, 8, 2, 21, 23, 56)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   11087,
#   datetime.datetime(2005, 8, 2, 7, 41, 41),
#   datetime.datetime(2005, 8, 10, 10, 37, 41)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   11177,
#   datetime.datetime(2005, 8, 2, 10, 43, 48),
#   datetime.datetime(2005, 8, 10, 10, 55, 48)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   11256,
#   datetime.datetime(2005, 8, 2, 13, 44, 53),
#   datetime.datetime(2005, 8, 4, 16, 39, 53)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   11614,
#   datetime.datetime(2005, 8, 17, 3, 52, 18),
#   datetime.datetime(2005, 8, 20, 7, 4, 18)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   12963,
#   datetime.datetime(2005, 8, 19, 6, 26, 4),
#   datetime.datetime(2005, 8, 23, 11, 37, 4)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   14475,
#   datetime.datetime(2005, 8, 21, 13, 24, 32),
#   datetime.datetime(2005, 8, 27, 8, 59, 32)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   14743,
#   datetime.datetime(2005, 8, 21, 22, 41, 56),
#   datetime.datetime(2005, 8, 29, 0, 18, 56)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   15145,
#   datetime.datetime(2005, 8, 22, 13, 53, 4),
#   datetime.datetime(2005, 8, 31, 15, 51, 4)),
#  (2,
#   'PATRICIA',
#   'JOHNSON',
#   15907,
#   datetime.datetime(2005, 8, 23, 17, 39, 35),
#   datetime.datetime(2005, 8, 25, 23, 23, 35)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   435,
#   datetime.datetime(2005, 5, 27, 17, 17, 9),
#   datetime.datetime(2005, 6, 2, 11, 20, 9)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   830,
#   datetime.datetime(2005, 5, 29, 22, 43, 55),
#   datetime.datetime(2005, 6, 1, 17, 43, 55)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   1546,
#   datetime.datetime(2005, 6, 16, 1, 34, 5),
#   datetime.datetime(2005, 6, 24, 4, 27, 5)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   1726,
#   datetime.datetime(2005, 6, 16, 15, 19, 10),
#   datetime.datetime(2005, 6, 25, 11, 39, 10)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   1911,
#   datetime.datetime(2005, 6, 17, 5, 15, 15),
#   datetime.datetime(2005, 6, 24, 11, 5, 15)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   2628,
#   datetime.datetime(2005, 6, 19, 8, 34, 53),
#   datetime.datetime(2005, 6, 28, 4, 19, 53)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   4180,
#   datetime.datetime(2005, 7, 7, 10, 23, 25),
#   datetime.datetime(2005, 7, 10, 13, 18, 25)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   4725,
#   datetime.datetime(2005, 7, 8, 12, 47, 11),
#   datetime.datetime(2005, 7, 15, 9, 8, 11)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   7096,
#   datetime.datetime(2005, 7, 27, 4, 54, 42),
#   datetime.datetime(2005, 8, 3, 1, 42, 42)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   7503,
#   datetime.datetime(2005, 7, 27, 20, 23, 12),
#   datetime.datetime(2005, 8, 5, 18, 46, 12)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   7703,
#   datetime.datetime(2005, 7, 28, 3, 59, 21),
#   datetime.datetime(2005, 8, 5, 8, 52, 21)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   7724,
#   datetime.datetime(2005, 7, 28, 4, 46, 30),
#   datetime.datetime(2005, 8, 4, 8, 41, 30)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   7911,
#   datetime.datetime(2005, 7, 28, 11, 46, 45),
#   datetime.datetime(2005, 7, 29, 7, 19, 45)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   8086,
#   datetime.datetime(2005, 7, 28, 18, 17, 14),
#   datetime.datetime(2005, 7, 30, 18, 22, 14)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   8545,
#   datetime.datetime(2005, 7, 29, 11, 7, 4),
#   datetime.datetime(2005, 8, 6, 13, 30, 4)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   9226,
#   datetime.datetime(2005, 7, 30, 13, 31, 20),
#   datetime.datetime(2005, 8, 6, 16, 42, 20)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   9443,
#   datetime.datetime(2005, 7, 30, 21, 45, 46),
#   datetime.datetime(2005, 8, 5, 21, 22, 46)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   9595,
#   datetime.datetime(2005, 7, 31, 3, 27, 58),
#   datetime.datetime(2005, 8, 3, 5, 58, 58)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   9816,
#   datetime.datetime(2005, 7, 31, 11, 32, 58),
#   datetime.datetime(2005, 8, 4, 17, 12, 58)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   10597,
#   datetime.datetime(2005, 8, 1, 14, 19, 48),
#   datetime.datetime(2005, 8, 8, 20, 1, 48)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   12556,
#   datetime.datetime(2005, 8, 18, 14, 49, 55),
#   datetime.datetime(2005, 8, 24, 15, 20, 55)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   13403,
#   datetime.datetime(2005, 8, 19, 22, 18, 7),
#   datetime.datetime(2005, 8, 27, 19, 23, 7)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   13610,
#   datetime.datetime(2005, 8, 20, 6, 14, 12),
#   datetime.datetime(2005, 8, 26, 0, 44, 12)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   14699,
#   datetime.datetime(2005, 8, 21, 20, 50, 48),
#   datetime.datetime(2005, 8, 29, 18, 8, 48)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   15038,
#   datetime.datetime(2005, 8, 22, 9, 37, 27),
#   datetime.datetime(2005, 8, 23, 14, 39, 27)),
#  (3,
#   'LINDA',
#   'WILLIAMS',
#   15619,
#   datetime.datetime(2005, 8, 23, 7, 10, 14),
#   datetime.datetime(2005, 8, 26, 7, 21, 14)),
#  (4,
#   'BARBARA',
#   'JONES',
#   1297,
#   datetime.datetime(2005, 6, 15, 9, 31, 28),
#   datetime.datetime(2005, 6, 19, 4, 33, 28)),
#  (4,
#   'BARBARA',
#   'JONES',
#   1633,
#   datetime.datetime(2005, 6, 16, 8, 8, 40),
#   datetime.datetime(2005, 6, 17, 11, 12, 40)),
#  (4,
#   'BARBARA',
#   'JONES',
#   1707,
#   datetime.datetime(2005, 6, 16, 14, 1, 27),
#   datetime.datetime(2005, 6, 18, 9, 35, 27)),
#  (4,
#   'BARBARA',
#   'JONES',
#   1735,
#   datetime.datetime(2005, 6, 16, 15, 51, 52),
#   datetime.datetime(2005, 6, 20, 13, 27, 52)),
#  (4,
#   'BARBARA',
#   'JONES',
#   2043,
#   datetime.datetime(2005, 6, 17, 14, 31, 12),
#   datetime.datetime(2005, 6, 19, 11, 4, 12)),
#  (4,
#   'BARBARA',
#   'JONES',
#   2642,
#   datetime.datetime(2005, 6, 19, 9, 39, 1),
#   datetime.datetime(2005, 6, 25, 8, 33, 1)),
#  (4,
#   'BARBARA',
#   'JONES',
#   7660,
#   datetime.datetime(2005, 7, 28, 2, 10, 10),
#   datetime.datetime(2005, 7, 30, 4, 29, 10)),
#  (4,
#   'BARBARA',
#   'JONES',
#   7718,
#   datetime.datetime(2005, 7, 28, 4, 37, 59),
#   datetime.datetime(2005, 7, 29, 9, 20, 59)),
#  (4,
#   'BARBARA',
#   'JONES',
#   8741,
#   datetime.datetime(2005, 7, 29, 18, 44, 57),
#   datetime.datetime(2005, 8, 3, 18, 25, 57)),
#  (4,
#   'BARBARA',
#   'JONES',
#   9100,
#   datetime.datetime(2005, 7, 30, 8, 46, 9),
#   datetime.datetime(2005, 8, 5, 10, 34, 9)),
#  (4,
#   'BARBARA',
#   'JONES',
#   9371,
#   datetime.datetime(2005, 7, 30, 18, 58),
#   datetime.datetime(2005, 8, 3, 15, 14)),
#  (4,
#   'BARBARA',
#   'JONES',
#   11069,
#   datetime.datetime(2005, 8, 2, 7, 9, 34),
#   datetime.datetime(2005, 8, 8, 8, 39, 34)),
#  (4,
#   'BARBARA',
#   'JONES',
#   11110,
#   datetime.datetime(2005, 8, 2, 8, 20, 31),
#   datetime.datetime(2005, 8, 4, 5, 6, 31)),
#  (4,
#   'BARBARA',
#   'JONES',
#   11529,
#   datetime.datetime(2005, 8, 17, 0, 28, 1),
#   datetime.datetime(2005, 8, 19, 4, 47, 1)),
#  (4,
#   'BARBARA',
#   'JONES',
#   12151,
#   datetime.datetime(2005, 8, 18, 0, 14, 3),
#   datetime.datetime(2005, 8, 18, 23, 52, 3)),
#  (4,
#   'BARBARA',
#   'JONES',
#   12294,
#   datetime.datetime(2005, 8, 18, 5, 14, 44),
#   datetime.datetime(2005, 8, 27, 1, 32, 44)),
#  (4,
#   'BARBARA',
#   'JONES',
#   12856,
#   datetime.datetime(2005, 8, 19, 2, 19, 13),
#   datetime.datetime(2005, 8, 23, 7, 49, 13)),
#  (4,
#   'BARBARA',
#   'JONES',
#   13704,
#   datetime.datetime(2005, 8, 20, 9, 32, 4),
#   datetime.datetime(2005, 8, 23, 14, 29, 4)),
#  (4,
#   'BARBARA',
#   'JONES',
#   13807,
#   datetime.datetime(2005, 8, 20, 12, 55, 40),
#   datetime.datetime(2005, 8, 28, 9, 6, 40)),
#  (4,
#   'BARBARA',
#   'JONES',
#   14225,
#   datetime.datetime(2005, 8, 21, 4, 53, 37),
#   datetime.datetime(2005, 8, 25, 23, 39, 37)),
#  (4,
#   'BARBARA',
#   'JONES',
#   15147,
#   datetime.datetime(2005, 8, 22, 13, 58, 23),
#   datetime.datetime(2005, 8, 28, 14, 33, 23)),
#  (4,
#   'BARBARA',
#   'JONES',
#   15635,
#   datetime.datetime(2005, 8, 23, 7, 43),
#   datetime.datetime(2005, 8, 27, 10, 47)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   731,
#   datetime.datetime(2005, 5, 29, 7, 25, 16),
#   datetime.datetime(2005, 5, 30, 5, 21, 16)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   1085,
#   datetime.datetime(2005, 5, 31, 11, 15, 43),
#   datetime.datetime(2005, 6, 7, 12, 2, 43)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   1142,
#   datetime.datetime(2005, 5, 31, 19, 46, 38),
#   datetime.datetime(2005, 6, 5, 14, 3, 38)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   1502,
#   datetime.datetime(2005, 6, 15, 22, 3, 14),
#   datetime.datetime(2005, 6, 23, 18, 42, 14)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   1631,
#   datetime.datetime(2005, 6, 16, 8, 1, 2),
#   datetime.datetime(2005, 6, 19, 9, 4, 2)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   2063,
#   datetime.datetime(2005, 6, 17, 15, 56, 53),
#   datetime.datetime(2005, 6, 21, 14, 19, 53)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   2570,
#   datetime.datetime(2005, 6, 19, 4, 20, 13),
#   datetime.datetime(2005, 6, 25, 7, 0, 13)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   3126,
#   datetime.datetime(2005, 6, 20, 18, 38, 22),
#   datetime.datetime(2005, 6, 26, 0, 0, 22)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   3677,
#   datetime.datetime(2005, 7, 6, 9, 11, 58),
#   datetime.datetime(2005, 7, 8, 10, 50, 58)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   4889,
#   datetime.datetime(2005, 7, 8, 20, 4, 43),
#   datetime.datetime(2005, 7, 13, 17, 57, 43)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   5016,
#   datetime.datetime(2005, 7, 9, 1, 57, 57),
#   datetime.datetime(2005, 7, 9, 22, 7, 57)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   5118,
#   datetime.datetime(2005, 7, 9, 7, 13, 52),
#   datetime.datetime(2005, 7, 18, 5, 18, 52)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   5156,
#   datetime.datetime(2005, 7, 9, 8, 51, 42),
#   datetime.datetime(2005, 7, 15, 3, 59, 42)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   5721,
#   datetime.datetime(2005, 7, 10, 11, 9, 35),
#   datetime.datetime(2005, 7, 17, 16, 41, 35)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   6042,
#   datetime.datetime(2005, 7, 11, 3, 17, 4),
#   datetime.datetime(2005, 7, 19, 7, 8, 4)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   6663,
#   datetime.datetime(2005, 7, 12, 11, 27, 35),
#   datetime.datetime(2005, 7, 21, 16, 35, 35)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   6685,
#   datetime.datetime(2005, 7, 12, 12, 16, 28),
#   datetime.datetime(2005, 7, 19, 17, 3, 28)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   7293,
#   datetime.datetime(2005, 7, 27, 12, 37, 28),
#   datetime.datetime(2005, 7, 30, 15, 12, 28)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   7652,
#   datetime.datetime(2005, 7, 28, 1, 50, 29),
#   datetime.datetime(2005, 7, 30, 22, 23, 29)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   7829,
#   datetime.datetime(2005, 7, 28, 8, 43, 39),
#   datetime.datetime(2005, 8, 4, 14, 33, 39)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   8263,
#   datetime.datetime(2005, 7, 29, 1, 11, 23),
#   datetime.datetime(2005, 7, 31, 1, 53, 23)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   8978,
#   datetime.datetime(2005, 7, 30, 4, 14, 28),
#   datetime.datetime(2005, 8, 6, 9, 8, 28)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   9493,
#   datetime.datetime(2005, 7, 30, 23, 52, 30),
#   datetime.datetime(2005, 8, 8, 5, 22, 30)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   9888,
#   datetime.datetime(2005, 7, 31, 14, 0, 53),
#   datetime.datetime(2005, 8, 8, 18, 51, 53)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   10609,
#   datetime.datetime(2005, 8, 1, 14, 48, 45),
#   datetime.datetime(2005, 8, 4, 13, 41, 45)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   10625,
#   datetime.datetime(2005, 8, 1, 15, 27, 10),
#   datetime.datetime(2005, 8, 2, 13, 16, 10)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   11001,
#   datetime.datetime(2005, 8, 2, 4, 56, 45),
#   datetime.datetime(2005, 8, 11, 8, 4, 45)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   11179,
#   datetime.datetime(2005, 8, 2, 10, 50, 6),
#   datetime.datetime(2005, 8, 4, 5, 24, 6)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   11930,
#   datetime.datetime(2005, 8, 17, 16, 28, 53),
#   datetime.datetime(2005, 8, 25, 10, 31, 53)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   12145,
#   datetime.datetime(2005, 8, 18, 0, 10, 4),
#   datetime.datetime(2005, 8, 26, 0, 51, 4)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   12797,
#   datetime.datetime(2005, 8, 19, 0, 24, 8),
#   datetime.datetime(2005, 8, 21, 22, 53, 8)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   13063,
#   datetime.datetime(2005, 8, 19, 9, 45, 41),
#   datetime.datetime(2005, 8, 24, 9, 11, 41)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   13209,
#   datetime.datetime(2006, 2, 14, 15, 16, 3),
#   None),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   13877,
#   datetime.datetime(2005, 8, 20, 15, 16, 18),
#   datetime.datetime(2005, 8, 22, 18, 20, 18)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   14053,
#   datetime.datetime(2005, 8, 20, 22, 13, 59),
#   datetime.datetime(2005, 8, 26, 20, 50, 59)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   14430,
#   datetime.datetime(2005, 8, 21, 11, 31, 11),
#   datetime.datetime(2005, 8, 26, 6, 29, 11)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   14494,
#   datetime.datetime(2005, 8, 21, 14, 2, 50),
#   datetime.datetime(2005, 8, 22, 16, 45, 50)),
#  (5,
#   'ELIZABETH',
#   'BROWN',
#   15232,
#   datetime.datetime(2005, 8, 22, 17, 37, 2),
#   datetime.datetime(2005, 8, 25, 18, 45, 2)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   57,
#   datetime.datetime(2005, 5, 25, 8, 43, 32),
#   datetime.datetime(2005, 5, 29, 6, 42, 32)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   577,
#   datetime.datetime(2005, 5, 28, 11, 9, 14),
#   datetime.datetime(2005, 6, 1, 13, 27, 14)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   916,
#   datetime.datetime(2005, 5, 30, 11, 25, 1),
#   datetime.datetime(2005, 5, 31, 9, 6, 1)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   1575,
#   datetime.datetime(2005, 6, 16, 3, 41, 38),
#   datetime.datetime(2005, 6, 22, 3, 1, 38)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   1841,
#   datetime.datetime(2005, 6, 16, 23, 44, 13),
#   datetime.datetime(2005, 6, 22, 4, 9, 13)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   1966,
#   datetime.datetime(2005, 6, 17, 9, 19, 45),
#   datetime.datetime(2005, 6, 20, 11, 19, 45)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   2345,
#   datetime.datetime(2005, 6, 18, 12, 3, 23),
#   datetime.datetime(2005, 6, 22, 14, 25, 23)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   3983,
#   datetime.datetime(2005, 7, 6, 23, 14, 21),
#   datetime.datetime(2005, 7, 12, 17, 55, 21)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   4278,
#   datetime.datetime(2005, 7, 7, 14, 53, 24),
#   datetime.datetime(2005, 7, 13, 14, 21, 24)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   5553,
#   datetime.datetime(2005, 7, 10, 3, 3, 35),
#   datetime.datetime(2005, 7, 14, 7, 49, 35)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   6211,
#   datetime.datetime(2005, 7, 11, 12, 39, 1),
#   datetime.datetime(2005, 7, 20, 15, 59, 1)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   6248,
#   datetime.datetime(2005, 7, 11, 15, 1, 54),
#   datetime.datetime(2005, 7, 19, 16, 58, 54)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   6686,
#   datetime.datetime(2005, 7, 12, 12, 18, 38),
#   datetime.datetime(2005, 7, 13, 17, 56, 38)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   7099,
#   datetime.datetime(2005, 7, 27, 5, 3, 44),
#   datetime.datetime(2005, 7, 29, 0, 12, 44)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   7136,
#   datetime.datetime(2005, 7, 27, 6, 38, 25),
#   datetime.datetime(2005, 8, 3, 5, 13, 25)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   8101,
#   datetime.datetime(2005, 7, 28, 18, 47, 23),
#   datetime.datetime(2005, 7, 31, 16, 23, 23)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   10271,
#   datetime.datetime(2005, 8, 1, 3, 13, 39),
#   datetime.datetime(2005, 8, 7, 23, 40, 39)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   11023,
#   datetime.datetime(2005, 8, 2, 5, 36, 38),
#   datetime.datetime(2005, 8, 10, 5, 39, 38)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   11398,
#   datetime.datetime(2005, 8, 2, 18, 55, 15),
#   datetime.datetime(2005, 8, 10, 19, 50, 15)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   11591,
#   datetime.datetime(2005, 8, 17, 2, 29, 41),
#   datetime.datetime(2005, 8, 23, 20, 47, 41)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   11727,
#   datetime.datetime(2005, 8, 17, 8, 12, 20),
#   datetime.datetime(2005, 8, 19, 12, 45, 20)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   11853,
#   datetime.datetime(2005, 8, 17, 13, 39, 32),
#   datetime.datetime(2005, 8, 23, 18, 44, 32)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   12254,
#   datetime.datetime(2005, 8, 18, 4, 5, 29),
#   datetime.datetime(2005, 8, 23, 4, 17, 29)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   13451,
#   datetime.datetime(2005, 8, 20, 0, 18, 25),
#   datetime.datetime(2005, 8, 29, 1, 8, 25)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   14329,
#   datetime.datetime(2005, 8, 21, 8, 22, 56),
#   datetime.datetime(2005, 8, 28, 2, 22, 56)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   14377,
#   datetime.datetime(2005, 8, 21, 9, 49, 28),
#   datetime.datetime(2005, 8, 29, 13, 34, 28)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   15509,
#   datetime.datetime(2005, 8, 23, 2, 51, 24),
#   datetime.datetime(2005, 8, 31, 6, 21, 24)),
#  (6,
#   'JENNIFER',
#   'DAVIS',
#   15603,
#   datetime.datetime(2005, 8, 23, 6, 41, 32),
#   datetime.datetime(2005, 8, 28, 8, 51, 32)),
#  (7,
#   'MARIA',
#   'MILLER',
#   46,
#   datetime.datetime(2005, 5, 25, 6, 4, 8),
#   datetime.datetime(2005, 6, 2, 8, 18, 8)),
#  (7,
#   'MARIA',
#   'MILLER',
#   117,
#   datetime.datetime(2005, 5, 25, 19, 30, 46),
#   datetime.datetime(2005, 5, 31, 23, 59, 46)),
#  (7,
#   'MARIA',
#   'MILLER',
#   748,
#   datetime.datetime(2005, 5, 29, 9, 27),
#   datetime.datetime(2005, 6, 3, 4, 25)),
#  (7,
#   'MARIA',
#   'MILLER',
#   975,
#   datetime.datetime(2005, 5, 30, 21, 7, 15),
#   datetime.datetime(2005, 6, 3, 1, 48, 15)),
#  (7,
#   'MARIA',
#   'MILLER',
#   1063,
#   datetime.datetime(2005, 5, 31, 8, 44, 29),
#   datetime.datetime(2005, 6, 9, 8, 0, 29)),
#  (7,
#   'MARIA',
#   'MILLER',
#   1810,
#   datetime.datetime(2005, 6, 16, 21, 6),
#   datetime.datetime(2005, 6, 21, 21, 24)),
#  (7,
#   'MARIA',
#   'MILLER',
#   2250,
#   datetime.datetime(2005, 6, 18, 5, 3, 36),
#   datetime.datetime(2005, 6, 22, 2, 25, 36)),
#  (7,
#   'MARIA',
#   'MILLER',
#   2709,
#   datetime.datetime(2005, 6, 19, 14, 0, 26),
#   datetime.datetime(2005, 6, 23, 14, 56, 26)),
#  (7,
#   'MARIA',
#   'MILLER',
#   2888,
#   datetime.datetime(2005, 6, 20, 1, 50, 56),
#   datetime.datetime(2005, 6, 22, 5, 5, 56)),
#  (7,
#   'MARIA',
#   'MILLER',
#   3007,
#   datetime.datetime(2005, 6, 20, 10, 11, 53),
#   datetime.datetime(2005, 6, 25, 4, 51, 53)),
#  (7,
#   'MARIA',
#   'MILLER',
#   3639,
#   datetime.datetime(2005, 7, 6, 7, 9, 17),
#   datetime.datetime(2005, 7, 15, 5, 12, 17)),
#  (7,
#   'MARIA',
#   'MILLER',
#   4238,
#   datetime.datetime(2005, 7, 7, 13, 22, 20),
#   datetime.datetime(2005, 7, 10, 7, 44, 20)),
#  (7,
#   'MARIA',
#   'MILLER',
#   4787,
#   datetime.datetime(2005, 7, 8, 16, 16, 4),
#   datetime.datetime(2005, 7, 14, 18, 2, 4)),
#  (7,
#   'MARIA',
#   'MILLER',
#   4856,
#   datetime.datetime(2005, 7, 8, 18, 47, 38),
#   datetime.datetime(2005, 7, 13, 15, 2, 38)),
#  (7,
#   'MARIA',
#   'MILLER',
#   5441,
#   datetime.datetime(2005, 7, 9, 21, 52, 5),
#   datetime.datetime(2005, 7, 17, 2, 54, 5)),
#  (7,
#   'MARIA',
#   'MILLER',
#   5921,
#   datetime.datetime(2005, 7, 10, 21, 35, 12),
#   datetime.datetime(2005, 7, 18, 19, 59, 12)),
#  (7,
#   'MARIA',
#   'MILLER',
#   6174,
#   datetime.datetime(2005, 7, 11, 10, 36, 28),
#   datetime.datetime(2005, 7, 18, 16, 19, 28)),
#  (7,
#   'MARIA',
#   'MILLER',
#   6295,
#   datetime.datetime(2005, 7, 11, 17, 30, 58),
#   datetime.datetime(2005, 7, 15, 15, 50, 58)),
#  (7,
#   'MARIA',
#   'MILLER',
#   6761,
#   datetime.datetime(2005, 7, 12, 15, 17, 42),
#   datetime.datetime(2005, 7, 18, 17, 59, 42)),
#  (7,
#   'MARIA',
#   'MILLER',
#   8422,
#   datetime.datetime(2005, 7, 29, 7, 2, 55),
#   datetime.datetime(2005, 8, 3, 12, 35, 55)),
#  (7,
#   'MARIA',
#   'MILLER',
#   9624,
#   datetime.datetime(2005, 7, 31, 4, 30, 3),
#   datetime.datetime(2005, 8, 6, 9, 13, 3)),
#  (7,
#   'MARIA',
#   'MILLER',
#   10330,
#   datetime.datetime(2005, 8, 1, 4, 57, 4),
#   datetime.datetime(2005, 8, 7, 23, 0, 4)),
#  (7,
#   'MARIA',
#   'MILLER',
#   10423,
#   datetime.datetime(2005, 8, 1, 8, 19, 53),
#   datetime.datetime(2005, 8, 8, 10, 25, 53)),
#  (7,
#   'MARIA',
#   'MILLER',
#   10514,
#   datetime.datetime(2005, 8, 1, 11, 39, 26),
#   datetime.datetime(2005, 8, 3, 7, 53, 26)),
#  (7,
#   'MARIA',
#   'MILLER',
#   10644,
#   datetime.datetime(2005, 8, 1, 15, 52),
#   datetime.datetime(2005, 8, 8, 16, 8)),
#  (7,
#   'MARIA',
#   'MILLER',
#   10989,
#   datetime.datetime(2005, 8, 2, 4, 40, 54),
#   datetime.datetime(2005, 8, 9, 3, 39, 54)),
#  (7,
#   'MARIA',
#   'MILLER',
#   11542,
#   datetime.datetime(2005, 8, 17, 0, 51, 32),
#   datetime.datetime(2005, 8, 24, 20, 29, 32)),
#  (7,
#   'MARIA',
#   'MILLER',
#   12367,
#   datetime.datetime(2005, 8, 18, 7, 57, 14),
#   datetime.datetime(2005, 8, 27, 7, 7, 14)),
#  (7,
#   'MARIA',
#   'MILLER',
#   12730,
#   datetime.datetime(2005, 8, 18, 21, 55, 1),
#   datetime.datetime(2005, 8, 22, 1, 23, 1)),
#  (7,
#   'MARIA',
#   'MILLER',
#   13373,
#   datetime.datetime(2005, 8, 19, 21, 23, 31),
#   datetime.datetime(2005, 8, 25, 22, 38, 31)),
#  (7,
#   'MARIA',
#   'MILLER',
#   13476,
#   datetime.datetime(2005, 8, 20, 1, 6, 4),
#   datetime.datetime(2005, 8, 24, 23, 56, 4)),
#  (7,
#   'MARIA',
#   'MILLER',
#   13594,
#   datetime.datetime(2005, 8, 20, 5, 53, 31),
#   datetime.datetime(2005, 8, 23, 9, 1, 31)),
#  (7,
#   'MARIA',
#   'MILLER',
#   14222,
#   datetime.datetime(2005, 8, 21, 4, 49, 48),
#   datetime.datetime(2005, 8, 25, 5, 34, 48)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   866,
#   datetime.datetime(2005, 5, 30, 3, 43, 54),
#   datetime.datetime(2005, 6, 8, 4, 28, 54)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   1305,
#   datetime.datetime(2005, 6, 15, 9, 59, 16),
#   datetime.datetime(2005, 6, 19, 9, 48, 16)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   2095,
#   datetime.datetime(2005, 6, 17, 18, 21, 35),
#   datetime.datetime(2005, 6, 23, 23, 49, 35)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   3114,
#   datetime.datetime(2005, 6, 20, 17, 57, 47),
#   datetime.datetime(2005, 6, 21, 19, 18, 47)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   3475,
#   datetime.datetime(2005, 7, 5, 23, 1, 21),
#   datetime.datetime(2005, 7, 13, 23, 7, 21)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   4003,
#   datetime.datetime(2005, 7, 7, 0, 9, 2),
#   datetime.datetime(2005, 7, 8, 4, 27, 2)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   4175,
#   datetime.datetime(2005, 7, 7, 10, 2, 3),
#   datetime.datetime(2005, 7, 10, 6, 9, 3)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   4409,
#   datetime.datetime(2005, 7, 7, 21, 47, 29),
#   datetime.datetime(2005, 7, 11, 20, 14, 29)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   4503,
#   datetime.datetime(2005, 7, 8, 2, 17, 12),
#   datetime.datetime(2005, 7, 13, 8, 12, 12)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   5300,
#   datetime.datetime(2005, 7, 9, 15, 40, 46),
#   datetime.datetime(2005, 7, 15, 13, 46, 46)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   5341,
#   datetime.datetime(2005, 7, 9, 17, 13, 23),
#   datetime.datetime(2005, 7, 14, 18, 11, 23)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   6375,
#   datetime.datetime(2005, 7, 11, 21, 39, 46),
#   datetime.datetime(2005, 7, 18, 2, 12, 46)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   6647,
#   datetime.datetime(2005, 7, 12, 10, 43, 53),
#   datetime.datetime(2005, 7, 14, 5, 37, 53)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   8809,
#   datetime.datetime(2005, 7, 29, 21, 42, 49),
#   datetime.datetime(2005, 8, 4, 1, 13, 49)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   9629,
#   datetime.datetime(2005, 7, 31, 4, 54, 43),
#   datetime.datetime(2005, 8, 2, 8, 36, 43)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   10141,
#   datetime.datetime(2005, 7, 31, 22, 8, 29),
#   datetime.datetime(2005, 8, 6, 16, 59, 29)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   10561,
#   datetime.datetime(2005, 8, 1, 13, 5, 35),
#   datetime.datetime(2005, 8, 4, 8, 34, 35)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   11232,
#   datetime.datetime(2005, 8, 2, 13, 4, 12),
#   datetime.datetime(2005, 8, 10, 15, 39, 12)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   11284,
#   datetime.datetime(2005, 8, 2, 14, 42, 45),
#   datetime.datetime(2005, 8, 4, 11, 55, 45)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   12613,
#   datetime.datetime(2005, 8, 18, 17, 16, 1),
#   datetime.datetime(2005, 8, 23, 18, 40, 1)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   14114,
#   datetime.datetime(2005, 8, 21, 1, 7, 11),
#   datetime.datetime(2005, 8, 24, 20, 33, 11)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   15374,
#   datetime.datetime(2005, 8, 22, 22, 9, 9),
#   datetime.datetime(2005, 8, 31, 1, 10, 9)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   15764,
#   datetime.datetime(2005, 8, 23, 13, 5, 10),
#   datetime.datetime(2005, 8, 25, 16, 15, 10)),
#  (8,
#   'SUSAN',
#   'WILSON',
#   15805,
#   datetime.datetime(2005, 8, 23, 14, 31, 19),
#   datetime.datetime(2005, 8, 25, 19, 1, 19)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   350,
#   datetime.datetime(2005, 5, 27, 5, 1, 28),
#   datetime.datetime(2005, 6, 4, 5, 1, 28)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   877,
#   datetime.datetime(2005, 5, 30, 5, 48, 59),
#   datetime.datetime(2005, 6, 2, 9, 30, 59)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   1075,
#   datetime.datetime(2005, 5, 31, 10, 13, 34),
#   datetime.datetime(2005, 6, 9, 8, 11, 34)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   3142,
#   datetime.datetime(2005, 6, 20, 19, 59, 28),
#   datetime.datetime(2005, 6, 28, 19, 51, 28)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   3262,
#   datetime.datetime(2005, 6, 21, 4, 8, 43),
#   datetime.datetime(2005, 6, 28, 2, 55, 43)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   4454,
#   datetime.datetime(2005, 7, 7, 23, 37),
#   datetime.datetime(2005, 7, 11, 2, 30)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   4748,
#   datetime.datetime(2005, 7, 8, 13, 59, 38),
#   datetime.datetime(2005, 7, 15, 16, 51, 38)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   4796,
#   datetime.datetime(2005, 7, 8, 16, 35, 44),
#   datetime.datetime(2005, 7, 13, 11, 8, 44)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   5659,
#   datetime.datetime(2005, 7, 10, 7, 45, 40),
#   datetime.datetime(2005, 7, 15, 5, 20, 40)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   6019,
#   datetime.datetime(2005, 7, 11, 2, 8, 29),
#   datetime.datetime(2005, 7, 13, 2, 19, 29)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   6165,
#   datetime.datetime(2005, 7, 11, 10, 17, 29),
#   datetime.datetime(2005, 7, 17, 7, 27, 29)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   7616,
#   datetime.datetime(2005, 7, 28, 0, 15, 26),
#   datetime.datetime(2005, 7, 30, 21, 52, 26)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   7801,
#   datetime.datetime(2005, 7, 28, 7, 51, 56),
#   datetime.datetime(2005, 7, 30, 12, 18, 56)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   9043,
#   datetime.datetime(2005, 7, 30, 6, 34, 7),
#   datetime.datetime(2005, 8, 2, 1, 16, 7)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   10451,
#   datetime.datetime(2005, 8, 1, 9, 11, 25),
#   datetime.datetime(2005, 8, 3, 12, 37, 25)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   10454,
#   datetime.datetime(2005, 8, 1, 9, 14),
#   datetime.datetime(2005, 8, 4, 4, 52)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   11400,
#   datetime.datetime(2005, 8, 2, 19, 0, 52),
#   datetime.datetime(2005, 8, 9, 19, 45, 52)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   11556,
#   datetime.datetime(2005, 8, 17, 1, 11, 53),
#   datetime.datetime(2005, 8, 18, 23, 41, 53)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   12228,
#   datetime.datetime(2005, 8, 18, 3, 8, 10),
#   datetime.datetime(2005, 8, 20, 2, 48, 10)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   12309,
#   datetime.datetime(2005, 8, 18, 5, 58, 40),
#   datetime.datetime(2005, 8, 20, 2, 20, 40)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   12652,
#   datetime.datetime(2005, 8, 18, 18, 48, 58),
#   datetime.datetime(2005, 8, 21, 14, 15, 58)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   14489,
#   datetime.datetime(2005, 8, 21, 13, 53, 59),
#   datetime.datetime(2005, 8, 30, 15, 45, 59)),
#  (9,
#   'MARGARET',
#   'MOORE',
#   15813,
#   datetime.datetime(2006, 2, 14, 15, 16, 3),
#   None),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   1140,
#   datetime.datetime(2005, 5, 31, 19, 36, 30),
#   datetime.datetime(2005, 6, 7, 18, 33, 30)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   1801,
#   datetime.datetime(2005, 6, 16, 20, 21, 53),
#   datetime.datetime(2005, 6, 18, 23, 18, 53)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   1995,
#   datetime.datetime(2005, 6, 17, 11, 11, 14),
#   datetime.datetime(2005, 6, 26, 16, 37, 14)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   2222,
#   datetime.datetime(2005, 6, 18, 3, 26, 23),
#   datetime.datetime(2005, 6, 26, 8, 50, 23)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   2814,
#   datetime.datetime(2005, 6, 19, 20, 1, 59),
#   datetime.datetime(2005, 6, 26, 1, 28, 59)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   2865,
#   datetime.datetime(2005, 6, 20, 0, 0, 55),
#   datetime.datetime(2005, 6, 21, 2, 20, 55)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   3790,
#   datetime.datetime(2005, 7, 6, 14, 13, 45),
#   datetime.datetime(2005, 7, 14, 13, 35, 45)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   4042,
#   datetime.datetime(2005, 7, 7, 3, 6, 40),
#   datetime.datetime(2005, 7, 10, 2, 37, 40)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   4255,
#   datetime.datetime(2005, 7, 7, 14, 14, 13),
#   datetime.datetime(2005, 7, 12, 18, 32, 13)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   5038,
#   datetime.datetime(2005, 7, 9, 3, 12, 52),
#   datetime.datetime(2005, 7, 17, 22, 27, 52)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   5068,
#   datetime.datetime(2005, 7, 9, 4, 53, 18),
#   datetime.datetime(2005, 7, 13, 9, 21, 18)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   5444,
#   datetime.datetime(2005, 7, 9, 21, 58, 57),
#   datetime.datetime(2005, 7, 11, 3, 9, 57)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   5905,
#   datetime.datetime(2005, 7, 10, 20, 41, 9),
#   datetime.datetime(2005, 7, 19, 14, 49, 9)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   7738,
#   datetime.datetime(2005, 7, 28, 5, 21, 42),
#   datetime.datetime(2005, 8, 3, 9, 46, 42)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   8001,
#   datetime.datetime(2005, 7, 28, 15, 10, 55),
#   datetime.datetime(2005, 8, 5, 18, 23, 55)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   8188,
#   datetime.datetime(2005, 7, 28, 22, 34, 12),
#   datetime.datetime(2005, 8, 1, 2, 32, 12)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   9935,
#   datetime.datetime(2005, 7, 31, 15, 27, 7),
#   datetime.datetime(2005, 8, 5, 11, 23, 7)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   10671,
#   datetime.datetime(2005, 8, 1, 17, 9, 59),
#   datetime.datetime(2005, 8, 9, 21, 36, 59)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   11289,
#   datetime.datetime(2005, 8, 2, 14, 55),
#   datetime.datetime(2005, 8, 11, 13, 57)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   11405,
#   datetime.datetime(2005, 8, 2, 19, 13, 39),
#   datetime.datetime(2005, 8, 7, 19, 19, 39)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   12031,
#   datetime.datetime(2005, 8, 17, 20, 11, 35),
#   datetime.datetime(2005, 8, 24, 23, 48, 35)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   12400,
#   datetime.datetime(2005, 8, 18, 9, 19, 12),
#   datetime.datetime(2005, 8, 26, 6, 52, 12)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   13316,
#   datetime.datetime(2005, 8, 19, 19, 23, 30),
#   datetime.datetime(2005, 8, 22, 23, 37, 30)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   13917,
#   datetime.datetime(2005, 8, 20, 16, 43, 28),
#   datetime.datetime(2005, 8, 29, 16, 44, 28)),
#  (10,
#   'DOROTHY',
#   'TAYLOR',
#   15370,
#   datetime.datetime(2005, 8, 22, 21, 59, 29),
#   datetime.datetime(2005, 8, 27, 16, 32, 29)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   987,
#   datetime.datetime(2005, 5, 30, 22, 59, 12),
#   datetime.datetime(2005, 6, 7, 20, 56, 12)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   1470,
#   datetime.datetime(2005, 6, 15, 20, 53, 7),
#   datetime.datetime(2005, 6, 25, 2, 12, 7)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   1939,
#   datetime.datetime(2005, 6, 17, 7, 26, 45),
#   datetime.datetime(2005, 6, 25, 13, 6, 45)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   3192,
#   datetime.datetime(2005, 6, 20, 23, 49, 12),
#   datetime.datetime(2005, 6, 24, 3, 0, 12)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   4608,
#   datetime.datetime(2005, 7, 8, 7, 19, 11),
#   datetime.datetime(2005, 7, 11, 1, 37, 11)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   4943,
#   datetime.datetime(2005, 7, 8, 22, 43, 5),
#   datetime.datetime(2005, 7, 15, 18, 17, 5)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   5835,
#   datetime.datetime(2005, 7, 10, 16, 44, 58),
#   datetime.datetime(2005, 7, 17, 16, 3, 58)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   6146,
#   datetime.datetime(2005, 7, 11, 9, 9, 59),
#   datetime.datetime(2005, 7, 20, 11, 42, 59)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   7314,
#   datetime.datetime(2005, 7, 27, 13, 13, 32),
#   datetime.datetime(2005, 8, 3, 9, 24, 32)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   8014,
#   datetime.datetime(2005, 7, 28, 15, 32, 7),
#   datetime.datetime(2005, 7, 31, 20, 52, 7)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   8100,
#   datetime.datetime(2005, 7, 28, 18, 43, 11),
#   datetime.datetime(2005, 8, 2, 15, 56, 11)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   8447,
#   datetime.datetime(2005, 7, 29, 7, 38, 14),
#   datetime.datetime(2005, 8, 5, 2, 27, 14)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   8715,
#   datetime.datetime(2005, 7, 29, 17, 33, 45),
#   datetime.datetime(2005, 8, 1, 17, 30, 45)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   8950,
#   datetime.datetime(2005, 7, 30, 3, 17, 13),
#   datetime.datetime(2005, 8, 7, 0, 20, 13)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   9292,
#   datetime.datetime(2005, 7, 30, 16, 8, 21),
#   datetime.datetime(2005, 8, 7, 10, 38, 21)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   10812,
#   datetime.datetime(2005, 8, 1, 22, 41, 16),
#   datetime.datetime(2005, 8, 7, 0, 50, 16)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   11166,
#   datetime.datetime(2005, 8, 2, 10, 14, 58),
#   datetime.datetime(2005, 8, 11, 11, 43, 58)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   11502,
#   datetime.datetime(2005, 8, 16, 23, 6, 30),
#   datetime.datetime(2005, 8, 19, 3, 49, 30)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   11646,
#   datetime.datetime(2006, 2, 14, 15, 16, 3),
#   None),
#  (11,
#   'LISA',
#   'ANDERSON',
#   12015,
#   datetime.datetime(2005, 8, 17, 19, 32, 44),
#   datetime.datetime(2005, 8, 23, 13, 36, 44)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   13572,
#   datetime.datetime(2005, 8, 20, 5, 7, 27),
#   datetime.datetime(2005, 8, 23, 23, 33, 27)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   13790,
#   datetime.datetime(2005, 8, 20, 12, 17, 27),
#   datetime.datetime(2005, 8, 25, 12, 20, 27)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   15120,
#   datetime.datetime(2005, 8, 22, 12, 42, 47),
#   datetime.datetime(2005, 8, 23, 14, 21, 47)),
#  (11,
#   'LISA',
#   'ANDERSON',
#   15240,
#   datetime.datetime(2005, 8, 22, 17, 46, 41),
#   datetime.datetime(2005, 8, 23, 15, 8, 41)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   988,
#   datetime.datetime(2005, 5, 30, 23, 8, 3),
#   datetime.datetime(2005, 6, 7, 0, 22, 3)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   1084,
#   datetime.datetime(2005, 5, 31, 11, 10, 17),
#   datetime.datetime(2005, 6, 1, 11, 15, 17)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   1752,
#   datetime.datetime(2005, 6, 16, 17, 2, 55),
#   datetime.datetime(2005, 6, 23, 19, 9, 55)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   2434,
#   datetime.datetime(2005, 6, 18, 18, 11, 51),
#   datetime.datetime(2005, 6, 23, 12, 52, 51)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   2500,
#   datetime.datetime(2005, 6, 18, 23, 7, 12),
#   datetime.datetime(2005, 6, 26, 17, 27, 12)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   2623,
#   datetime.datetime(2005, 6, 19, 8, 11, 51),
#   datetime.datetime(2005, 6, 26, 12, 28, 51)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   3135,
#   datetime.datetime(2005, 6, 20, 19, 33, 52),
#   datetime.datetime(2005, 6, 29, 18, 20, 52)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   3411,
#   datetime.datetime(2005, 6, 21, 16, 31, 27),
#   datetime.datetime(2005, 6, 28, 12, 27, 27)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   3870,
#   datetime.datetime(2005, 7, 6, 17, 57, 54),
#   datetime.datetime(2005, 7, 13, 12, 30, 54)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   5071,
#   datetime.datetime(2005, 7, 9, 5, 0, 39),
#   datetime.datetime(2005, 7, 9, 23, 8, 39)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   5074,
#   datetime.datetime(2005, 7, 9, 5, 6, 24),
#   datetime.datetime(2005, 7, 12, 4, 37, 24)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   5111,
#   datetime.datetime(2005, 7, 9, 7, 2, 19),
#   datetime.datetime(2005, 7, 10, 6, 27, 19)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   5242,
#   datetime.datetime(2005, 7, 9, 13, 20, 25),
#   datetime.datetime(2005, 7, 18, 7, 38, 25)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   6773,
#   datetime.datetime(2005, 7, 12, 15, 55, 39),
#   datetime.datetime(2005, 7, 18, 17, 52, 39)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   7008,
#   datetime.datetime(2005, 7, 27, 1, 44, 3),
#   datetime.datetime(2005, 7, 28, 21, 19, 3)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   7279,
#   datetime.datetime(2005, 7, 27, 11, 50, 47),
#   datetime.datetime(2005, 7, 30, 11, 19, 47)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   8985,
#   datetime.datetime(2005, 7, 30, 4, 34, 51),
#   datetime.datetime(2005, 8, 6, 0, 45, 51)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   9166,
#   datetime.datetime(2005, 7, 30, 11, 26, 28),
#   datetime.datetime(2005, 8, 4, 12, 32, 28)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   9238,
#   datetime.datetime(2005, 7, 30, 13, 49, 43),
#   datetime.datetime(2005, 8, 8, 8, 25, 43)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   9627,
#   datetime.datetime(2005, 7, 31, 4, 42, 46),
#   datetime.datetime(2005, 8, 8, 0, 42, 46)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   9708,
#   datetime.datetime(2005, 7, 31, 7, 45, 33),
#   datetime.datetime(2005, 8, 8, 8, 56, 33)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   10392,
#   datetime.datetime(2005, 8, 1, 6, 50, 26),
#   datetime.datetime(2005, 8, 10, 10, 52, 26)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   11497,
#   datetime.datetime(2005, 8, 16, 22, 52, 30),
#   datetime.datetime(2005, 8, 21, 19, 52, 30)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   12604,
#   datetime.datetime(2005, 8, 18, 16, 58, 48),
#   datetime.datetime(2005, 8, 19, 19, 36, 48)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   13519,
#   datetime.datetime(2005, 8, 20, 2, 37, 7),
#   datetime.datetime(2005, 8, 23, 1, 26, 7)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   13895,
#   datetime.datetime(2005, 8, 20, 15, 58, 28),
#   datetime.datetime(2005, 8, 26, 15, 7, 28)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   14240,
#   datetime.datetime(2005, 8, 21, 5, 19, 39),
#   datetime.datetime(2005, 8, 22, 23, 25, 39)),
#  (12,
#   'NANCY',
#   'THOMAS',
#   15993,
#   datetime.datetime(2005, 8, 23, 20, 28, 44),
#   datetime.datetime(2005, 8, 27, 16, 23, 44)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   1933,
#   datetime.datetime(2005, 6, 17, 6, 54, 42),
#   datetime.datetime(2005, 6, 26, 2, 0, 42)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   2209,
#   datetime.datetime(2005, 6, 18, 2, 24, 1),
#   datetime.datetime(2005, 6, 22, 4, 13, 1)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   2952,
#   datetime.datetime(2005, 6, 20, 6, 26, 57),
#   datetime.datetime(2005, 6, 22, 11, 51, 57)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   3047,
#   datetime.datetime(2005, 6, 20, 12, 45, 33),
#   datetime.datetime(2005, 6, 29, 13, 9, 33)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   3946,
#   datetime.datetime(2005, 7, 6, 21, 39, 24),
#   datetime.datetime(2005, 7, 11, 16, 10, 24)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   6118,
#   datetime.datetime(2005, 7, 11, 7, 43, 8),
#   datetime.datetime(2005, 7, 20, 3, 17, 8)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   6568,
#   datetime.datetime(2005, 7, 12, 5, 45, 47),
#   datetime.datetime(2005, 7, 15, 5, 18, 47)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   6870,
#   datetime.datetime(2005, 7, 12, 20, 13, 45),
#   datetime.datetime(2005, 7, 16, 22, 9, 45)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   6897,
#   datetime.datetime(2005, 7, 12, 21, 30, 41),
#   datetime.datetime(2005, 7, 15, 3, 19, 41)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   7916,
#   datetime.datetime(2005, 7, 28, 11, 49, 53),
#   datetime.datetime(2005, 7, 29, 15, 1, 53)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   8277,
#   datetime.datetime(2005, 7, 29, 1, 38, 53),
#   datetime.datetime(2005, 8, 4, 7, 9, 53)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   8831,
#   datetime.datetime(2005, 7, 29, 22, 37, 41),
#   datetime.datetime(2005, 8, 8, 4, 28, 41)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   9260,
#   datetime.datetime(2005, 7, 30, 14, 38, 22),
#   datetime.datetime(2005, 8, 7, 18, 47, 22)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   9434,
#   datetime.datetime(2005, 7, 30, 21, 29, 41),
#   datetime.datetime(2005, 8, 1, 16, 30, 41)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   9664,
#   datetime.datetime(2005, 7, 31, 6, 12, 8),
#   datetime.datetime(2005, 8, 4, 2, 19, 8)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   9736,
#   datetime.datetime(2005, 7, 31, 8, 58, 40),
#   datetime.datetime(2005, 8, 9, 8, 34, 40)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   10003,
#   datetime.datetime(2005, 7, 31, 17, 48, 51),
#   datetime.datetime(2005, 8, 2, 14, 23, 51)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   11292,
#   datetime.datetime(2005, 8, 2, 14, 58, 41),
#   datetime.datetime(2005, 8, 6, 14, 38, 41)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   11315,
#   datetime.datetime(2005, 8, 2, 16, 5, 17),
#   datetime.datetime(2005, 8, 5, 16, 33, 17)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   11761,
#   datetime.datetime(2005, 8, 17, 9, 44, 59),
#   datetime.datetime(2005, 8, 25, 7, 46, 59)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   12918,
#   datetime.datetime(2005, 8, 19, 4, 31, 36),
#   datetime.datetime(2005, 8, 25, 5, 50, 36)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   13096,
#   datetime.datetime(2005, 8, 19, 10, 49, 3),
#   datetime.datetime(2005, 8, 21, 5, 33, 3)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   13213,
#   datetime.datetime(2005, 8, 19, 15, 25, 48),
#   datetime.datetime(2005, 8, 22, 9, 32, 48)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   13456,
#   datetime.datetime(2005, 8, 20, 0, 33, 19),
#   datetime.datetime(2005, 8, 22, 1, 47, 19)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   14252,
#   datetime.datetime(2005, 8, 21, 5, 44, 7),
#   datetime.datetime(2005, 8, 29, 8, 53, 7)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   14545,
#   datetime.datetime(2005, 8, 21, 15, 44, 23),
#   datetime.datetime(2005, 8, 29, 20, 9, 23)),
#  (13,
#   'KAREN',
#   'JACKSON',
#   15338,
#   datetime.datetime(2005, 8, 22, 20, 51, 24),
#   datetime.datetime(2005, 8, 24, 23, 41, 24)),
#  (14,
#   'BETTY',
#   'WHITE',
#   151,
#   datetime.datetime(2005, 5, 26, 0, 37, 28),
#   datetime.datetime(2005, 5, 30, 6, 28, 28)),
#  (14,
#   'BETTY',
#   'WHITE',
#   346,
#   datetime.datetime(2005, 5, 27, 4, 34, 41),
#   datetime.datetime(2005, 6, 5, 4, 24, 41)),
#  (14,
#   'BETTY',
#   'WHITE',
#   525,
#   datetime.datetime(2005, 5, 28, 4, 25, 33),
#   datetime.datetime(2005, 6, 6, 4, 18, 33)),
#  (14,
#   'BETTY',
#   'WHITE',
#   671,
#   datetime.datetime(2005, 5, 28, 22, 4, 30),
#   datetime.datetime(2005, 6, 3, 1, 21, 30)),
#  (14,
#   'BETTY',
#   'WHITE',
#   815,
#   datetime.datetime(2005, 5, 29, 20, 24, 28),
#   datetime.datetime(2005, 6, 3, 15, 32, 28)),
#  (14,
#   'BETTY',
#   'WHITE',
#   1360,
#   datetime.datetime(2005, 6, 15, 13, 32, 15),
#   datetime.datetime(2005, 6, 18, 10, 59, 15)),
#  (14,
#   'BETTY',
#   'WHITE',
#   3707,
#   datetime.datetime(2005, 7, 6, 10, 21, 49),
#   datetime.datetime(2005, 7, 12, 5, 14, 49)),
#  (14,
#   'BETTY',
#   'WHITE',
#   4952,
#   datetime.datetime(2005, 7, 8, 23, 0, 7),
#   datetime.datetime(2005, 7, 9, 21, 47, 7)),
#  (14,
#   'BETTY',
#   'WHITE',
#   5104,
#   datetime.datetime(2005, 7, 9, 6, 37, 7),
#   datetime.datetime(2005, 7, 14, 12, 32, 7)),
#  (14,
#   'BETTY',
#   'WHITE',
#   5317,
#   datetime.datetime(2005, 7, 9, 16, 10, 25),
#   datetime.datetime(2005, 7, 18, 17, 10, 25)),
#  (14,
#   'BETTY',
#   'WHITE',
#   5383,
#   datetime.datetime(2005, 7, 9, 19, 14, 32),
#   datetime.datetime(2005, 7, 11, 19, 57, 32)),
#  (14,
#   'BETTY',
#   'WHITE',
#   5565,
#   datetime.datetime(2005, 7, 10, 3, 29, 48),
#   datetime.datetime(2005, 7, 17, 4, 43, 48)),
#  (14,
#   'BETTY',
#   'WHITE',
#   8035,
#   datetime.datetime(2005, 7, 28, 16, 23, 1),
#   datetime.datetime(2005, 8, 5, 10, 52, 1)),
#  (14,
#   'BETTY',
#   'WHITE',
#   8042,
#   datetime.datetime(2005, 7, 28, 16, 45, 11),
#   datetime.datetime(2005, 8, 4, 17, 16, 11)),
#  (14,
#   'BETTY',
#   'WHITE',
#   8548,
#   datetime.datetime(2005, 7, 29, 11, 11, 33),
#   datetime.datetime(2005, 8, 4, 11, 52, 33)),
#  (14,
#   'BETTY',
#   'WHITE',
#   8836,
#   datetime.datetime(2005, 7, 29, 22, 46, 8),
#   datetime.datetime(2005, 8, 2, 19, 53, 8)),
#  (14,
#   'BETTY',
#   'WHITE',
#   9438,
#   datetime.datetime(2005, 7, 30, 21, 36, 15),
#   datetime.datetime(2005, 8, 7, 16, 54, 15)),
#  (14,
#   'BETTY',
#   'WHITE',
# ...
#   datetime.datetime(2005, 8, 31, 6, 1, 34)),
#  (31,
#   'BRENDA',
#   'WRIGHT',
#   15816,
#   datetime.datetime(2005, 8, 23, 14, 58, 6),
#   datetime.datetime(2005, 8, 28, 13, 30, 6)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   483,
#   datetime.datetime(2005, 5, 27, 23, 0, 25),
#   datetime.datetime(2005, 5, 28, 21, 30, 25)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   803,
#   datetime.datetime(2005, 5, 29, 17, 52, 30),
#   datetime.datetime(2005, 5, 30, 14, 35, 30)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   1067,
#   datetime.datetime(2005, 5, 31, 9, 12, 13),
#   datetime.datetime(2005, 6, 1, 6, 15, 13)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   1887,
#   datetime.datetime(2005, 6, 17, 3, 53, 18),
#   datetime.datetime(2005, 6, 25, 7, 37, 18)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   2160,
#   datetime.datetime(2005, 6, 17, 23, 39, 11),
#   datetime.datetime(2005, 6, 22, 20, 4, 11)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   2624,
#   datetime.datetime(2005, 6, 19, 8, 22, 9),
#   datetime.datetime(2005, 6, 27, 11, 13, 9)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   2891,
#   datetime.datetime(2005, 6, 20, 2, 2, 5),
#   datetime.datetime(2005, 6, 25, 2, 45, 5)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   3500,
#   datetime.datetime(2005, 7, 6, 0, 11, 13),
#   datetime.datetime(2005, 7, 13, 19, 1, 13)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   4434,
#   datetime.datetime(2005, 7, 7, 22, 48, 34),
#   datetime.datetime(2005, 7, 9, 18, 55, 34)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   4771,
#   datetime.datetime(2005, 7, 8, 15, 33, 32),
#   datetime.datetime(2005, 7, 10, 12, 38, 32)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   4899,
#   datetime.datetime(2005, 7, 8, 20, 37, 11),
#   datetime.datetime(2005, 7, 10, 21, 53, 11)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   5307,
#   datetime.datetime(2005, 7, 9, 15, 57, 15),
#   datetime.datetime(2005, 7, 17, 13, 42, 15)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   5767,
#   datetime.datetime(2005, 7, 10, 13, 13, 18),
#   datetime.datetime(2005, 7, 17, 14, 41, 18)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   5954,
#   datetime.datetime(2005, 7, 10, 23, 22, 1),
#   datetime.datetime(2005, 7, 14, 4, 42, 1)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   6122,
#   datetime.datetime(2005, 7, 11, 7, 58, 7),
#   datetime.datetime(2005, 7, 16, 9, 52, 7)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   6450,
#   datetime.datetime(2005, 7, 12, 0, 49, 5),
#   datetime.datetime(2005, 7, 13, 1, 54, 5)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   7084,
#   datetime.datetime(2005, 7, 27, 4, 34, 7),
#   datetime.datetime(2005, 8, 5, 0, 21, 7)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   7589,
#   datetime.datetime(2005, 7, 27, 23, 23, 36),
#   datetime.datetime(2005, 8, 4, 0, 16, 36)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   7793,
#   datetime.datetime(2005, 7, 28, 7, 26, 14),
#   datetime.datetime(2005, 8, 3, 7, 45, 14)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   8390,
#   datetime.datetime(2005, 7, 29, 5, 52, 26),
#   datetime.datetime(2005, 8, 4, 8, 12, 26)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   8453,
#   datetime.datetime(2005, 7, 29, 7, 46, 29),
#   datetime.datetime(2005, 7, 30, 7, 7, 29)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   8914,
#   datetime.datetime(2005, 7, 30, 1, 42, 3),
#   datetime.datetime(2005, 8, 4, 3, 53, 3)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   11135,
#   datetime.datetime(2005, 8, 2, 9, 22, 25),
#   datetime.datetime(2005, 8, 4, 14, 30, 25)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   11831,
#   datetime.datetime(2005, 8, 17, 12, 54, 47),
#   datetime.datetime(2005, 8, 21, 11, 21, 47)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   12414,
#   datetime.datetime(2005, 8, 18, 9, 50, 40),
#   datetime.datetime(2005, 8, 26, 6, 45, 40)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   13736,
#   datetime.datetime(2005, 8, 20, 10, 31, 23),
#   datetime.datetime(2005, 8, 28, 6, 51, 23)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   13931,
#   datetime.datetime(2005, 8, 20, 17, 16, 10),
#   datetime.datetime(2005, 8, 27, 12, 3, 10)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   14075,
#   datetime.datetime(2005, 8, 20, 23, 18, 54),
#   datetime.datetime(2005, 8, 26, 21, 59, 54)),
#  (32,
#   'AMY',
#   'LOPEZ',
#   14570,
#   datetime.datetime(2005, 8, 21, 16, 32, 32),
#   datetime.datetime(2005, 8, 30, 12, 3, 32)),
#  (33,
#   'ANNA',
#   'HILL',
#   165,
#   datetime.datetime(2005, 5, 26, 2, 28, 36),
#   datetime.datetime(2005, 6, 2, 3, 21, 36)),
#  (33,
#   'ANNA',
#   'HILL',
#   1301,
#   datetime.datetime(2005, 6, 15, 9, 46, 33),
#   datetime.datetime(2005, 6, 24, 8, 56, 33)),
#  (33,
#   'ANNA',
#   'HILL',
#   3173,
#   datetime.datetime(2005, 6, 20, 22, 21, 10),
#   datetime.datetime(2005, 6, 27, 19, 41, 10)),
#  (33,
#   'ANNA',
#   'HILL',
#   4095,
#   datetime.datetime(2005, 7, 7, 6, 1, 48),
#   datetime.datetime(2005, 7, 15, 2, 52, 48)),
#  (33,
#   'ANNA',
#   'HILL',
#   5421,
#   datetime.datetime(2005, 7, 9, 20, 49, 12),
#   datetime.datetime(2005, 7, 10, 16, 30, 12)),
#  (33,
#   'ANNA',
#   'HILL',
#   5723,
#   datetime.datetime(2005, 7, 10, 11, 14, 48),
#   datetime.datetime(2005, 7, 11, 15, 46, 48)),
#  (33,
#   'ANNA',
#   'HILL',
#   6280,
#   datetime.datetime(2005, 7, 11, 16, 36, 17),
#   datetime.datetime(2005, 7, 13, 14, 4, 17)),
#  (33,
#   'ANNA',
#   'HILL',
#   7992,
#   datetime.datetime(2005, 7, 28, 14, 53, 6),
#   datetime.datetime(2005, 7, 29, 18, 17, 6)),
#  (33,
#   'ANNA',
#   'HILL',
#   9040,
#   datetime.datetime(2005, 7, 30, 6, 31, 45),
#   datetime.datetime(2005, 8, 3, 12, 20, 45)),
#  (33,
#   'ANNA',
#   'HILL',
#   9085,
#   datetime.datetime(2005, 7, 30, 8, 17, 24),
#   datetime.datetime(2005, 8, 3, 9, 35, 24)),
#  (33,
#   'ANNA',
#   'HILL',
#   9254,
#   datetime.datetime(2005, 7, 30, 14, 26, 11),
#   datetime.datetime(2005, 8, 4, 16, 12, 11)),
#  (33,
#   'ANNA',
#   'HILL',
#   10335,
#   datetime.datetime(2005, 8, 1, 4, 59, 30),
#   datetime.datetime(2005, 8, 5, 2, 26, 30)),
#  (33,
#   'ANNA',
#   'HILL',
#   10870,
#   datetime.datetime(2005, 8, 2, 0, 27, 12),
#   datetime.datetime(2005, 8, 2, 20, 0, 12)),
#  (33, 'ANNA', 'HILL', 12277, datetime.datetime(2006, 2, 14, 15, 16, 3), None),
#  (33,
#   'ANNA',
#   'HILL',
#   13241,
#   datetime.datetime(2005, 8, 19, 16, 25),
#   datetime.datetime(2005, 8, 26, 12, 27)),
#  (33,
#   'ANNA',
#   'HILL',
#   13858,
#   datetime.datetime(2005, 8, 20, 14, 50, 57),
#   datetime.datetime(2005, 8, 23, 12, 10, 57)),
#  (33,
#   'ANNA',
#   'HILL',
#   13958,
#   datetime.datetime(2005, 8, 20, 18, 11, 44),
#   datetime.datetime(2005, 8, 28, 14, 59, 44)),
#  (33,
#   'ANNA',
#   'HILL',
#   14002,
#   datetime.datetime(2005, 8, 20, 20, 12, 19),
#   datetime.datetime(2005, 8, 23, 0, 23, 19)),
#  (33,
#   'ANNA',
#   'HILL',
#   14623,
#   datetime.datetime(2005, 8, 21, 18, 29, 13),
#   datetime.datetime(2005, 8, 26, 20, 48, 13)),
#  (33,
#   'ANNA',
#   'HILL',
#   15096,
#   datetime.datetime(2005, 8, 22, 11, 43, 4),
#   datetime.datetime(2005, 8, 29, 12, 16, 4)),
#  (33,
#   'ANNA',
#   'HILL',
#   15115,
#   datetime.datetime(2005, 8, 22, 12, 28, 1),
#   datetime.datetime(2005, 8, 26, 16, 12, 1)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   1900,
#   datetime.datetime(2005, 6, 17, 4, 29, 58),
#   datetime.datetime(2005, 6, 21, 5, 58, 58)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   2257,
#   datetime.datetime(2005, 6, 18, 5, 29, 52),
#   datetime.datetime(2005, 6, 22, 0, 19, 52)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   3150,
#   datetime.datetime(2005, 6, 20, 20, 35, 28),
#   datetime.datetime(2005, 6, 26, 1, 1, 28)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   3508,
#   datetime.datetime(2005, 7, 6, 0, 24, 25),
#   datetime.datetime(2005, 7, 10, 5, 38, 25)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   3911,
#   datetime.datetime(2005, 7, 6, 20, 9, 11),
#   datetime.datetime(2005, 7, 8, 23, 53, 11)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   5188,
#   datetime.datetime(2005, 7, 9, 10, 22, 31),
#   datetime.datetime(2005, 7, 13, 4, 41, 31)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   5643,
#   datetime.datetime(2005, 7, 10, 6, 49),
#   datetime.datetime(2005, 7, 14, 1, 53)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   5918,
#   datetime.datetime(2005, 7, 10, 21, 32, 6),
#   datetime.datetime(2005, 7, 19, 21, 35, 6)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   7015,
#   datetime.datetime(2005, 7, 27, 2, 15, 1),
#   datetime.datetime(2005, 7, 28, 7, 46, 1)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   7124,
#   datetime.datetime(2005, 7, 27, 6, 9, 30),
#   datetime.datetime(2005, 8, 2, 9, 31, 30)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   7532,
#   datetime.datetime(2005, 7, 27, 21, 20, 52),
#   datetime.datetime(2005, 7, 30, 21, 38, 52)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   9160,
#   datetime.datetime(2005, 7, 30, 11, 17, 33),
#   datetime.datetime(2005, 8, 6, 15, 16, 33)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   10523,
#   datetime.datetime(2005, 8, 1, 11, 52, 32),
#   datetime.datetime(2005, 8, 2, 10, 47, 32)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   10615,
#   datetime.datetime(2005, 8, 1, 14, 58, 14),
#   datetime.datetime(2005, 8, 2, 13, 38, 14)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   11096,
#   datetime.datetime(2005, 8, 2, 8, 5, 19),
#   datetime.datetime(2005, 8, 4, 7, 28, 19)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   11505,
#   datetime.datetime(2005, 8, 16, 23, 18, 47),
#   datetime.datetime(2005, 8, 23, 19, 52, 47)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   11701,
#   datetime.datetime(2005, 8, 17, 7, 15, 47),
#   datetime.datetime(2005, 8, 19, 1, 44, 47)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   12286,
#   datetime.datetime(2005, 8, 18, 4, 57, 59),
#   datetime.datetime(2005, 8, 18, 23, 20, 59)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   12599,
#   datetime.datetime(2005, 8, 18, 16, 42, 45),
#   datetime.datetime(2005, 8, 23, 18, 27, 45)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   12651,
#   datetime.datetime(2005, 8, 18, 18, 36, 16),
#   datetime.datetime(2005, 8, 22, 22, 1, 16)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   13371,
#   datetime.datetime(2005, 8, 19, 21, 21, 47),
#   datetime.datetime(2005, 8, 26, 16, 17, 47)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   13949,
#   datetime.datetime(2005, 8, 20, 17, 55, 13),
#   datetime.datetime(2005, 8, 22, 20, 49, 13)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   14686,
#   datetime.datetime(2005, 8, 21, 20, 32, 8),
#   datetime.datetime(2005, 8, 26, 18, 7, 8)),
#  (34,
#   'REBECCA',
#   'SCOTT',
#   14701,
#   datetime.datetime(2005, 8, 21, 20, 54, 32),
#   datetime.datetime(2005, 8, 30, 16, 46, 32)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   47,
#   datetime.datetime(2005, 5, 25, 6, 5, 20),
#   datetime.datetime(2005, 5, 30, 3, 4, 20)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   424,
#   datetime.datetime(2005, 5, 27, 15, 34, 1),
#   datetime.datetime(2005, 6, 5, 9, 44, 1)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   1579,
#   datetime.datetime(2005, 6, 16, 4, 9, 8),
#   datetime.datetime(2005, 6, 21, 5, 21, 8)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   1989,
#   datetime.datetime(2005, 6, 17, 10, 47, 24),
#   datetime.datetime(2005, 6, 19, 5, 12, 24)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   2229,
#   datetime.datetime(2005, 6, 18, 3, 50, 18),
#   datetime.datetime(2005, 6, 26, 7, 16, 18)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   2231,
#   datetime.datetime(2005, 6, 18, 3, 52, 14),
#   datetime.datetime(2005, 6, 23, 6, 52, 14)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   2743,
#   datetime.datetime(2005, 6, 19, 16, 15, 56),
#   datetime.datetime(2005, 6, 23, 12, 30, 56)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   3112,
#   datetime.datetime(2005, 6, 20, 17, 53, 30),
#   datetime.datetime(2005, 6, 26, 16, 3, 30)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   3597,
#   datetime.datetime(2005, 7, 6, 5, 3, 59),
#   datetime.datetime(2005, 7, 13, 6, 49, 59)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   4098,
#   datetime.datetime(2005, 7, 7, 6, 14, 51),
#   datetime.datetime(2005, 7, 14, 6, 51, 51)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   4990,
#   datetime.datetime(2005, 7, 9, 0, 48, 49),
#   datetime.datetime(2005, 7, 10, 6, 36, 49)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   5013,
#   datetime.datetime(2005, 7, 9, 1, 46, 45),
#   datetime.datetime(2005, 7, 16, 6, 57, 45)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   5323,
#   datetime.datetime(2005, 7, 9, 16, 34, 7),
#   datetime.datetime(2005, 7, 13, 21, 37, 7)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   5916,
#   datetime.datetime(2005, 7, 10, 21, 26, 31),
#   datetime.datetime(2005, 7, 19, 20, 23, 31)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   5963,
#   datetime.datetime(2005, 7, 10, 23, 47, 8),
#   datetime.datetime(2005, 7, 12, 4, 27, 8)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   6147,
#   datetime.datetime(2005, 7, 11, 9, 13, 8),
#   datetime.datetime(2005, 7, 17, 3, 48, 8)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   6401,
#   datetime.datetime(2005, 7, 11, 22, 44, 34),
#   datetime.datetime(2005, 7, 12, 22, 18, 34)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   6565,
#   datetime.datetime(2005, 7, 12, 5, 39, 50),
#   datetime.datetime(2005, 7, 13, 1, 7, 50)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   6572,
#   datetime.datetime(2005, 7, 12, 5, 56, 38),
#   datetime.datetime(2005, 7, 16, 10, 41, 38)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   7140,
#   datetime.datetime(2005, 7, 27, 6, 54, 12),
#   datetime.datetime(2005, 8, 3, 10, 36, 12)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   8822,
#   datetime.datetime(2005, 7, 29, 22, 20, 21),
#   datetime.datetime(2005, 8, 6, 3, 0, 21)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   8971,
#   datetime.datetime(2005, 7, 30, 4, 3, 58),
#   datetime.datetime(2005, 8, 8, 4, 16, 58)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   9033,
#   datetime.datetime(2005, 7, 30, 6, 7, 42),
#   datetime.datetime(2005, 8, 5, 1, 18, 42)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   9579,
#   datetime.datetime(2005, 7, 31, 2, 59, 20),
#   datetime.datetime(2005, 8, 6, 3, 52, 20)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   11298,
#   datetime.datetime(2005, 8, 2, 15, 32, 32),
#   datetime.datetime(2005, 8, 6, 20, 22, 32)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   11452,
#   datetime.datetime(2005, 8, 2, 20, 59, 52),
#   datetime.datetime(2005, 8, 12, 1, 16, 52)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   11645,
#   datetime.datetime(2005, 8, 17, 4, 50, 56),
#   datetime.datetime(2005, 8, 25, 23, 3, 56)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   12055,
#   datetime.datetime(2005, 8, 17, 21, 2, 19),
#   datetime.datetime(2005, 8, 18, 15, 24, 19)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   13735,
#   datetime.datetime(2005, 8, 20, 10, 31, 1),
#   datetime.datetime(2005, 8, 26, 5, 0, 1)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   14110,
#   datetime.datetime(2005, 8, 21, 0, 53, 9),
#   datetime.datetime(2005, 8, 24, 5, 33, 9)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   14124,
#   datetime.datetime(2005, 8, 21, 1, 31, 51),
#   datetime.datetime(2005, 8, 24, 22, 20, 51)),
#  (35,
#   'VIRGINIA',
#   'GREEN',
#   14735,
#   datetime.datetime(2005, 8, 21, 22, 25, 9),
#   datetime.datetime(2005, 8, 23, 21, 16, 9)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   349,
#   datetime.datetime(2005, 5, 27, 4, 53, 11),
#   datetime.datetime(2005, 5, 28, 6, 33, 11)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   716,
#   datetime.datetime(2005, 5, 29, 4, 35, 29),
#   datetime.datetime(2005, 6, 1, 7, 42, 29)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   2741,
#   datetime.datetime(2005, 6, 19, 16, 5, 41),
#   datetime.datetime(2005, 6, 20, 20, 48, 41)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   4135,
#   datetime.datetime(2005, 7, 7, 8, 15, 3),
#   datetime.datetime(2005, 7, 11, 10, 56, 3)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   4560,
#   datetime.datetime(2005, 7, 8, 4, 58, 48),
#   datetime.datetime(2005, 7, 10, 4, 27, 48)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   4762,
#   datetime.datetime(2005, 7, 8, 14, 54, 42),
#   datetime.datetime(2005, 7, 12, 18, 8, 42)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   5403,
#   datetime.datetime(2005, 7, 9, 20, 7, 9),
#   datetime.datetime(2005, 7, 12, 18, 33, 9)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   6030,
#   datetime.datetime(2005, 7, 11, 2, 37, 51),
#   datetime.datetime(2005, 7, 16, 22, 34, 51)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   7205,
#   datetime.datetime(2005, 7, 27, 9, 6, 13),
#   datetime.datetime(2005, 8, 5, 7, 11, 13)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   7647,
#   datetime.datetime(2005, 7, 28, 1, 35, 17),
#   datetime.datetime(2005, 8, 1, 0, 14, 17)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   7919,
#   datetime.datetime(2005, 7, 28, 11, 59, 45),
#   datetime.datetime(2005, 8, 6, 11, 19, 45)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   8099,
#   datetime.datetime(2005, 7, 28, 18, 35, 12),
#   datetime.datetime(2005, 7, 30, 15, 44, 12)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   8391,
#   datetime.datetime(2005, 7, 29, 5, 52, 50),
#   datetime.datetime(2005, 8, 3, 4, 45, 50)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   8952,
#   datetime.datetime(2005, 7, 30, 3, 20, 38),
#   datetime.datetime(2005, 8, 2, 2, 54, 38)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   9369,
#   datetime.datetime(2005, 7, 30, 18, 52, 19),
#   datetime.datetime(2005, 8, 1, 12, 53, 19)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   9805,
#   datetime.datetime(2005, 7, 31, 11, 11, 10),
#   datetime.datetime(2005, 8, 3, 7, 36, 10)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   10525,
#   datetime.datetime(2005, 8, 1, 11, 53, 17),
#   datetime.datetime(2005, 8, 7, 7, 24, 17)),
#  (36,
#   'KATHLEEN',
#   'ADAMS',
#   10761,
#   datetime.datetime(2005, 8, 1, 20, 25, 35),
#   datetime.datetime(2005, 8, 8, 15, 20, 35)),
#  ...]

# %%
customers_rentals = pd.DataFrame(q_result)
customers_rentals
# Out:
#          0       1        2      3                   4                   5
# 0        1    MARY    SMITH     76 2005-05-25 11:30:37 2005-06-03 12:00:37
# 1        1    MARY    SMITH    573 2005-05-28 10:35:23 2005-06-03 06:32:23
# 2        1    MARY    SMITH   1185 2005-06-15 00:54:12 2005-06-23 02:42:12
# 3        1    MARY    SMITH   1422 2005-06-15 18:02:53 2005-06-19 15:54:53
# 4        1    MARY    SMITH   1476 2005-06-15 21:08:46 2005-06-25 02:26:46
# ...    ...     ...      ...    ...                 ...                 ...
# 16039  599  AUSTIN  CINTRON  14599 2005-08-21 17:43:42 2005-08-22 18:53:42
# 16040  599  AUSTIN  CINTRON  14719 2005-08-21 21:41:57 2005-08-25 20:37:57
# 16041  599  AUSTIN  CINTRON  15590 2005-08-23 06:09:44 2005-09-01 06:53:44
# 16042  599  AUSTIN  CINTRON  15719 2005-08-23 11:08:46 2005-08-25 07:25:46
# 16043  599  AUSTIN  CINTRON  15725 2005-08-23 11:25:00 2005-08-26 11:46:00
#
# [16044 rows x 6 columns]

# %% [markdown]
# # Challenge 1 - Working with JSON files
# Import the pandas library.

# %%
# your code here

import pandas as pd

# %% [markdown]
# In the next cell, load the data in nasa.json in the data folder and load it into a pandas dataframe. Name the dataframe nasa.

# %%
# your code here

nasa = pd.read_json("nasa.json")

# %% [markdown]
# Now that we have loaded the data, let's examine it using the head() function.

# %%
# your code here

nasa.head()
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass      name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0    Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0    Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0      Abee
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0  Acapulco
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0   Achiras
#
#   nametype     recclass    reclat    reclong                     year
# 0    Valid           L5  50.77500    6.08333  1880-01-01T00:00:00.000
# 1    Valid           H6  56.18333   10.23333  1951-01-01T00:00:00.000
# 2    Valid          EH4  54.21667 -113.00000  1952-01-01T00:00:00.000
# 3    Valid  Acapulcoite  16.88333  -99.90000  1976-01-01T00:00:00.000
# 4    Valid           L6 -33.16667  -64.95000  1902-01-01T00:00:00.000

# %% [markdown]
# ####  The value_counts() function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the value_counts() function to determine the frequency of all types of asteroid landings by applying the function to the fall column.

# %%
# your code here

nasa["fall"].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the orient=records argument and name the file nasa-output.json. Remember to save the file inside the data folder.

# %%
# your code here

nasa_output = nasa.to_json("nasa-output.json", orient="records")

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# Import the pandas library
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
#Your pandas import here:

import pandas as pd

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:

shuttle = pd.read_csv(tst_url, sep = " ", names = cols)

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# Your code here:

shuttle.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:

shuttle.to_csv("shuttle.csv", index = False, header = False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:

astronaut = pd.read_excel("astronauts.xls")

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:

astronaut.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN
# 1                              STS 51-F (Challenger)        NaT           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaT           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT           NaN
# 4                               Gemini 12, Apollo 11        NaT           NaN

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut['Undergraduate Major'].value_counts()
# Out:
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:

astronaut.to_csv("astronaut.csv", sep = "\t", index = False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:

columns = ["Season in which the analysis was performed", "Age at the time of analysis", "Childish diseases (ie , chicken pox, measles, mumps, polio)", "Accident or serious trauma", "Surgical intervention", "High fevers in the last year", "Frequency of alcohol consumption", "Smoking habit", "Number of hours spent sitting per day ene-16", "Output"]
fertility = pd.read_csv("fertility_Diagnosis.txt", names = columns)
fertility.head()
# Out:
#    Season in which the analysis was performed  Age at the time of analysis  \
# 0                                       -0.33                         0.69
# 1                                       -0.33                         0.94
# 2                                       -0.33                         0.50
# 3                                       -0.33                         0.75
# 4                                       -0.33                         0.67
#
#    Childish diseases (ie , chicken pox, measles, mumps, polio)  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#    Accident or serious trauma  Surgical intervention  \
# 0                           1                      1
# 1                           0                      1
# 2                           0                      0
# 3                           1                      1
# 4                           1                      0
#
#    High fevers in the last year  Frequency of alcohol consumption  \
# 0                             0                               0.8
# 1                             0                               0.8
# 2                             0                               1.0
# 3                             0                               1.0
# 4                             0                               0.8
#
#    Smoking habit  Number of hours spent sitting per day ene-16 Output
# 0              0                                          0.88      N
# 1              1                                          0.31      O
# 2             -1                                          0.50      N
# 3             -1                                          0.38      N
# 4             -1                                          0.50      O
