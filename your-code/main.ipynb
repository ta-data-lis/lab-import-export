# %% [markdown]
# # Import and Export Files

# %% [markdown]
# # Challenge 0 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here
import mysql.connector
import pandas as pd

# %%
# your code here

mydb=mysql.connector.connect(user="root",
                            password = "Tudore.123#",
                            host ="localhost",
                            database = "sakila",
                            auth_plugin = "mysql_native_password")

# check if the connection was successful
mydb.is_connected()

if mydb.is_connected():
    print('Connection open')
else:
    print('Connection is not succesfully open')
# Out:
# Connection open

# %%
cursor = mydb.cursor()
cursor
    
query1 = ("""SELECT sakila.actor.first_name AS FNAME , sakila.actor.last_name AS LNAME, COUNT(sakila.film_actor.film_id)/* its good practice to specify database.table.column */
FROM sakila.film_actor   
INNER JOIN sakila.actor
ON sakila.actor.actor_id = sakila.film_actor.actor_id
GROUP BY sakila.actor.first_name, sakila.actor.last_name;""")

cursor.execute(query1)

myresult1 = cursor.fetchall()
for x in myresult1:
    print(x)

myresult11 = pd.DataFrame(myresult1)
display(myresult11)


print("\n")

query2 = ("""SELECT *
FROM sakila.film
INNER JOIN
(SELECT first_name, last_name, film_id                    
FROM sakila.actor
INNER JOIN sakila.film_actor
ON sakila.actor.actor_id = sakila.film_actor.actor_id)  AS test_table
ON sakila.film.film_id = test_table.film_id;""")
cursor.execute(query2)
myresult2 = cursor.fetchall()
for x in myresult2:
    print(x)

    
myresult22 = pd.DataFrame(myresult2)

display(myresult22)
# Out:
# ('PENELOPE', 'GUINESS', 19)
# ('NICK', 'WAHLBERG', 25)
# ('ED', 'CHASE', 22)
# ('JENNIFER', 'DAVIS', 22)
# ('JOHNNY', 'LOLLOBRIGIDA', 29)
# ('BETTE', 'NICHOLSON', 20)
# ('GRACE', 'MOSTEL', 30)
# ('MATTHEW', 'JOHANSSON', 20)
# ('JOE', 'SWANK', 25)
# ('CHRISTIAN', 'GABLE', 22)
# ('ZERO', 'CAGE', 25)
# ('KARL', 'BERRY', 31)
# ('UMA', 'WOOD', 35)
# ('VIVIEN', 'BERGEN', 30)
# ('CUBA', 'OLIVIER', 28)
# ('FRED', 'COSTNER', 27)
# ('HELEN', 'VOIGHT', 32)
# ('DAN', 'TORN', 22)
# ('BOB', 'FAWCETT', 25)
# ('LUCILLE', 'TRACY', 30)
# ('KIRSTEN', 'PALTROW', 27)
# ('ELVIS', 'MARX', 26)
# ('SANDRA', 'KILMER', 37)
# ('CAMERON', 'STREEP', 24)
# ('KEVIN', 'BLOOM', 21)
# ('RIP', 'CRAWFORD', 33)
# ('JULIA', 'MCQUEEN', 33)
# ('WOODY', 'HOFFMAN', 31)
# ('ALEC', 'WAYNE', 29)
# ('SANDRA', 'PECK', 19)
# ('SISSY', 'SOBIESKI', 18)
# ('TIM', 'HACKMAN', 23)
# ('MILLA', 'PECK', 24)
# ('AUDREY', 'OLIVIER', 25)
# ('JUDY', 'DEAN', 15)
# ('BURT', 'DUKAKIS', 29)
# ('VAL', 'BOLGER', 35)
# ('TOM', 'MCKELLEN', 25)
# ('GOLDIE', 'BRODY', 28)
# ('JOHNNY', 'CAGE', 29)
# ('JODIE', 'DEGENERES', 29)
# ('TOM', 'MIRANDA', 27)
# ('KIRK', 'JOVOVICH', 26)
# ('NICK', 'STALLONE', 30)
# ('REESE', 'KILMER', 32)
# ('PARKER', 'GOLDBERG', 24)
# ('JULIA', 'BARRYMORE', 24)
# ('FRANCES', 'DAY-LEWIS', 26)
# ('ANNE', 'CRONYN', 27)
# ('NATALIE', 'HOPKINS', 32)
# ('GARY', 'PHOENIX', 25)
# ('CARMEN', 'HUNT', 26)
# ('MENA', 'TEMPLE', 30)
# ('PENELOPE', 'PINKETT', 25)
# ('FAY', 'KILMER', 20)
# ('DAN', 'HARRIS', 28)
# ('JUDE', 'CRUISE', 30)
# ('CHRISTIAN', 'AKROYD', 32)
# ('DUSTIN', 'TAUTOU', 27)
# ('HENRY', 'BERRY', 35)
# ('CHRISTIAN', 'NEESON', 25)
# ('JAYNE', 'NEESON', 29)
# ('CAMERON', 'WRAY', 19)
# ('RAY', 'JOHANSSON', 30)
# ('ANGELA', 'HUDSON', 34)
# ('MARY', 'TANDY', 31)
# ('JESSICA', 'BAILEY', 23)
# ('RIP', 'WINSLET', 30)
# ('KENNETH', 'PALTROW', 21)
# ('MICHELLE', 'MCCONAUGHEY', 23)
# ('ADAM', 'GRANT', 18)
# ('SEAN', 'WILLIAMS', 26)
# ('GARY', 'PENN', 26)
# ('MILLA', 'KEITEL', 28)
# ('BURT', 'POSEY', 24)
# ('ANGELINA', 'ASTAIRE', 31)
# ('CARY', 'MCCONAUGHEY', 24)
# ('GROUCHO', 'SINATRA', 26)
# ('MAE', 'HOFFMAN', 28)
# ('RALPH', 'CRUZ', 28)
# ('SCARLETT', 'DAMON', 36)
# ('WOODY', 'JOLIE', 31)
# ('BEN', 'WILLIS', 33)
# ('JAMES', 'PITT', 31)
# ('MINNIE', 'ZELLWEGER', 31)
# ('GREG', 'CHAPLIN', 27)
# ('SPENCER', 'PECK', 21)
# ('KENNETH', 'PESCI', 20)
# ('CHARLIZE', 'DENCH', 24)
# ('SEAN', 'GUINESS', 33)
# ('CHRISTOPHER', 'BERRY', 20)
# ('KIRSTEN', 'AKROYD', 34)
# ('ELLEN', 'PRESLEY', 25)
# ('KENNETH', 'TORN', 33)
# ('DARYL', 'WAHLBERG', 31)
# ('GENE', 'WILLIS', 23)
# ('MEG', 'HAWKE', 27)
# ('CHRIS', 'BRIDGES', 27)
# ('JIM', 'MOSTEL', 26)
# ('SPENCER', 'DEPP', 24)
# ('SUSAN', 'DAVIS', 54)
# ('WALTER', 'TORN', 41)
# ('MATTHEW', 'LEIGH', 30)
# ('PENELOPE', 'CRONYN', 31)
# ('SIDNEY', 'CROWE', 34)
# ('GROUCHO', 'DUNST', 35)
# ('GINA', 'DEGENERES', 42)
# ('WARREN', 'NOLTE', 34)
# ('SYLVESTER', 'DERN', 22)
# ('CAMERON', 'ZELLWEGER', 33)
# ('RUSSELL', 'BACALL', 25)
# ('MORGAN', 'HOPKINS', 27)
# ('MORGAN', 'MCDORMAND', 25)
# ('HARRISON', 'BALE', 28)
# ('DAN', 'STREEP', 24)
# ('RENEE', 'TRACY', 33)
# ('CUBA', 'ALLEN', 25)
# ('WARREN', 'JACKMAN', 32)
# ('PENELOPE', 'MONROE', 27)
# ('LIZA', 'BERGMAN', 25)
# ('SALMA', 'NOLTE', 25)
# ('JULIANNE', 'DENCH', 32)
# ('SCARLETT', 'BENING', 26)
# ('ALBERT', 'NOLTE', 31)
# ('FRANCES', 'TOMEI', 23)
# ('KEVIN', 'GARLAND', 33)
# ('CATE', 'MCQUEEN', 30)
# ('DARYL', 'CRAWFORD', 30)
# ('GRETA', 'KEITEL', 27)
# ('JANE', 'JACKMAN', 25)
# ('ADAM', 'HOPPER', 22)
# ('RICHARD', 'PENN', 30)
# ('GENE', 'HOPKINS', 22)
# ('RITA', 'REYNOLDS', 20)
# ('ED', 'MANSFIELD', 32)
# ('MORGAN', 'WILLIAMS', 27)
# ('LUCILLE', 'DEE', 24)
# ('EWAN', 'GOODING', 33)
# ('WHOOPI', 'HURT', 32)
# ('CATE', 'HARRIS', 28)
# ('JADA', 'RYDER', 31)
# ('RIVER', 'DEAN', 31)
# ('ANGELA', 'WITHERSPOON', 35)
# ('KIM', 'ALLEN', 28)
# ('ALBERT', 'JOHANSSON', 33)
# ('FAY', 'WINSLET', 31)
# ('EMILY', 'DEE', 14)
# ('RUSSELL', 'TEMPLE', 31)
# ('JAYNE', 'NOLTE', 34)
# ('GEOFFREY', 'HESTON', 26)
# ('BEN', 'HARRIS', 23)
# ('MINNIE', 'KILMER', 20)
# ('MERYL', 'GIBSON', 28)
# ('IAN', 'TANDY', 31)
# ('FAY', 'WOOD', 22)
# ('GRETA', 'MALDEN', 32)
# ('VIVIEN', 'BASINGER', 35)
# ('LAURA', 'BRODY', 26)
# ('CHRIS', 'DEPP', 20)
# ('HARVEY', 'HOPE', 32)
# ('OPRAH', 'KILMER', 25)
# ('CHRISTOPHER', 'WEST', 21)
# ('HUMPHREY', 'WILLIS', 26)
# ('AL', 'GARLAND', 26)
# ('NICK', 'DEGENERES', 22)
# ('LAURENCE', 'BULLOCK', 26)
# ('WILL', 'WILSON', 31)
# ('KENNETH', 'HOFFMAN', 29)
# ('MENA', 'HOPPER', 24)
# ('OLYMPIA', 'PFEIFFER', 28)
# ('GROUCHO', 'WILLIAMS', 25)
# ('ALAN', 'DREYFUSS', 27)
# ('MICHAEL', 'BENING', 24)
# ('WILLIAM', 'HACKMAN', 27)
# ('JON', 'CHASE', 29)
# ('GENE', 'MCKELLEN', 27)
# ('LISA', 'MONROE', 23)
# ('ED', 'GUINESS', 29)
# ('JEFF', 'SILVERSTONE', 25)
# ('MATTHEW', 'CARREY', 39)
# ('DEBBIE', 'AKROYD', 24)
# ('RUSSELL', 'CLOSE', 19)
# ('HUMPHREY', 'GARLAND', 29)
# ('MICHAEL', 'BOLGER', 30)
# ('JULIA', 'ZELLWEGER', 16)
# ('RENEE', 'BALL', 33)
# ('ROCK', 'DUKAKIS', 30)
# ('CUBA', 'BIRCH', 24)
# ('AUDREY', 'BAILEY', 27)
# ('GREGORY', 'GOODING', 30)
# ('JOHN', 'SUVARI', 29)
# ('BURT', 'TEMPLE', 23)
# ('MERYL', 'ALLEN', 22)
# ('JAYNE', 'SILVERSTONE', 27)
# ('BELA', 'WALKEN', 30)
# ('REESE', 'WEST', 33)
# ('MARY', 'KEITEL', 40)
# ('JULIA', 'FAWCETT', 15)
# ('THORA', 'TEMPLE', 20)
#             0             1   2
# 0    PENELOPE       GUINESS  19
# 1        NICK      WAHLBERG  25
# 2          ED         CHASE  22
# 3    JENNIFER         DAVIS  22
# 4      JOHNNY  LOLLOBRIGIDA  29
# ..        ...           ...  ..
# 194      BELA        WALKEN  30
# 195     REESE          WEST  33
# 196      MARY        KEITEL  40
# 197     JULIA       FAWCETT  15
# 198     THORA        TEMPLE  20
#
# [199 rows x 3 columns]
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 1)
# (23, 'ANACONDA CONFESSIONS', 'A Lacklusture Display of a Dentist And a Dentist who must Fight a Girl in Australia', 2006, 1, None, 3, Decimal('0.99'), 92, Decimal('9.99'), 'R', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 23)
# (25, 'ANGELS LIFE', 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin', 2006, 1, None, 3, Decimal('2.99'), 74, Decimal('15.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 25)
# (106, 'BULWORTH COMMANDMENTS', 'A Amazing Display of a Mad Cow And a Pioneer who must Redeem a Sumo Wrestler in The Outback', 2006, 1, None, 4, Decimal('2.99'), 61, Decimal('14.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 106)
# (140, 'CHEAPER CLYDE', 'A Emotional Character Study of a Pioneer And a Girl who must Discover a Dog in Ancient Japan', 2006, 1, None, 6, Decimal('0.99'), 87, Decimal('23.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 140)
# (166, 'COLOR PHILADELPHIA', 'A Thoughtful Panorama of a Car And a Crocodile who must Sink a Monkey in The Sahara Desert', 2006, 1, None, 6, Decimal('2.99'), 149, Decimal('19.99'), 'G', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 166)
# (277, 'ELEPHANT TROJAN', 'A Beautiful Panorama of a Lumberjack And a Forensic Psychologist who must Overcome a Frisbee in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 126, Decimal('24.99'), 'PG-13', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 277)
# (361, 'GLEAMING JAWBREAKER', 'A Amazing Display of a Composer And a Forensic Psychologist who must Discover a Car in The Canadian Rockies', 2006, 1, None, 5, Decimal('2.99'), 89, Decimal('25.99'), 'NC-17', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 361)
# (438, 'HUMAN GRAFFITI', 'A Beautiful Reflection of a Womanizer And a Sumo Wrestler who must Chase a Database Administrator in The Gulf of Mexico', 2006, 1, None, 3, Decimal('2.99'), 68, Decimal('22.99'), 'NC-17', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 438)
# (499, 'KING EVOLUTION', 'A Action-Packed Tale of a Boy And a Lumberjack who must Chase a Madman in A Baloon', 2006, 1, None, 3, Decimal('4.99'), 184, Decimal('24.99'), 'NC-17', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 499)
# (506, 'LADY STAGE', 'A Beautiful Character Study of a Woman And a Man who must Pursue a Explorer in A U-Boat', 2006, 1, None, 4, Decimal('4.99'), 67, Decimal('14.99'), 'PG', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 506)
# (509, 'LANGUAGE COWBOY', 'A Epic Yarn of a Cat And a Madman who must Vanquish a Dentist in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('0.99'), 78, Decimal('26.99'), 'NC-17', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 509)
# (605, 'MULHOLLAND BEAST', 'A Awe-Inspiring Display of a Husband And a Squirrel who must Battle a Sumo Wrestler in A Jet Boat', 2006, 1, None, 7, Decimal('2.99'), 157, Decimal('13.99'), 'PG', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 605)
# (635, 'OKLAHOMA JUMANJI', 'A Thoughtful Drama of a Dentist And a Womanizer who must Meet a Husband in The Sahara Desert', 2006, 1, None, 7, Decimal('0.99'), 58, Decimal('15.99'), 'PG', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 635)
# (749, 'RULES HUMAN', 'A Beautiful Epistle of a Astronaut And a Student who must Confront a Monkey in An Abandoned Fun House', 2006, 1, None, 6, Decimal('4.99'), 153, Decimal('19.99'), 'R', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 749)
# (832, 'SPLASH GUMP', 'A Taut Saga of a Crocodile And a Boat who must Conquer a Hunter in A Shark Tank', 2006, 1, None, 5, Decimal('0.99'), 175, Decimal('16.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 832)
# (939, 'VERTIGO NORTHWEST', 'A Unbelieveable Display of a Mad Scientist And a Mad Scientist who must Outgun a Mad Cow in Ancient Japan', 2006, 1, None, 4, Decimal('2.99'), 90, Decimal('17.99'), 'R', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 939)
# (970, 'WESTWARD SEABISCUIT', 'A Lacklusture Tale of a Butler And a Husband who must Face a Boy in Ancient China', 2006, 1, None, 7, Decimal('0.99'), 52, Decimal('11.99'), 'NC-17', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 970)
# (980, 'WIZARD COLDBLOODED', 'A Lacklusture Display of a Robot And a Girl who must Defeat a Sumo Wrestler in A MySQL Convention', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('12.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'PENELOPE', 'GUINESS', 980)
# (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 3)
# (31, 'APACHE DIVINE', 'A Awe-Inspiring Reflection of a Pastry Chef And a Teacher who must Overcome a Sumo Wrestler in A U-Boat', 2006, 1, None, 5, Decimal('4.99'), 92, Decimal('16.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 31)
# (47, 'BABY HALL', 'A Boring Character Study of a A Shark And a Girl who must Outrace a Feminist in An Abandoned Mine Shaft', 2006, 1, None, 5, Decimal('4.99'), 153, Decimal('23.99'), 'NC-17', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 47)
# (105, 'BULL SHAWSHANK', 'A Fanciful Drama of a Moose And a Squirrel who must Conquer a Pioneer in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 125, Decimal('21.99'), 'NC-17', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 105)
# (132, 'CHAINSAW UPTOWN', 'A Beautiful Documentary of a Boy And a Robot who must Discover a Squirrel in Australia', 2006, 1, None, 6, Decimal('0.99'), 114, Decimal('25.99'), 'PG', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 132)
# (145, 'CHISUM BEHAVIOR', 'A Epic Documentary of a Sumo Wrestler And a Butler who must Kill a Car in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 124, Decimal('25.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 145)
# (226, 'DESTINY SATURDAY', 'A Touching Drama of a Crocodile And a Crocodile who must Conquer a Explorer in Soviet Georgia', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('20.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 226)
# (249, 'DRACULA CRYSTAL', 'A Thrilling Reflection of a Feminist And a Cat who must Find a Frisbee in An Abandoned Fun House', 2006, 1, None, 7, Decimal('0.99'), 176, Decimal('26.99'), 'G', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 249)
# (314, 'FIGHT JAWBREAKER', 'A Intrepid Panorama of a Womanizer And a Girl who must Escape a Girl in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 91, Decimal('13.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 314)
# (321, 'FLASH WARS', 'A Astounding Saga of a Moose And a Pastry Chef who must Chase a Student in The Gulf of Mexico', 2006, 1, None, 3, Decimal('4.99'), 123, Decimal('21.99'), 'NC-17', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 321)
# (357, 'GILBERT PELICAN', 'A Fateful Tale of a Man And a Feminist who must Conquer a Crocodile in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 114, Decimal('13.99'), 'G', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 357)
# (369, 'GOODFELLAS SALUTE', 'A Unbelieveable Tale of a Dog And a Explorer who must Sink a Mad Cow in A Baloon Factory', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('22.99'), 'PG', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 369)
# (399, 'HAPPINESS UNITED', 'A Action-Packed Panorama of a Husband And a Feminist who must Meet a Forensic Psychologist in Ancient Japan', 2006, 1, None, 6, Decimal('2.99'), 100, Decimal('23.99'), 'G', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 399)
# (458, 'INDIAN LOVE', 'A Insightful Saga of a Mad Scientist And a Mad Scientist who must Kill a Astronaut in An Abandoned Fun House', 2006, 1, None, 4, Decimal('0.99'), 135, Decimal('26.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 458)
# (481, 'JEKYLL FROGMEN', 'A Fanciful Epistle of a Student And a Astronaut who must Kill a Waitress in A Shark Tank', 2006, 1, None, 4, Decimal('2.99'), 58, Decimal('22.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 481)
# (485, 'JERSEY SASSY', 'A Lacklusture Documentary of a Madman And a Mad Cow who must Find a Feminist in Ancient Japan', 2006, 1, None, 6, Decimal('4.99'), 60, Decimal('16.99'), 'PG', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 485)
# (518, 'LIAISONS SWEET', 'A Boring Drama of a A Shark And a Explorer who must Redeem a Waitress in The Canadian Rockies', 2006, 1, None, 5, Decimal('4.99'), 140, Decimal('15.99'), 'PG', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 518)
# (540, 'LUCKY FLYING', 'A Lacklusture Character Study of a A Shark And a Man who must Find a Forensic Psychologist in A U-Boat', 2006, 1, None, 7, Decimal('2.99'), 97, Decimal('10.99'), 'PG-13', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 540)
# (550, 'MAGUIRE APACHE', 'A Fast-Paced Reflection of a Waitress And a Hunter who must Defeat a Forensic Psychologist in A Baloon', 2006, 1, None, 6, Decimal('2.99'), 74, Decimal('22.99'), 'NC-17', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 550)
# (555, 'MALLRATS UNITED', 'A Thrilling Yarn of a Waitress And a Dentist who must Find a Hunter in A Monastery', 2006, 1, None, 4, Decimal('0.99'), 133, Decimal('25.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 555)
# (561, 'MASK PEACH', 'A Boring Character Study of a Student And a Robot who must Meet a Woman in California', 2006, 1, None, 6, Decimal('2.99'), 123, Decimal('26.99'), 'NC-17', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 561)
# (742, 'ROOF CHAMPION', 'A Lacklusture Reflection of a Car And a Explorer who must Find a Monkey in A Baloon', 2006, 1, None, 7, Decimal('0.99'), 101, Decimal('25.99'), 'R', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 742)
# (754, 'RUSHMORE MERMAID', 'A Boring Story of a Woman And a Moose who must Reach a Husband in A Shark Tank', 2006, 1, None, 6, Decimal('2.99'), 150, Decimal('17.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 754)
# (811, 'SMILE EARRING', 'A Intrepid Drama of a Teacher And a Butler who must Build a Pastry Chef in Berlin', 2006, 1, None, 4, Decimal('2.99'), 60, Decimal('29.99'), 'G', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 811)
# (958, 'WARDROBE PHANTOM', 'A Action-Packed Display of a Mad Cow And a Astronaut who must Kill a Car in Ancient India', 2006, 1, None, 6, Decimal('2.99'), 178, Decimal('19.99'), 'G', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'NICK', 'WAHLBERG', 958)
# (17, 'ALONE TRIP', 'A Fast-Paced Character Study of a Composer And a Dog who must Outgun a Boat in An Abandoned Fun House', 2006, 1, None, 3, Decimal('0.99'), 82, Decimal('14.99'), 'R', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 17)
# (40, 'ARMY FLINTSTONES', 'A Boring Saga of a Database Administrator And a Womanizer who must Battle a Waitress in Nigeria', 2006, 1, None, 4, Decimal('0.99'), 148, Decimal('22.99'), 'R', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 40)
# (42, 'ARTIST COLDBLOODED', 'A Stunning Reflection of a Robot And a Moose who must Challenge a Woman in California', 2006, 1, None, 5, Decimal('2.99'), 170, Decimal('10.99'), 'NC-17', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 42)
# (87, 'BOONDOCK BALLROOM', 'A Fateful Panorama of a Crocodile And a Boy who must Defeat a Monkey in The Gulf of Mexico', 2006, 1, None, 7, Decimal('0.99'), 76, Decimal('14.99'), 'NC-17', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 87)
# (111, 'CADDYSHACK JEDI', 'A Awe-Inspiring Epistle of a Woman And a Madman who must Fight a Robot in Soviet Georgia', 2006, 1, None, 3, Decimal('0.99'), 52, Decimal('17.99'), 'NC-17', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 111)
# (185, 'COWBOY DOOM', 'A Astounding Drama of a Boy And a Lumberjack who must Fight a Butler in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 146, Decimal('10.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 185)
# (289, 'EVE RESURRECTION', 'A Awe-Inspiring Yarn of a Pastry Chef And a Database Administrator who must Challenge a Teacher in A Baloon', 2006, 1, None, 5, Decimal('4.99'), 66, Decimal('25.99'), 'G', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 289)
# (329, 'FORREST SONS', 'A Thrilling Documentary of a Forensic Psychologist And a Butler who must Defeat a Explorer in A Jet Boat', 2006, 1, None, 4, Decimal('2.99'), 63, Decimal('15.99'), 'R', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 329)
# (336, 'FRENCH HOLIDAY', 'A Thrilling Epistle of a Dog And a Feminist who must Kill a Madman in Berlin', 2006, 1, None, 5, Decimal('4.99'), 99, Decimal('22.99'), 'PG', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 336)
# (341, 'FROST HEAD', 'A Amazing Reflection of a Lumberjack And a Cat who must Discover a Husband in A MySQL Convention', 2006, 1, None, 5, Decimal('0.99'), 82, Decimal('13.99'), 'PG', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 341)
# (393, 'HALLOWEEN NUTS', 'A Amazing Panorama of a Forensic Psychologist And a Technical Writer who must Fight a Dentist in A U-Boat', 2006, 1, None, 6, Decimal('2.99'), 47, Decimal('19.99'), 'PG-13', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 393)
# (441, 'HUNTER ALTER', 'A Emotional Drama of a Mad Cow And a Boat who must Redeem a Secret Agent in A Shark Tank', 2006, 1, None, 5, Decimal('2.99'), 125, Decimal('21.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 441)
# (453, 'IMAGE PRINCESS', 'A Lacklusture Panorama of a Secret Agent And a Crocodile who must Discover a Madman in The Canadian Rockies', 2006, 1, None, 3, Decimal('2.99'), 178, Decimal('17.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 453)
# (480, 'JEEPERS WEDDING', 'A Astounding Display of a Composer And a Dog who must Kill a Pastry Chef in Soviet Georgia', 2006, 1, None, 3, Decimal('2.99'), 84, Decimal('29.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 480)
# (539, 'LUCK OPUS', 'A Boring Display of a Moose And a Squirrel who must Outrace a Teacher in A Shark Tank', 2006, 1, None, 7, Decimal('2.99'), 152, Decimal('21.99'), 'NC-17', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 539)
# (618, 'NECKLACE OUTBREAK', 'A Astounding Epistle of a Database Administrator And a Mad Scientist who must Pursue a Cat in California', 2006, 1, None, 3, Decimal('0.99'), 132, Decimal('21.99'), 'PG', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 618)
# (685, 'PLATOON INSTINCT', 'A Thrilling Panorama of a Man And a Woman who must Reach a Woman in Australia', 2006, 1, None, 6, Decimal('4.99'), 132, Decimal('10.99'), 'PG-13', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 685)
# (827, 'SPICE SORORITY', 'A Fateful Display of a Pioneer And a Hunter who must Defeat a Husband in An Abandoned Mine Shaft', 2006, 1, None, 5, Decimal('4.99'), 141, Decimal('22.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 827)
# (966, 'WEDDING APOLLO', 'A Action-Packed Tale of a Student And a Waitress who must Conquer a Lumberjack in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('0.99'), 70, Decimal('14.99'), 'PG', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 966)
# (967, 'WEEKEND PERSONAL', 'A Fast-Paced Documentary of a Car And a Butler who must Find a Frisbee in A Jet Boat', 2006, 1, None, 5, Decimal('2.99'), 134, Decimal('26.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 967)
# (971, 'WHALE BIKINI', 'A Intrepid Story of a Pastry Chef And a Database Administrator who must Kill a Feminist in A MySQL Convention', 2006, 1, None, 4, Decimal('4.99'), 109, Decimal('11.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 971)
# (996, 'YOUNG LANGUAGE', 'A Unbelieveable Yarn of a Boat And a Database Administrator who must Meet a Boy in The First Manned Space Station', 2006, 1, None, 6, Decimal('0.99'), 183, Decimal('9.99'), 'G', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'ED', 'CHASE', 996)
# (23, 'ANACONDA CONFESSIONS', 'A Lacklusture Display of a Dentist And a Dentist who must Fight a Girl in Australia', 2006, 1, None, 3, Decimal('0.99'), 92, Decimal('9.99'), 'R', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 23)
# (25, 'ANGELS LIFE', 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin', 2006, 1, None, 3, Decimal('2.99'), 74, Decimal('15.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 25)
# (56, 'BAREFOOT MANCHURIAN', 'A Intrepid Story of a Cat And a Student who must Vanquish a Girl in An Abandoned Amusement Park', 2006, 1, None, 6, Decimal('2.99'), 129, Decimal('15.99'), 'G', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 56)
# (62, 'BED HIGHBALL', 'A Astounding Panorama of a Lumberjack And a Dog who must Redeem a Woman in An Abandoned Fun House', 2006, 1, None, 5, Decimal('2.99'), 106, Decimal('23.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 62)
# (79, 'BLADE POLISH', 'A Thoughtful Character Study of a Frisbee And a Pastry Chef who must Fight a Dentist in The First Manned Space Station', 2006, 1, None, 5, Decimal('0.99'), 114, Decimal('10.99'), 'PG-13', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 79)
# (87, 'BOONDOCK BALLROOM', 'A Fateful Panorama of a Crocodile And a Boy who must Defeat a Monkey in The Gulf of Mexico', 2006, 1, None, 7, Decimal('0.99'), 76, Decimal('14.99'), 'NC-17', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 87)
# (355, 'GHOSTBUSTERS ELF', 'A Thoughtful Epistle of a Dog And a Feminist who must Chase a Composer in Berlin', 2006, 1, None, 7, Decimal('0.99'), 101, Decimal('18.99'), 'R', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 355)
# (379, 'GREEDY ROOTS', 'A Amazing Reflection of a A Shark And a Butler who must Chase a Hunter in The Canadian Rockies', 2006, 1, None, 7, Decimal('0.99'), 166, Decimal('14.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 379)
# (398, 'HANOVER GALAXY', 'A Stunning Reflection of a Girl And a Secret Agent who must Succumb a Boy in A MySQL Convention', 2006, 1, None, 5, Decimal('4.99'), 47, Decimal('21.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 398)
# (463, 'INSTINCT AIRPORT', 'A Touching Documentary of a Mad Cow And a Explorer who must Confront a Butler in A Manhattan Penthouse', 2006, 1, None, 4, Decimal('2.99'), 116, Decimal('21.99'), 'PG', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 463)
# (490, 'JUMANJI BLADE', 'A Intrepid Yarn of a Husband And a Womanizer who must Pursue a Mad Scientist in New Orleans', 2006, 1, None, 4, Decimal('2.99'), 121, Decimal('13.99'), 'G', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 490)
# (616, 'NATIONAL STORY', 'A Taut Epistle of a Mad Scientist And a Girl who must Escape a Monkey in California', 2006, 1, None, 4, Decimal('2.99'), 92, Decimal('19.99'), 'NC-17', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 616)
# (635, 'OKLAHOMA JUMANJI', 'A Thoughtful Drama of a Dentist And a Womanizer who must Meet a Husband in The Sahara Desert', 2006, 1, None, 7, Decimal('0.99'), 58, Decimal('15.99'), 'PG', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 635)
# (691, 'POSEIDON FOREVER', 'A Thoughtful Epistle of a Womanizer And a Monkey who must Vanquish a Dentist in A Monastery', 2006, 1, None, 6, Decimal('4.99'), 159, Decimal('29.99'), 'PG-13', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 691)
# (712, 'RAIDERS ANTITRUST', 'A Amazing Drama of a Teacher And a Feminist who must Meet a Woman in The First Manned Space Station', 2006, 1, None, 4, Decimal('0.99'), 82, Decimal('11.99'), 'PG-13', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 712)
# (714, 'RANDOM GO', 'A Fateful Drama of a Frisbee And a Student who must Confront a Cat in A Shark Tank', 2006, 1, None, 6, Decimal('2.99'), 73, Decimal('29.99'), 'NC-17', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 714)
# (721, 'REDS POCUS', 'A Lacklusture Yarn of a Sumo Wrestler And a Squirrel who must Redeem a Monkey in Soviet Georgia', 2006, 1, None, 7, Decimal('4.99'), 182, Decimal('23.99'), 'PG-13', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 721)
# (798, 'SILVERADO GOLDFINGER', 'A Stunning Epistle of a Sumo Wrestler And a Man who must Challenge a Waitress in Ancient India', 2006, 1, None, 4, Decimal('4.99'), 74, Decimal('11.99'), 'PG', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 798)
# (832, 'SPLASH GUMP', 'A Taut Saga of a Crocodile And a Boat who must Conquer a Hunter in A Shark Tank', 2006, 1, None, 5, Decimal('0.99'), 175, Decimal('16.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 832)
# (858, 'SUBMARINE BED', 'A Amazing Display of a Car And a Monkey who must Fight a Teacher in Soviet Georgia', 2006, 1, None, 5, Decimal('4.99'), 127, Decimal('21.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 858)
# (909, 'TREASURE COMMAND', 'A Emotional Saga of a Car And a Madman who must Discover a Pioneer in California', 2006, 1, None, 3, Decimal('0.99'), 102, Decimal('28.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 909)
# (924, 'UNFORGIVEN ZOOLANDER', 'A Taut Epistle of a Monkey And a Sumo Wrestler who must Vanquish a A Shark in A Baloon Factory', 2006, 1, None, 7, Decimal('0.99'), 129, Decimal('15.99'), 'PG', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JENNIFER', 'DAVIS', 924)
# (19, 'AMADEUS HOLY', 'A Emotional Display of a Pioneer And a Technical Writer who must Battle a Man in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 113, Decimal('20.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 19)
# (54, 'BANGER PINOCCHIO', 'A Awe-Inspiring Drama of a Car And a Pastry Chef who must Chase a Crocodile in The First Manned Space Station', 2006, 1, None, 5, Decimal('0.99'), 113, Decimal('15.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 54)
# (85, 'BONNIE HOLOCAUST', 'A Fast-Paced Story of a Crocodile And a Robot who must Find a Moose in Ancient Japan', 2006, 1, None, 4, Decimal('0.99'), 63, Decimal('29.99'), 'G', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 85)
# (146, 'CHITTY LOCK', 'A Boring Epistle of a Boat And a Database Administrator who must Kill a Sumo Wrestler in The First Manned Space Station', 2006, 1, None, 6, Decimal('2.99'), 107, Decimal('24.99'), 'G', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 146)
# (171, 'COMMANDMENTS EXPRESS', 'A Fanciful Saga of a Student And a Mad Scientist who must Battle a Hunter in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('4.99'), 59, Decimal('13.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 171)
# (172, 'CONEHEADS SMOOCHY', 'A Touching Story of a Womanizer And a Composer who must Pursue a Husband in Nigeria', 2006, 1, None, 7, Decimal('4.99'), 112, Decimal('12.99'), 'NC-17', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 172)
# (202, 'DADDY PITTSBURGH', 'A Epic Story of a A Shark And a Student who must Confront a Explorer in The Gulf of Mexico', 2006, 1, None, 5, Decimal('4.99'), 161, Decimal('26.99'), 'G', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 202)
# (203, 'DAISY MENAGERIE', 'A Fast-Paced Saga of a Pastry Chef And a Monkey who must Sink a Composer in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 84, Decimal('9.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 203)
# (286, 'ENOUGH RAGING', 'A Astounding Character Study of a Boat And a Secret Agent who must Find a Mad Cow in The Sahara Desert', 2006, 1, None, 7, Decimal('2.99'), 158, Decimal('16.99'), 'NC-17', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 286)
# (288, 'ESCAPE METROPOLIS', 'A Taut Yarn of a Astronaut And a Technical Writer who must Outgun a Boat in New Orleans', 2006, 1, None, 7, Decimal('2.99'), 167, Decimal('20.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 288)
# (316, 'FIRE WOLVES', 'A Intrepid Documentary of a Frisbee And a Dog who must Outrace a Lumberjack in Nigeria', 2006, 1, None, 5, Decimal('4.99'), 173, Decimal('18.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 316)
# (340, 'FRONTIER CABIN', 'A Emotional Story of a Madman And a Waitress who must Battle a Teacher in An Abandoned Fun House', 2006, 1, None, 6, Decimal('4.99'), 183, Decimal('14.99'), 'PG-13', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 340)
# (369, 'GOODFELLAS SALUTE', 'A Unbelieveable Tale of a Dog And a Explorer who must Sink a Mad Cow in A Baloon Factory', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('22.99'), 'PG', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 369)
# (375, 'GRAIL FRANKENSTEIN', 'A Unbelieveable Saga of a Teacher And a Monkey who must Fight a Girl in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('2.99'), 85, Decimal('17.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 375)
# (383, 'GROOVE FICTION', 'A Unbelieveable Reflection of a Moose And a A Shark who must Defeat a Lumberjack in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('0.99'), 111, Decimal('13.99'), 'NC-17', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 383)
# (392, 'HALL CASSIDY', 'A Beautiful Panorama of a Pastry Chef And a A Shark who must Battle a Pioneer in Soviet Georgia', 2006, 1, None, 5, Decimal('4.99'), 51, Decimal('13.99'), 'NC-17', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 392)
# (411, 'HEAVENLY GUN', 'A Beautiful Yarn of a Forensic Psychologist And a Frisbee who must Battle a Moose in A Jet Boat', 2006, 1, None, 5, Decimal('4.99'), 49, Decimal('13.99'), 'NC-17', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 411)
# (503, 'KRAMER CHOCOLATE', 'A Amazing Yarn of a Robot And a Pastry Chef who must Redeem a Mad Scientist in The Outback', 2006, 1, None, 3, Decimal('2.99'), 171, Decimal('24.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 503)
# (535, 'LOVE SUICIDES', 'A Brilliant Panorama of a Hunter And a Explorer who must Pursue a Dentist in An Abandoned Fun House', 2006, 1, None, 6, Decimal('0.99'), 181, Decimal('21.99'), 'R', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 535)
# (571, 'METAL ARMAGEDDON', 'A Thrilling Display of a Lumberjack And a Crocodile who must Meet a Monkey in A Baloon Factory', 2006, 1, None, 6, Decimal('2.99'), 161, Decimal('26.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 571)
# (650, 'PACIFIC AMISTAD', 'A Thrilling Yarn of a Dog And a Moose who must Kill a Pastry Chef in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 144, Decimal('27.99'), 'G', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 650)
# (665, 'PATTON INTERVIEW', 'A Thrilling Documentary of a Composer And a Secret Agent who must Succumb a Cat in Berlin', 2006, 1, None, 4, Decimal('2.99'), 175, Decimal('22.99'), 'PG', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 665)
# (687, 'POCUS PULP', 'A Intrepid Yarn of a Frisbee And a Dog who must Build a Astronaut in A Baloon Factory', 2006, 1, None, 6, Decimal('0.99'), 138, Decimal('15.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 687)
# (730, 'RIDGEMONT SUBMARINE', 'A Unbelieveable Drama of a Waitress And a Composer who must Sink a Mad Cow in Ancient Japan', 2006, 1, None, 3, Decimal('0.99'), 46, Decimal('28.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 730)
# (732, 'RINGS HEARTBREAKERS', 'A Amazing Yarn of a Sumo Wrestler And a Boat who must Conquer a Waitress in New Orleans', 2006, 1, None, 5, Decimal('0.99'), 58, Decimal('17.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 732)
# (811, 'SMILE EARRING', 'A Intrepid Drama of a Teacher And a Butler who must Build a Pastry Chef in Berlin', 2006, 1, None, 4, Decimal('2.99'), 60, Decimal('29.99'), 'G', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 811)
# (817, 'SOLDIERS EVOLUTION', 'A Lacklusture Panorama of a A Shark And a Pioneer who must Confront a Student in The First Manned Space Station', 2006, 1, None, 7, Decimal('4.99'), 185, Decimal('27.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 817)
# (841, 'STAR OPERATION', 'A Insightful Character Study of a Girl And a Car who must Pursue a Mad Cow in A Shark Tank', 2006, 1, None, 5, Decimal('2.99'), 181, Decimal('9.99'), 'PG', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 841)
# (865, 'SUNRISE LEAGUE', 'A Beautiful Epistle of a Madman And a Butler who must Face a Crocodile in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('4.99'), 135, Decimal('19.99'), 'PG-13', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JOHNNY', 'LOLLOBRIGIDA', 865)
# (29, 'ANTITRUST TOMATOES', 'A Fateful Yarn of a Womanizer And a Feminist who must Succumb a Database Administrator in Ancient India', 2006, 1, None, 5, Decimal('2.99'), 168, Decimal('11.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 29)
# (53, 'BANG KWAI', 'A Epic Drama of a Madman And a Cat who must Face a A Shark in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('2.99'), 87, Decimal('25.99'), 'NC-17', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 53)
# (60, 'BEAST HUNCHBACK', 'A Awe-Inspiring Epistle of a Student And a Squirrel who must Defeat a Boy in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 89, Decimal('22.99'), 'R', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 60)
# (70, 'BIKINI BORROWERS', 'A Astounding Drama of a Astronaut And a Cat who must Discover a Woman in The First Manned Space Station', 2006, 1, None, 7, Decimal('4.99'), 142, Decimal('26.99'), 'NC-17', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 70)
# (112, 'CALENDAR GUNFIGHT', 'A Thrilling Drama of a Frisbee And a Lumberjack who must Sink a Man in Nigeria', 2006, 1, None, 4, Decimal('4.99'), 120, Decimal('22.99'), 'NC-17', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 112)
# (164, 'COAST RAINBOW', 'A Astounding Documentary of a Mad Cow And a Pioneer who must Challenge a Butler in The Sahara Desert', 2006, 1, None, 4, Decimal('0.99'), 55, Decimal('20.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 164)
# (165, 'COLDBLOODED DARLING', 'A Brilliant Panorama of a Dentist And a Moose who must Find a Student in The Gulf of Mexico', 2006, 1, None, 7, Decimal('4.99'), 70, Decimal('27.99'), 'G', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 165)
# (193, 'CROSSROADS CASUALTIES', 'A Intrepid Documentary of a Sumo Wrestler And a Astronaut who must Battle a Composer in The Outback', 2006, 1, None, 5, Decimal('2.99'), 153, Decimal('20.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 193)
# (256, 'DROP WATERFRONT', 'A Fanciful Documentary of a Husband And a Explorer who must Reach a Madman in Ancient China', 2006, 1, None, 6, Decimal('4.99'), 178, Decimal('20.99'), 'R', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 256)
# (451, 'IGBY MAKER', 'A Epic Documentary of a Hunter And a Dog who must Outgun a Dog in A Baloon Factory', 2006, 1, None, 7, Decimal('4.99'), 160, Decimal('12.99'), 'NC-17', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 451)
# (503, 'KRAMER CHOCOLATE', 'A Amazing Yarn of a Robot And a Pastry Chef who must Redeem a Mad Scientist in The Outback', 2006, 1, None, 3, Decimal('2.99'), 171, Decimal('24.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 503)
# (509, 'LANGUAGE COWBOY', 'A Epic Yarn of a Cat And a Madman who must Vanquish a Dentist in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('0.99'), 78, Decimal('26.99'), 'NC-17', {'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 509)
# (517, 'LESSON CLEOPATRA', 'A Emotional Display of a Man And a Explorer who must Build a Boy in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 167, Decimal('28.99'), 'NC-17', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 517)
# (519, 'LIBERTY MAGNIFICENT', 'A Boring Drama of a Student And a Cat who must Sink a Technical Writer in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 138, Decimal('27.99'), 'G', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 519)
# (605, 'MULHOLLAND BEAST', 'A Awe-Inspiring Display of a Husband And a Squirrel who must Battle a Sumo Wrestler in A Jet Boat', 2006, 1, None, 7, Decimal('2.99'), 157, Decimal('13.99'), 'PG', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 605)
# (692, 'POTLUCK MIXED', 'A Beautiful Story of a Dog And a Technical Writer who must Outgun a Student in A Baloon', 2006, 1, None, 3, Decimal('2.99'), 179, Decimal('10.99'), 'G', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 692)
# (826, 'SPEED SUIT', 'A Brilliant Display of a Frisbee And a Mad Scientist who must Succumb a Robot in Ancient China', 2006, 1, None, 7, Decimal('4.99'), 124, Decimal('19.99'), 'PG-13', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 826)
# (892, 'TITANIC BOONDOCK', 'A Brilliant Reflection of a Feminist And a Dog who must Fight a Boy in A Baloon Factory', 2006, 1, None, 3, Decimal('4.99'), 104, Decimal('18.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 892)
# (902, 'TRADING PINOCCHIO', 'A Emotional Character Study of a Student And a Explorer who must Discover a Frisbee in The First Manned Space Station', 2006, 1, None, 6, Decimal('4.99'), 170, Decimal('22.99'), 'PG', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 902)
# (994, 'WYOMING STORM', 'A Awe-Inspiring Panorama of a Robot And a Boat who must Overcome a Feminist in A U-Boat', 2006, 1, None, 6, Decimal('4.99'), 100, Decimal('29.99'), 'PG-13', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'BETTE', 'NICHOLSON', 994)
# (25, 'ANGELS LIFE', 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin', 2006, 1, None, 3, Decimal('2.99'), 74, Decimal('15.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 25)
# (27, 'ANONYMOUS HUMAN', 'A Amazing Reflection of a Database Administrator And a Astronaut who must Outrace a Database Administrator in A Shark Tank', 2006, 1, None, 7, Decimal('0.99'), 179, Decimal('12.99'), 'NC-17', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 27)
# (35, 'ARACHNOPHOBIA ROLLERCOASTER', 'A Action-Packed Reflection of a Pastry Chef And a Composer who must Discover a Mad Scientist in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 147, Decimal('24.99'), 'PG-13', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 35)
# (67, 'BERETS AGENT', 'A Taut Saga of a Crocodile And a Boy who must Overcome a Technical Writer in Ancient China', 2006, 1, None, 5, Decimal('2.99'), 77, Decimal('24.99'), 'PG-13', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 67)
# (96, 'BREAKING HOME', 'A Beautiful Display of a Secret Agent And a Monkey who must Battle a Sumo Wrestler in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('2.99'), 169, Decimal('21.99'), 'PG-13', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 96)
# (170, 'COMMAND DARLING', 'A Awe-Inspiring Tale of a Forensic Psychologist And a Woman who must Challenge a Database Administrator in Ancient Japan', 2006, 1, None, 5, Decimal('4.99'), 120, Decimal('28.99'), 'PG-13', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 170)
# (173, 'CONFESSIONS MAGUIRE', 'A Insightful Story of a Car And a Boy who must Battle a Technical Writer in A Baloon', 2006, 1, None, 7, Decimal('4.99'), 65, Decimal('25.99'), 'PG-13', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 173)
# (217, 'DAZED PUNK', 'A Action-Packed Story of a Pioneer And a Technical Writer who must Discover a Forensic Psychologist in An Abandoned Amusement Park', 2006, 1, None, 6, Decimal('4.99'), 120, Decimal('20.99'), 'G', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'GRACE', 'MOSTEL', 217)
# ...
# (806, 'SLEEPY JAPANESE', 'A Emotional Epistle of a Moose And a Composer who must Fight a Technical Writer in The Outback', 2006, 1, None, 4, Decimal('2.99'), 137, Decimal('25.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 806)
# (817, 'SOLDIERS EVOLUTION', 'A Lacklusture Panorama of a A Shark And a Pioneer who must Confront a Student in The First Manned Space Station', 2006, 1, None, 7, Decimal('4.99'), 185, Decimal('27.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 817)
# (843, 'STEEL SANTA', 'A Fast-Paced Yarn of a Composer And a Frisbee who must Face a Moose in Nigeria', 2006, 1, None, 4, Decimal('4.99'), 143, Decimal('15.99'), 'NC-17', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 843)
# (858, 'SUBMARINE BED', 'A Amazing Display of a Car And a Monkey who must Fight a Teacher in Soviet Georgia', 2006, 1, None, 5, Decimal('4.99'), 127, Decimal('21.99'), 'R', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 858)
# (871, 'SWEDEN SHINING', 'A Taut Documentary of a Car And a Robot who must Conquer a Boy in The Canadian Rockies', 2006, 1, None, 6, Decimal('4.99'), 176, Decimal('19.99'), 'PG', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 871)
# (886, 'THEORY MERMAID', 'A Fateful Yarn of a Composer And a Monkey who must Vanquish a Womanizer in The First Manned Space Station', 2006, 1, None, 5, Decimal('0.99'), 184, Decimal('9.99'), 'PG-13', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 886)
# (892, 'TITANIC BOONDOCK', 'A Brilliant Reflection of a Feminist And a Dog who must Fight a Boy in A Baloon Factory', 2006, 1, None, 3, Decimal('4.99'), 104, Decimal('18.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 892)
# (924, 'UNFORGIVEN ZOOLANDER', 'A Taut Epistle of a Monkey And a Sumo Wrestler who must Vanquish a A Shark in A Baloon Factory', 2006, 1, None, 7, Decimal('0.99'), 129, Decimal('15.99'), 'PG', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 924)
# (952, 'WAGON JAWS', 'A Intrepid Drama of a Moose And a Boat who must Kill a Explorer in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('2.99'), 152, Decimal('17.99'), 'PG', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 952)
# (997, 'YOUTH KICK', 'A Touching Drama of a Teacher And a Cat who must Challenge a Technical Writer in A U-Boat', 2006, 1, None, 4, Decimal('0.99'), 179, Decimal('14.99'), 'NC-17', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'MARY', 'KEITEL', 997)
# (67, 'BERETS AGENT', 'A Taut Saga of a Crocodile And a Boy who must Overcome a Technical Writer in Ancient China', 2006, 1, None, 5, Decimal('2.99'), 77, Decimal('24.99'), 'PG-13', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 67)
# (84, 'BOILED DARES', 'A Awe-Inspiring Story of a Waitress And a Dog who must Discover a Dentist in Ancient Japan', 2006, 1, None, 7, Decimal('4.99'), 102, Decimal('13.99'), 'PG', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 84)
# (145, 'CHISUM BEHAVIOR', 'A Epic Documentary of a Sumo Wrestler And a Butler who must Kill a Car in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 124, Decimal('25.99'), 'G', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 145)
# (159, 'CLOSER BANG', 'A Unbelieveable Panorama of a Frisbee And a Hunter who must Vanquish a Monkey in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 58, Decimal('12.99'), 'R', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 159)
# (216, 'DAY UNFAITHFUL', 'A Stunning Documentary of a Composer And a Mad Scientist who must Find a Technical Writer in A U-Boat', 2006, 1, None, 3, Decimal('4.99'), 113, Decimal('16.99'), 'G', {'Commentaries', 'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 216)
# (432, 'HOPE TOOTSIE', 'A Amazing Documentary of a Student And a Sumo Wrestler who must Outgun a A Shark in A Shark Tank', 2006, 1, None, 4, Decimal('2.99'), 139, Decimal('22.99'), 'NC-17', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 432)
# (541, 'LUKE MUMMY', 'A Taut Character Study of a Boy And a Robot who must Redeem a Mad Scientist in Ancient India', 2006, 1, None, 5, Decimal('2.99'), 74, Decimal('21.99'), 'NC-17', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 541)
# (604, 'MULAN MOON', 'A Emotional Saga of a Womanizer And a Pioneer who must Overcome a Dentist in A Baloon', 2006, 1, None, 4, Decimal('0.99'), 160, Decimal('10.99'), 'G', {'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 604)
# (640, 'OPUS ICE', 'A Fast-Paced Drama of a Hunter And a Boy who must Discover a Feminist in The Sahara Desert', 2006, 1, None, 5, Decimal('4.99'), 102, Decimal('21.99'), 'R', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 640)
# (689, 'POLLOCK DELIVERANCE', 'A Intrepid Story of a Madman And a Frisbee who must Outgun a Boat in The Sahara Desert', 2006, 1, None, 5, Decimal('2.99'), 137, Decimal('14.99'), 'PG', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 689)
# (730, 'RIDGEMONT SUBMARINE', 'A Unbelieveable Drama of a Waitress And a Composer who must Sink a Mad Cow in Ancient Japan', 2006, 1, None, 3, Decimal('0.99'), 46, Decimal('28.99'), 'PG-13', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 730)
# (784, 'SHANGHAI TYCOON', 'A Fast-Paced Character Study of a Crocodile And a Lumberjack who must Build a Husband in An Abandoned Fun House', 2006, 1, None, 7, Decimal('2.99'), 47, Decimal('20.99'), 'PG', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 784)
# (785, 'SHAWSHANK BUBBLE', 'A Lacklusture Story of a Moose And a Monkey who must Confront a Butler in An Abandoned Amusement Park', 2006, 1, None, 6, Decimal('4.99'), 80, Decimal('20.99'), 'PG', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 785)
# (886, 'THEORY MERMAID', 'A Fateful Yarn of a Composer And a Monkey who must Vanquish a Womanizer in The First Manned Space Station', 2006, 1, None, 5, Decimal('0.99'), 184, Decimal('9.99'), 'PG-13', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 886)
# (953, 'WAIT CIDER', 'A Intrepid Epistle of a Woman And a Forensic Psychologist who must Succumb a Astronaut in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 112, Decimal('9.99'), 'PG-13', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'JULIA', 'FAWCETT', 953)
# (5, 'AFRICAN EGG', 'A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico', 2006, 1, None, 6, Decimal('2.99'), 130, Decimal('22.99'), 'G', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 5)
# (49, 'BADMAN DAWN', 'A Emotional Panorama of a Pioneer And a Composer who must Escape a Mad Scientist in A Jet Boat', 2006, 1, None, 6, Decimal('2.99'), 162, Decimal('22.99'), 'R', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 49)
# (80, 'BLANKET BEVERLY', 'A Emotional Documentary of a Student And a Girl who must Build a Boat in Nigeria', 2006, 1, None, 7, Decimal('2.99'), 148, Decimal('21.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 80)
# (116, 'CANDIDATE PERDITION', 'A Brilliant Epistle of a Composer And a Database Administrator who must Vanquish a Mad Scientist in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 70, Decimal('10.99'), 'R', {'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 116)
# (121, 'CAROL TEXAS', 'A Astounding Character Study of a Composer And a Student who must Overcome a Composer in A Monastery', 2006, 1, None, 4, Decimal('2.99'), 151, Decimal('15.99'), 'PG', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 121)
# (149, 'CHRISTMAS MOONSHINE', 'A Action-Packed Epistle of a Feminist And a Astronaut who must Conquer a Boat in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 150, Decimal('21.99'), 'NC-17', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 149)
# (346, 'GALAXY SWEETHEARTS', 'A Emotional Reflection of a Womanizer And a Pioneer who must Face a Squirrel in Berlin', 2006, 1, None, 4, Decimal('4.99'), 128, Decimal('13.99'), 'R', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 346)
# (419, 'HOCUS FRIDA', 'A Awe-Inspiring Tale of a Girl And a Madman who must Outgun a Student in A Shark Tank', 2006, 1, None, 4, Decimal('2.99'), 141, Decimal('19.99'), 'G', {'Deleted Scenes', 'Trailers', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 419)
# (462, 'INSIDER ARIZONA', 'A Astounding Saga of a Mad Scientist And a Hunter who must Pursue a Robot in A Baloon Factory', 2006, 1, None, 5, Decimal('2.99'), 78, Decimal('17.99'), 'NC-17', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 462)
# (465, 'INTERVIEW LIAISONS', 'A Action-Packed Reflection of a Student And a Butler who must Discover a Database Administrator in A Manhattan Penthouse', 2006, 1, None, 4, Decimal('4.99'), 59, Decimal('17.99'), 'R', {'Commentaries', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 465)
# (474, 'JADE BUNCH', 'A Insightful Panorama of a Squirrel And a Mad Cow who must Confront a Student in The First Manned Space Station', 2006, 1, None, 6, Decimal('2.99'), 174, Decimal('21.99'), 'NC-17', {'Commentaries', 'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 474)
# (537, 'LOVER TRUMAN', 'A Emotional Yarn of a Robot And a Boy who must Outgun a Technical Writer in A U-Boat', 2006, 1, None, 3, Decimal('2.99'), 75, Decimal('29.99'), 'G', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 537)
# (538, 'LOVERBOY ATTACKS', 'A Boring Story of a Car And a Butler who must Build a Girl in Soviet Georgia', 2006, 1, None, 7, Decimal('0.99'), 162, Decimal('19.99'), 'PG-13', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 538)
# (544, 'MADISON TRAP', 'A Awe-Inspiring Reflection of a Monkey And a Dentist who must Overcome a Pioneer in A U-Boat', 2006, 1, None, 4, Decimal('2.99'), 147, Decimal('11.99'), 'R', {'Commentaries', 'Deleted Scenes', 'Behind the Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 544)
# (714, 'RANDOM GO', 'A Fateful Drama of a Frisbee And a Student who must Confront a Cat in A Shark Tank', 2006, 1, None, 6, Decimal('2.99'), 73, Decimal('29.99'), 'NC-17', {'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 714)
# (879, 'TELEGRAPH VOYAGE', 'A Fateful Yarn of a Husband And a Dog who must Battle a Waitress in A Jet Boat', 2006, 1, None, 3, Decimal('4.99'), 148, Decimal('20.99'), 'PG', {'Commentaries'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 879)
# (912, 'TROJAN TOMORROW', 'A Astounding Panorama of a Husband And a Sumo Wrestler who must Pursue a Boat in Ancient India', 2006, 1, None, 3, Decimal('2.99'), 52, Decimal('9.99'), 'PG', {'Commentaries', 'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 912)
# (945, 'VIRGINIAN PLUTO', 'A Emotional Panorama of a Dentist And a Crocodile who must Meet a Boy in Berlin', 2006, 1, None, 5, Decimal('0.99'), 164, Decimal('22.99'), 'R', {'Deleted Scenes'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 945)
# (958, 'WARDROBE PHANTOM', 'A Action-Packed Display of a Mad Cow And a Astronaut who must Kill a Car in Ancient India', 2006, 1, None, 6, Decimal('2.99'), 178, Decimal('19.99'), 'G', {'Commentaries', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 958)
# (993, 'WRONG BEHAVIOR', 'A Emotional Saga of a Crocodile And a Sumo Wrestler who must Discover a Mad Cow in New Orleans', 2006, 1, None, 6, Decimal('2.99'), 178, Decimal('10.99'), 'PG-13', {'Behind the Scenes', 'Trailers'}, datetime.datetime(2006, 2, 15, 5, 3, 42), 'THORA', 'TEMPLE', 993)
#        0                      1   \
# 0       1       ACADEMY DINOSAUR
# 1      23   ANACONDA CONFESSIONS
# 2      25            ANGELS LIFE
# 3     106  BULWORTH COMMANDMENTS
# 4     140          CHEAPER CLYDE
# ...   ...                    ...
# 5457  879       TELEGRAPH VOYAGE
# 5458  912        TROJAN TOMORROW
# 5459  945        VIRGINIAN PLUTO
# 5460  958       WARDROBE PHANTOM
# 5461  993         WRONG BEHAVIOR
#
#                                                      2     3   4     5   6   \
# 0     A Epic Drama of a Feminist And a Mad Scientist...  2006   1  None   6
# 1     A Lacklusture Display of a Dentist And a Denti...  2006   1  None   3
# 2     A Thoughtful Display of a Woman And a Astronau...  2006   1  None   3
# 3     A Amazing Display of a Mad Cow And a Pioneer w...  2006   1  None   4
# 4     A Emotional Character Study of a Pioneer And a...  2006   1  None   6
# ...                                                 ...   ...  ..   ...  ..
# 5457  A Fateful Yarn of a Husband And a Dog who must...  2006   1  None   3
# 5458  A Astounding Panorama of a Husband And a Sumo ...  2006   1  None   3
# 5459  A Emotional Panorama of a Dentist And a Crocod...  2006   1  None   5
# 5460  A Action-Packed Display of a Mad Cow And a Ast...  2006   1  None   6
# 5461  A Emotional Saga of a Crocodile And a Sumo Wre...  2006   1  None   6
#
#         7    8      9      10                                           11  \
# 0     0.99   86  20.99     PG          {Deleted Scenes, Behind the Scenes}
# 1     0.99   92   9.99      R                   {Deleted Scenes, Trailers}
# 2     2.99   74  15.99      G                                   {Trailers}
# 3     2.99   61  14.99      G                                   {Trailers}
# 4     0.99   87  23.99      G  {Commentaries, Behind the Scenes, Trailers}
# ...    ...  ...    ...    ...                                          ...
# 5457  4.99  148  20.99     PG                               {Commentaries}
# 5458  2.99   52   9.99     PG               {Commentaries, Deleted Scenes}
# 5459  0.99  164  22.99      R                             {Deleted Scenes}
# 5460  2.99  178  19.99      G                     {Commentaries, Trailers}
# 5461  2.99  178  10.99  PG-13                {Behind the Scenes, Trailers}
#
#                       12        13       14   15
# 0    2006-02-15 05:03:42  PENELOPE  GUINESS    1
# 1    2006-02-15 05:03:42  PENELOPE  GUINESS   23
# 2    2006-02-15 05:03:42  PENELOPE  GUINESS   25
# 3    2006-02-15 05:03:42  PENELOPE  GUINESS  106
# 4    2006-02-15 05:03:42  PENELOPE  GUINESS  140
# ...                  ...       ...      ...  ...
# 5457 2006-02-15 05:03:42     THORA   TEMPLE  879
# 5458 2006-02-15 05:03:42     THORA   TEMPLE  912
# 5459 2006-02-15 05:03:42     THORA   TEMPLE  945
# 5460 2006-02-15 05:03:42     THORA   TEMPLE  958
# 5461 2006-02-15 05:03:42     THORA   TEMPLE  993
#
# [5462 rows x 16 columns]

# %% [markdown]
# # Challenge 1 - Working with JSON files
# Import the pandas library.

# %%
# your code here
import pandas as pd

# %% [markdown]
# In the next cell, load the data in nasa.json in the data folder and load it into a pandas dataframe. Name the dataframe nasa.

# %%
# your code here
nasa = pd.read_json("nasa.json")
nasa
# Out:
#      :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                            NaN                          NaN  Fell
# 1                            NaN                          NaN  Fell
# 2                            NaN                          NaN  Fell
# 3                            NaN                          NaN  Fell
# 4                            NaN                          NaN  Fell
# ..                           ...                          ...   ...
# 995                          NaN                          NaN  Fell
# 996                          NaN                          NaN  Fell
# 997                          NaN                          NaN  Fell
# 998                          NaN                          NaN  Fell
# 999                          NaN                          NaN  Fell
#
#                                            geolocation     id      mass  \
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....      1      21.0
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...      2     720.0
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...      6  107000.0
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88...     10    1914.0
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....    370     780.0
# ..                                                 ...    ...       ...
# 995  {'type': 'Point', 'coordinates': [79.41667, 13...  24009     230.0
# 996  {'type': 'Point', 'coordinates': [-7.61123, 29...  54823    7000.0
# 997  {'type': 'Point', 'coordinates': [111.53333, -...  24011   20000.0
# 998  {'type': 'Point', 'coordinates': [106.58333, -...  24012   16500.0
# 999  {'type': 'Point', 'coordinates': [34.76667, 47...  24019     600.0
#
#           name nametype               recclass    reclat    reclong  \
# 0       Aachen    Valid                     L5  50.77500    6.08333
# 1       Aarhus    Valid                     H6  56.18333   10.23333
# 2         Abee    Valid                    EH4  54.21667 -113.00000
# 3     Acapulco    Valid            Acapulcoite  16.88333  -99.90000
# 4      Achiras    Valid                     L6 -33.16667  -64.95000
# ..         ...      ...                    ...       ...        ...
# 995   Tirupati    Valid                     H6  13.63333   79.41667
# 996    Tissint    Valid  Martian (shergottite)  29.48195   -7.61123
# 997      Tjabe    Valid                     H6  -7.08333  111.53333
# 998   Tjerebon    Valid                     L5  -6.66667  106.58333
# 999  Tomakovka    Valid                    LL6  47.85000   34.76667
#
#                         year
# 0    1880-01-01T00:00:00.000
# 1    1951-01-01T00:00:00.000
# 2    1952-01-01T00:00:00.000
# 3    1976-01-01T00:00:00.000
# 4    1902-01-01T00:00:00.000
# ..                       ...
# 995  1934-01-01T00:00:00.000
# 996  2011-01-01T00:00:00.000
# 997  1869-01-01T00:00:00.000
# 998  1922-01-01T00:00:00.000
# 999  1905-01-01T00:00:00.000
#
# [1000 rows x 12 columns]

# %% [markdown]
# Now that we have loaded the data, let's examine it using the head() function.

# %%
# your code here
nasa.head()
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass      name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0    Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0    Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0      Abee
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0  Acapulco
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0   Achiras
#
#   nametype     recclass    reclat    reclong                     year
# 0    Valid           L5  50.77500    6.08333  1880-01-01T00:00:00.000
# 1    Valid           H6  56.18333   10.23333  1951-01-01T00:00:00.000
# 2    Valid          EH4  54.21667 -113.00000  1952-01-01T00:00:00.000
# 3    Valid  Acapulcoite  16.88333  -99.90000  1976-01-01T00:00:00.000
# 4    Valid           L6 -33.16667  -64.95000  1902-01-01T00:00:00.000

# %% [markdown]
# ####  The value_counts() function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the value_counts() function to determine the frequency of all types of asteroid landings by applying the function to the fall column.

# %%
# your code here
nasa['fall'].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the orient=records argument and name the file nasa-output.json. Remember to save the file inside the data folder.

# %%
# your code here
nasa.to_json("nasa-output.json", orient="records")

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# Import the pandas library
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
#Your pandas import here:

import pandas as pd

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:

shuttle=pd.read_csv(tst_url, sep=" ", names=cols)
shuttle
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
# ..   ...       ...        ...       ...   ...     ...        ...       ...
# 80     0        84          0       -36   -29       4        120       116
# 55     0        81          0       -20    25      26        102        76
# 55     0        77          0        12   -22      22         65        42
# 37     0       103          0        18   -16      66         85        20
# 56     2        98          0        52     1      42         46         4
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1
# ..    ...
# 80      5
# 55      4
# 55      4
# 37      1
# 56      4
#
# [14500 rows x 9 columns]

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# Your code here:
shuttle.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:

shuttle.to_csv("shuttle.csv", sep=",", index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:

astronaut = pd.read_excel("astronauts.xls")
astronaut
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active 1967-05-17
# 1           Loren W. Acton     NaN    NaN  Retired 1936-03-07
# 2         James C. Adamson  1984.0   10.0  Retired 1946-03-03
# 3          Thomas D. Akers  1987.0   12.0  Retired 1951-05-20
# 4              Buzz Aldrin  1963.0    3.0  Retired 1930-01-20
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired 1956-08-23
# 353  Neil W. Woodward III   1998.0   17.0  Retired 1962-07-26
# 354       Alfred M. Worden  1966.0    5.0  Retired 1932-02-07
# 355          John W. Young  1962.0    2.0  Retired 1930-09-24
# 356        George D. Zamka  1998.0   17.0  Retired 1962-06-29
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# 0             NaN                        NaN              2
# 1             NaN                        NaN              1
# 2         Colonel          US Army (Retired)              2
# 3         Colonel     US Air Force (Retired)              4
# 4         Colonel     US Air Force (Retired)              2
# ..            ...                        ...            ...
# 352           NaN                        NaN              3
# 353     Commander                    US Navy              0
# 354       Colonel     US Air Force (Retired)              1
# 355       Captain          US Navy (Retired)              6
# 356       Colonel  US Marine Corps (Retired)              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0                 3307            2              13.0
# 1                  190            0               0.0
# 2                  334            0               0.0
# 3                  814            4              29.0
# 4                  289            2               8.0
# ..                 ...          ...               ...
# 352               4044            7              41.0
# 353                  0            0               0.0
# 354                295            1               0.5
# 355                835            3              20.0
# 356                692            0               0.0
#
#                                               Missions Death Date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT
# 1                                STS 51-F (Challenger)        NaT
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaT
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT
# 4                                 Gemini 12, Apollo 11        NaT
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaT
# 353                                                NaN        NaT
# 354                                          Apollo 15        NaT
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaT
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaT
#
#     Death Mission
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 352           NaN
# 353           NaN
# 354           NaN
# 355           NaN
# 356           NaN
#
# [357 rows x 19 columns]

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:

astronaut.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN
# 1                              STS 51-F (Challenger)        NaT           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaT           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT           NaN
# 4                               Gemini 12, Apollo 11        NaT           NaN

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut["Undergraduate Major"].value_counts()
# Out:
# Physics                      35
# Aerospace Engineering        33
# Mechanical Engineering       30
# Aeronautical Engineering     28
# Electrical Engineering       23
#                              ..
# Bioscience                    1
# Animal Science                1
# Animal Nutrition              1
# Earth & Planetary Science     1
# Physiology                    1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:
astronaut.to_csv("astronaut.csv", sep="\t")

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:
