# %% [markdown]
# # Import and Export Files

# %% [markdown]
# # Challenge 0 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here

import sqlalchemy

import pymysql

import pandas as pd

import mysql.connector

import getpass

pwd = getpass.getpass()

cnx = mysql.connector.connect(user = "root",
                            password = pwd, # to input password
                            host = "localhost",
                            database = "sakila")

cnx.is_connected()

cursor = cnx.cursor()
# Out:
# ········

# %%
query = ("SELECT * FROM sakila.actor;")

cursor.execute(query)

results_actors = cursor.fetchall()

for item in results_actors:
    print("full name: ", item[1]," ",item[2])
# Out:
# full name:  PENELOPE   GUINESS
# full name:  NICK   WAHLBERG
# full name:  ED   CHASE
# full name:  JENNIFER   DAVIS
# full name:  JOHNNY   LOLLOBRIGIDA
# full name:  BETTE   NICHOLSON
# full name:  GRACE   MOSTEL
# full name:  MATTHEW   JOHANSSON
# full name:  JOE   SWANK
# full name:  CHRISTIAN   GABLE
# full name:  ZERO   CAGE
# full name:  KARL   BERRY
# full name:  UMA   WOOD
# full name:  VIVIEN   BERGEN
# full name:  CUBA   OLIVIER
# full name:  FRED   COSTNER
# full name:  HELEN   VOIGHT
# full name:  DAN   TORN
# full name:  BOB   FAWCETT
# full name:  LUCILLE   TRACY
# full name:  KIRSTEN   PALTROW
# full name:  ELVIS   MARX
# full name:  SANDRA   KILMER
# full name:  CAMERON   STREEP
# full name:  KEVIN   BLOOM
# full name:  RIP   CRAWFORD
# full name:  JULIA   MCQUEEN
# full name:  WOODY   HOFFMAN
# full name:  ALEC   WAYNE
# full name:  SANDRA   PECK
# full name:  SISSY   SOBIESKI
# full name:  TIM   HACKMAN
# full name:  MILLA   PECK
# full name:  AUDREY   OLIVIER
# ...

# %%
cursor.description
actors_df = pd.DataFrame(results_actors, columns = [head[0] for head in cursor.description])
actors_df
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
query = ("SELECT * FROM sakila.film_actor;")

cursor.execute(query)

results_films = cursor.fetchall()

film_actors = pd.DataFrame(results_films)
cursor.description
film_actors = pd.DataFrame(results_films, columns = [head[0] for head in cursor.description])
film_actors
# Out:
#       actor_id  film_id         last_update
# 0            1        1 2006-02-15 05:05:03
# 1            1       23 2006-02-15 05:05:03
# 2            1       25 2006-02-15 05:05:03
# 3            1      106 2006-02-15 05:05:03
# 4            1      140 2006-02-15 05:05:03
# ...        ...      ...                 ...
# 5457       200      879 2006-02-15 05:05:03
# 5458       200      912 2006-02-15 05:05:03
# 5459       200      945 2006-02-15 05:05:03
# 5460       200      958 2006-02-15 05:05:03
# 5461       200      993 2006-02-15 05:05:03
#
# [5462 rows x 3 columns]

# %%
query = ("SELECT * FROM sakila.film;")

cursor.execute(query)

results_film = cursor.fetchall()

cursor.description
films = pd.DataFrame(results_film, columns = [head[0] for head in cursor.description])
films.head(3)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
#
#    language_id original_language_id  rental_duration rental_rate  length  \
# 0            1                 None                6        0.99      86
# 1            1                 None                3        4.99      48
# 2            1                 None                7        2.99      50
#
#   replacement_cost rating                     special_features  \
# 0            20.99     PG  {Behind the Scenes, Deleted Scenes}
# 1            12.99      G           {Trailers, Deleted Scenes}
# 2            18.99  NC-17           {Trailers, Deleted Scenes}
#
# ...

# %%
/* the same as using group by*/
SELECT actor_id
FROM sakila.film_actor
INNER JOIN sakila.film
ON sakila.film_actor.film_id = sakila.film.film_id
WHERE length >= (SELECT AVG(length) FROM sakila.film)
GROUP BY actor_id
ORDER BY actor_id ASC;

# %%
films_actor = pd.merge(left = actors_df,
                           right = film_actors,
                           how = "inner",
                           left_on = "actor_id",
                           right_on = "actor_id")

films_actor.head(3)
# Out:
#    actor_id first_name last_name       last_update_x  film_id  \
# 0         1   PENELOPE   GUINESS 2006-02-15 04:34:33        1
# 1         1   PENELOPE   GUINESS 2006-02-15 04:34:33       23
# 2         1   PENELOPE   GUINESS 2006-02-15 04:34:33       25
#
#         last_update_y
# 0 2006-02-15 05:05:03
# 1 2006-02-15 05:05:03
# 2 2006-02-15 05:05:03

# %%
movies = pd.merge(left = films_actor,
                           right = films,
                           how = "inner",
                           left_on = "film_id",
                           right_on = "film_id")

movies.head(3)
# Out:
#    actor_id first_name last_name       last_update_x  film_id  \
# 0         1   PENELOPE   GUINESS 2006-02-15 04:34:33        1
# 1        10  CHRISTIAN     GABLE 2006-02-15 04:34:33        1
# 2        20    LUCILLE     TRACY 2006-02-15 04:34:33        1
#
#         last_update_y             title  \
# 0 2006-02-15 05:05:03  ACADEMY DINOSAUR
# 1 2006-02-15 05:05:03  ACADEMY DINOSAUR
# 2 2006-02-15 05:05:03  ACADEMY DINOSAUR
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 2  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id original_language_id  rental_duration rental_rate  length  \
# 0            1                 None                6        0.99      86
# 1            1                 None                6        0.99      86
# ...

# %%
actor_movie = movies.drop(['last_update_x','last_update_y','language_id','actor_id','film_id','description','last_update'], axis=1)

actor_movie.head(3)
# Out:
#   first_name last_name             title  release_year original_language_id  \
# 0   PENELOPE   GUINESS  ACADEMY DINOSAUR          2006                 None
# 1  CHRISTIAN     GABLE  ACADEMY DINOSAUR          2006                 None
# 2    LUCILLE     TRACY  ACADEMY DINOSAUR          2006                 None
#
#    rental_duration rental_rate  length replacement_cost rating  \
# 0                6        0.99      86            20.99     PG
# 1                6        0.99      86            20.99     PG
# 2                6        0.99      86            20.99     PG
#
#                       special_features
# 0  {Behind the Scenes, Deleted Scenes}
# 1  {Behind the Scenes, Deleted Scenes}
# 2  {Behind the Scenes, Deleted Scenes}

# %% [markdown]
# # Challenge 1 - Working with JSON files
# Import the pandas library.

# %%
# your code here

import pandas as pd

# %% [markdown]
# In the next cell, load the data in nasa.json in the data folder and load it into a pandas dataframe. Name the dataframe nasa.

# %%
# your code here

nasa = pd.read_json("C:/Users/migue/Documents/IRONHACK/Week 2/Labs/lab-import-export/your-code/nasa.json")

# %% [markdown]
# Now that we have loaded the data, let's examine it using the head() function.

# %%
# your code here

nasa.head(3)
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
#
#                                          geolocation  id      mass    name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....   1      21.0  Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...   2     720.0  Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...   6  107000.0    Abee
#
#   nametype recclass    reclat    reclong                     year
# 0    Valid       L5  50.77500    6.08333  1880-01-01T00:00:00.000
# 1    Valid       H6  56.18333   10.23333  1951-01-01T00:00:00.000
# 2    Valid      EH4  54.21667 -113.00000  1952-01-01T00:00:00.000

# %% [markdown]
# ####  The value_counts() function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the value_counts() function to determine the frequency of all types of asteroid landings by applying the function to the fall column.

# %%
# your code here

nasa["fall"].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the orient=records argument and name the file nasa-output.json. Remember to save the file inside the data folder.

# %%
# your code here

nasa.to_json("nasa-output.json", orient="records", lines=True)

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# Import the pandas library
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
#Your pandas import here:

import pandas as pd

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:

shuttle = pd.read_csv(tst_url, sep = " ", names = cols)

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# Your code here:

shuttle.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:

shuttle.to_csv("shuttle.csv", sep='\t', index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:

astronaut = pd.read_excel("C:/Users/migue/Documents/IRONHACK/Week 2/Labs/lab-import-export/your-code/astronauts.xls")

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:

astronaut.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut["Undergraduate Major"].value_counts()

#Physics is the most popular undegraduate major
# Out:
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:

astronaut.to_csv("astronaut.csv", sep='\t', index=False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:

import requests

from bs4 import BeautifulSoup

url = "https://archive.ics.uci.edu/ml/datasets/Fertility"

response = requests.get(url)
response.content

#fertility = pd.read_csv(url, sep ="\n")

#fertility.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [86], in <cell line: 12>()
#       9 response = requests.get(url)
#      10 response.content
# ---> 12 fertility = pd.read_csv(url, sep ="\n")
#      14 fertility.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
